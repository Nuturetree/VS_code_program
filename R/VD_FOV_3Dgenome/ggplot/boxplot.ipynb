# %%
## 分析CITT (钙离子跨膜运输) 所能够包含的Go term 
#options(repr.plot.width=12, repr.plot.height=15)
library(ggplot2)
library(reshape2)
rm(list = ls())
setwd("G:/Billfish/VD_FOV_3Dgenome/RNA_Seq/DEG/time_go_term_ljy/Calcium")
library(ggplot2)
library(ggpubr)
df <- read.csv("CITT_log2TPM_12h.txt", sep = "\t", header =T)
df_long <-  melt(df, id.vars=c("GeneId"))
#print(df_long)
# df_long <- within(df_long, samples <- factor(samples, levels = c("anthers_at", "anthers_dt", "cotyledon_at", "cotyledon_dt", "hypocotyl_at", "hypocotyl_dt", "leaf_at", "leaf_dt", "ovules_at", "ovules_dt", "fiber_5DPA_at", "fiber_5DPA_dt", "fiber_10DPA_at", "fiber_10DPA_dt", "fiber_20DPA_at", "fiber_20DPA_dt", "petals_at", "petals_dt", "radicle_at", "radicle_dt", "root_at", "root_dt", "stem_at", "stem_dt", "stigma_at", "stigma_dt")))
# with(df, levels(samples))
#df_long
compaired = list(c("Glr19_mock_Fov7", "J668_mock_Fov7"), c("J668_mock_Fov7", "J668_mock_v991"))
fg <- ggplot(df_long, aes(x = variable, y = value, fill = variable)) +
geom_boxplot(outlier.colour = NA, notch = FALSE) +
geom_point(colour = '#8C8C8C', alpha = 0.8)+
geom_line(aes(group=GeneId))+
#facet_wrap(.~samples, ncol=6) +
#coord_cartesian(ylim = c(0,5))+
labs(y = "|log2(FC)|", x = NULL) +
theme(panel.background = element_blank(),
     panel.grid = element_blank(),
     axis.line = element_line(linetype = 1),
     legend.position = "none",
     axis.ticks.length = unit(0.25, "cm"),
     axis.text = element_text(color = "black"),
     axis.text.x = element_text(angle = 315, hjust=0, size=12),
     axis.text.y = element_text(size=12),
     strip.text.x = element_text(size=14),
     axis.title.y = element_text(size=16)
     ) +
     scale_fill_manual(values = c("#1FA675", "#D95204", "#7571B2", "#E6298D", "#A6751B", "#69A71E", "#E2AE09", "#E6191E", "#1E79B2", "#df6b24", "#419FB7", "#efdab4"))
     #geom_signif(comparisons = compaired, step_increase = 0.05,test =wilcox.test, tip_length=0.01, textsize = 2, y_position=4)
fg
#ggsave(plot =fg, filename = 'CITT_log2read_12h.pdf', height =15, width = 12)
ggsave(plot =fg, filename = 'CITT_log2TPM_12hg.png', height =6, width = 5)
# Out:
# plot without title

# %%
## 分析CITT (钙离子跨膜运输) 所能够包含的Go term 
#options(repr.plot.width=12, repr.plot.height=15)
library(ggplot2)
library(reshape2)
rm(list = ls())
setwd("G:/Billfish/VD_FOV_3Dgenome/RNA_Seq/DEG/time_go_term_ljy/Calcium")
library(ggplot2)
library(ggpubr)
df <- read.csv("CITT_TPM_12h.bed", sep = "\t", header =T)
df_long <-  melt(df, id.vars=c("GeneId"))
compaired = list(c("Glr19_mock_Fov7", "J668_mock_Fov7"), c("J668_mock_Fov7", "J668_mock_v991"))
fg <- ggplot(df_long, aes(x = variable, y = log2(value), fill = variable)) +
geom_boxplot(outlier.colour = NA, notch = FALSE) +
geom_point(colour = '#8C8C8C', alpha = 0.8)+
geom_line(aes(group=GeneId))+
#facet_wrap(.~samples, ncol=6) +
#coord_cartesian(ylim = c(0,5))+
labs(y = "|log2(FC)|", x = NULL) +
theme(panel.background = element_blank(),
     panel.grid = element_blank(),
     axis.line = element_line(linetype = 1),
     legend.position = "none",
     axis.ticks.length = unit(0.25, "cm"),
     axis.text = element_text(color = "black"),
     axis.text.x = element_text(angle = 315, hjust=0, size=12),
     axis.text.y = element_text(size=12),
     strip.text.x = element_text(size=14),
     axis.title.y = element_text(size=16)
     ) +
     scale_fill_manual(values = c("#1FA675", "#D95204", "#7571B2", "#E6298D", "#A6751B", "#69A71E", "#E2AE09", "#E6191E", "#1E79B2", "#df6b24", "#419FB7", "#efdab4"))
     #geom_signif(comparisons = compaired, step_increase = 0.05,test =wilcox.test, tip_length=0.01, textsize = 2, y_position=4)
fg
#ggsave(plot =fg, filename = 'CITT_log2read_12h.pdf', height =15, width = 12)
ggsave(plot =fg, filename = 'CITT_TPM_12hg.png', height =6, width = 5)
# Out:
# Warning message:
# "Removed 5 rows containing non-finite values (stat_boxplot)."
# Warning message:
# "Removed 5 rows containing non-finite values (stat_boxplot)."
# plot without title

# %%
## 分析PTI 相关的基因 差异表达倍数
library(ggplot2)
library(reshape2)
rm(list = ls())
setwd("G:/Billfish/VD_FOV_3Dgenome/RNA_Seq/DEG/ETI_PTI/PTI/FC")
library(ggplot2)
library(ggpubr)
df <- read.csv("PTI_gene_FC.bed", sep = "\t", header =T)
df <- within(df, times <- factor(times, levels = c("1min", "5min", "10min", "30min", "90min", "180min", "720min")))
with(df, levels(times))
df <- within(df, tags <- factor(tags, levels = c("J668_mock_Fov7", "J668_mock_V991", "J668_Fov7_V991")))
with(df, levels(tags))
compaired = list(c("J668_mock_Fov7", "J668_Fov7_V991"), c("J668_mock_V991", "J668_Fov7_V991"))
fg <- ggplot(df, aes(x = tags, y = log2FC)) +
geom_violin(trim=F, aes(col=tags), fill=NA) +
geom_jitter(width=0.1, size=0.8, aes(col=tags), alpha = 0.3)+
stat_boxplot(geom = "errorbar",width=0.5, size=0.2)+
geom_boxplot(outlier.colour = NA, notch = TRUE, width = 0.3, fill = NA) +
#geom_point()+
#geom_line(aes(group=GeneId))+
facet_grid(.~times) +
coord_cartesian(ylim = c(-0.5,13))+
scale_y_continuous(breaks = c(0,4,8,12))+
labs(y = "|log2(FC)|", x = NULL) +
theme(panel.background = element_blank(),
     panel.grid = element_blank(),
     axis.line = element_line(linetype = 1),
#     legend.position = c(0.7, 0.9),
     legend.position = "top",

     axis.ticks.length = unit(0.25, "cm"),
     axis.text = element_text(color = "black"),
     #axis.text.x = element_text(angle = 315, hjust=0, size=12),
     axis.text.x = element_blank(),
     axis.ticks.x = element_blank(),
     axis.text.y = element_text(size=12),
     strip.text.x = element_text(size=8),
     axis.title.y = element_text(size=16),
     legend.key.size = unit(8, "pt")
     ) +
     scale_color_manual(values = c('#654ABC', '#FF9A15', '#008080'))+
     #scale_fill_manual(values = c('#3C2B73', '#CF7C30', '#005A5A'))
     geom_signif(comparisons = compaired, step_increase = 0.05,test =wilcox.test, tip_length=0.02, textsize = 2, y_position=11.5,  map_signif_level = T)
fg
#ggsave(plot =fg, filename = 'CITT_log2read_12h.pdf', height =15, width = 12)
ggsave(plot =fg, filename = 'PTI_gene_FC.pdf', height =3.5, width = 4)
# Out:
# [1] "1min"   "5min"   "10min"  "30min"  "90min"  "180min" "720min"
# [1] "J668_mock_Fov7" "J668_mock_V991" "J668_Fov7_V991"
# plot without title

# %%
## 分析能富集到活性氧信号相关的go terms 所包含的基因，其时期间差异水平的比较
## 分析PTI 相关的基因 差异表达倍数
library(ggplot2)
library(reshape2)
rm(list = ls())
setwd("G:/Billfish/VD_FOV_3Dgenome/RNA_Seq/DEG/ETI_PTI/PTI/FC/oxygen_calcium")
library(ggplot2)
library(ggpubr)
df <- read.csv("oxygen_FC_long.bed", sep = "\t", header =T)
df <- within(df, times <- factor(times, levels = c("1min", "5min", "10min", "30min", "90min", "180min", "720min")))
with(df, levels(times))
#df_need <- df[df$tags=='mock_vs_Fov7', ]

# print(df_long)
# df <- within(df, tags <- factor(tags, levels = c("J668_mock_Fov7", "J668_mock_V991", "J668_Fov7_V991")))
# with(df, levels(tags))
compaired = list(c("1min", "5min"), c('5min', '10min'), c('5min', '30min'), c('5min', '90min'), c('5min', '180min'), c('5min', '720min'))
fg <- ggplot(df, aes(x = times, y = abs(log2FC), fill=times)) +
geom_violin(trim=F) +
#geom_jitter(width=0.1, size=0.8, aes(col=variable), alpha = 0.3)+
stat_boxplot(geom = "errorbar",width=0.2)+
geom_boxplot(outlier.colour = NA, notch = TRUE, width = 0.2, fill = 'white') +
#geom_point()+
#geom_line(aes(group=GeneId))+
facet_grid(.~tags) +
coord_cartesian(ylim = c(-0.5,13))+
scale_y_continuous(breaks = c(0,4,8,12))+
labs(y = "|log2(FC)|", x = NULL) +
theme(panel.background = element_blank(),
     panel.grid = element_blank(),
     axis.line = element_line(linetype = 1),
#     legend.position = c(0.7, 0.9),
     legend.position = "top",

     axis.ticks.length = unit(0.25, "cm"),
     axis.text = element_text(color = "black"),
     axis.text.x = element_text(angle = 315, hjust=0, size=12),
     axis.text.y = element_text(size=12),
     strip.text.x = element_text(size=8),
     axis.title.y = element_text(size=16),
     legend.key.size = unit(8, "pt")
     ) +
     scale_fill_manual(values = c('#D782D9', '#05C7F2', '#1C8C63','#97BF04','#F26241','#FEEB5E','#B3E8BE'))+
     #scale_fill_manual(values = c('#3C2B73', '#CF7C30', '#005A5A'))
     geom_signif(comparisons = compaired, step_increase = 0.08,test =wilcox.test, tip_length=0.02, textsize = 2, na.rm=TRUE)
fg
#ggsave(plot =fg, filename = 'CITT_log2read_12h.pdf', height =15, width = 12)
ggsave(plot =fg, filename = 'oxygen_FC_long.pdf', height =4, width = 4)
# Out:
# [1] "1min"   "5min"   "10min"  "30min"  "90min"  "180min" "720min"
# plot without title

# %%
## 分析能富集到活性氧信号相关的go terms 所包含的基因，其时期间差异水平的比较
## 分析PTI 相关的基因 差异表达倍数
library(ggplot2)
library(reshape2)
rm(list = ls())
setwd("G:/Billfish/VD_FOV_3Dgenome/RNA_Seq/DEG/ETI_PTI/PTI/FC/oxygen_calcium")
library(ggplot2)
library(ggpubr)
df <- read.csv("calcium_FC_long.bed", sep = "\t", header =T)
df <- within(df, times <- factor(times, levels = c("1min", "5min", "10min", "30min", "90min", "180min", "720min")))
with(df, levels(times))
#df_need <- df[df$tags=='mock_vs_Fov7', ]

# print(df_long)
# df <- within(df, tags <- factor(tags, levels = c("J668_mock_Fov7", "J668_mock_V991", "J668_Fov7_V991")))
# with(df, levels(tags))
compaired = list(c("1min", "5min"), c('5min', '10min'), c('5min', '30min'), c('5min', '90min'), c('5min', '180min'), c('5min', '720min'))
fg <- ggplot(df, aes(x = times, y = abs(log2FC), fill=times)) +
geom_violin(trim=F) +
#geom_jitter(width=0.1, size=0.8, aes(col=variable), alpha = 0.3)+
stat_boxplot(geom = "errorbar",width=0.2)+
geom_boxplot(outlier.colour = NA, notch = TRUE, width = 0.2, fill = 'white') +
#geom_point()+
#geom_line(aes(group=GeneId))+
facet_grid(.~tags) +
coord_cartesian(ylim = c(-0.5,9.5))+
scale_y_continuous(breaks = c(0,2,4,6,8))+
labs(y = "|log2(FC)|", x = NULL) +
theme(panel.background = element_blank(),
     panel.grid = element_blank(),
     axis.line = element_line(linetype = 1),
#     legend.position = c(0.7, 0.9),
     legend.position = "top",

     axis.ticks.length = unit(0.25, "cm"),
     axis.text = element_text(color = "black"),
     axis.text.x = element_text(angle = 315, hjust=0, size=12),
     axis.text.y = element_text(size=12),
     strip.text.x = element_text(size=8),
     axis.title.y = element_text(size=16),
     legend.key.size = unit(8, "pt")
     ) +
     scale_fill_manual(values = c('#D782D9', '#05C7F2', '#1C8C63','#97BF04','#F26241','#FEEB5E','#B3E8BE'))+
     #scale_fill_manual(values = c('#3C2B73', '#CF7C30', '#005A5A'))
     geom_signif(comparisons = compaired, step_increase = 0.08,test =wilcox.test, tip_length=0.02, textsize = 2, na.rm=TRUE)
fg
ggsave(plot =fg, filename = 'calcium_FC_long.pdf', height =4, width = 4)
# Out:
# [1] "1min"   "5min"   "10min"  "30min"  "90min"  "180min" "720min"
# notch went outside hinges. Try setting notch=FALSE.
#
# notch went outside hinges. Try setting notch=FALSE.
#
# notch went outside hinges. Try setting notch=FALSE.
#
# notch went outside hinges. Try setting notch=FALSE.
#
# notch went outside hinges. Try setting notch=FALSE.
#
# notch went outside hinges. Try setting notch=FALSE.
#
# notch went outside hinges. Try setting notch=FALSE.
#
# notch went outside hinges. Try setting notch=FALSE.
# plot without title

# %%
## 分析活性氧相关Go terms，所关注的cluster1 基因
#options(repr.plot.width=12, repr.plot.height=15)
library(ggplot2)
library(reshape2)
rm(list = ls())
setwd("G:/Billfish/VD_FOV_3Dgenome/RNA_Seq/DEG/ETI_PTI/PTI/TPM/oxygen")
library(ggplot2)
library(ggpubr)
df <- read.csv("reactive_oxygen_cluster2.bed", sep = "\t", header =T)
df <- within(df, times <- factor(times, levels = c("1min", "5min", "10min", "30min", "90min", "180min", "720min")))
with(df, levels(times))
df <- within(df, tags <- factor(tags, levels = c( "J668_V991", "J668_Fov7","J668_mock", "Glr19_mock", "Glr19_Fov7")))
with(df, levels(tags))
df_choose = df[df$tags=='J668_Fov7' | df$tags=='J668_V991' | df$tags=='J668_mock', ]
#print(df_long)

#df_long
#ompaired = list(c("Glr19_mock_Fov7", "J668_mock_Fov7"), c("J668_mock_Fov7", "J668_mock_v991"))
fg <- ggplot(df_choose, aes(x = times, y = TPM, color = times)) +
stat_boxplot(geom = "errorbar",width=0.3)+
geom_boxplot(outlier.colour = NA, notch = FALSE, fill='white', width=0.5) +
geom_line(aes(group=GeneId), color="#BABABA")+
#geom_smooth(aes(group=GeneId), color="#BABABA", se = FALSE)+
geom_point(alpha = 0.8)+
facet_grid(tags~., scales = 'free') +
#coord_cartesian(ylim = c(0,5))+
labs(y = "TPM", x = NULL) +
theme(panel.background = element_blank(),    
     panel.grid = element_blank(),
     axis.line = element_line(linetype = 1),
     legend.position = "none",
     axis.ticks.length = unit(0.25, "cm"),
     axis.text = element_text(color = "black"),
     axis.text.x = element_text(angle = 315, hjust=0, size=12),
     axis.text.y = element_text(size=12),
     strip.text.x = element_text(size=14),
     axis.title.y = element_text(size=16)
     ) +
     scale_color_manual(values = c('#D782D9', '#05C7F2', '#1C8C63','#97BF04','#F26241','#FEEB5E','#B3E8BE'))
     #geom_signif(comparisons = compaired, step_increase = 0.05,test =wilcox.test, tip_length=0.01, textsize = 2, y_position=4)
fg
# ggsave(plot =fg, filename = 'reactive_oxygen_cluster1.pdf', height =3, width = 3.5)
# ggsave(plot =fg, filename = 'reactive_oxygen_cluster1.png', height =3, width = 3.5)

ggsave(plot =fg, filename = 'reactive_oxygen_cluster2.pdf', height =3, width = 3.5)
ggsave(plot =fg, filename = 'reactive_oxygen_cluster2.png', height =3, width = 3.5)
# Out:
# [1] "1min"   "5min"   "10min"  "30min"  "90min"  "180min" "720min"
# [1] "J668_V991"  "J668_Fov7"  "J668_mock"  "Glr19_mock" "Glr19_Fov7"
# plot without title

# %%
## 分析活性氧相关Go terms，所关注的cluster1 基因
#options(repr.plot.width=12, repr.plot.height=15)
library(ggplot2)
library(reshape2)
rm(list = ls())
setwd("G:/Billfish/VD_FOV_3Dgenome/RNA_Seq/DEG/ETI_PTI/PTI/TPM/calcium")
library(ggplot2)
library(ggpubr)
df <- read.csv("calcium_cluster1.bed", sep = "\t", header =T)
df <- within(df, times <- factor(times, levels = c("1min", "5min", "10min", "30min", "90min", "180min", "720min")))
with(df, levels(times))
df <- within(df, tags <- factor(tags, levels = c( "J668_V991", "J668_Fov7","J668_mock", "Glr19_mock", "Glr19_Fov7")))
with(df, levels(tags))
df_choose = df[df$tags=='J668_Fov7' | df$tags=='J668_V991' | df$tags=='J668_mock', ]
#print(df_long)

#df_long
#ompaired = list(c("Glr19_mock_Fov7", "J668_mock_Fov7"), c("J668_mock_Fov7", "J668_mock_v991"))
fg <- ggplot(df_choose, aes(x = times, y = TPM, color = times)) +
stat_boxplot(geom = "errorbar",width=0.3)+
geom_boxplot(outlier.colour = NA, notch = FALSE, fill='white', width=0.5) +
geom_line(aes(group=GeneId), color="#BABABA")+
#geom_smooth(aes(group=GeneId), color="#BABABA", se = FALSE)+
geom_point(alpha = 0.8)+
facet_grid(tags~.) +
#coord_cartesian(ylim = c(0,5))+
labs(y = "TPM", x = NULL) +
theme(panel.background = element_blank(),
     panel.grid = element_blank(),
     axis.line = element_line(linetype = 1),
     legend.position = "none",
     axis.ticks.length = unit(0.25, "cm"),
     axis.text = element_text(color = "black"),
     axis.text.x = element_text(angle = 315, hjust=0, size=12),
     axis.text.y = element_text(size=12),
     strip.text.x = element_text(size=14),
     axis.title.y = element_text(size=16)
     ) +
     scale_color_manual(values = c('#D782D9', '#05C7F2', '#1C8C63','#97BF04','#F26241','#FEEB5E','#B3E8BE'))
     #geom_signif(comparisons = compaired, step_increase = 0.05,test =wilcox.test, tip_length=0.01, textsize = 2, y_position=4)
fg
ggsave(plot =fg, filename = 'calcium_cluster1.pdf', height =6, width = 6)
ggsave(plot =fg, filename = 'calcium_cluster1.png', height =6, width = 6)
# Out:
# [1] "1min"   "5min"   "10min"  "30min"  "90min"  "180min" "720min"
# [1] "J668_V991"  "J668_Fov7"  "J668_mock"  "Glr19_mock" "Glr19_Fov7"
# plot without title
