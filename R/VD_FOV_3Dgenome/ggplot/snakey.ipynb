# %%
## 基因差异表达动态变化桑基图
rm(list=ls())
library(ggplot2)
library(alluvial)
setwd('F:/VD_FOV_3Dgenome/RNA_Seq/DEG/J668_mock_Fov7')
tit = read.csv('J668_mock_Fov7_snaky_format.txt', header = T, sep = '\t')
alluvial(tit[,1:7], freq=tit$number,
         #col = tit$DPA20,
         #col = ['#72D9C6','#C3D9B8','#F1C848'],
         #border = tit$DPA20,
         col = ifelse(tit$h12 == "Down", '#FFE9AA', ifelse(tit$h12 == "Up", "#D94854", 'grey')),
         border = ifelse(tit$h12 == "Down", '#FFE9AA', ifelse(tit$h12 == "Up", "#D94854", 'grey')),
         #border = ifelse(tit$DPA20 == "Yes", "orange", "grey"),
         hide = tit$number == 0,
         cex = 0.7
)
# Out:
# plot without title

# %%
pdf(file = 'J668_mock_Fov7_snaky_format.pdf')
alluvial(tit[,1:7], freq=tit$number,
         #col = tit$DPA20,
         #col = ['#72D9C6','#C3D9B8','#F1C848'],
         #border = tit$DPA20,
         col = ifelse(tit$h12 == "Down", '#FFE9AA', ifelse(tit$h12 == "Up", "#D94854", 'grey')),
         border = ifelse(tit$h12 == "Down", '#FFE9AA', ifelse(tit$h12 == "Up", "#D94854", 'grey')),
         #border = ifelse(tit$DPA20 == "Yes", "orange", "grey"),
         hide = tit$number == 0,
         cex = 0.7
)
dev.off()
# Out:
# png
#   2

# %%
## 基因差异表达动态变化桑基图
rm(list=ls())
library(ggplot2)
library(alluvial)
setwd('F:/VD_FOV_3Dgenome/RNA_Seq/DEG/J668_mock_Fov7')
tit = read.csv('J668_mock_Fov7_snaky_format_not.txt', header = T, sep = '\t')
alluvial(tit[,1:7], freq=tit$number,
         #col = tit$DPA20,
         #col = ['#72D9C6','#C3D9B8','#F1C848'],
         #border = tit$DPA20,
         col = ifelse(tit$h12 == "Down", '#FFE9AA', ifelse(tit$h12 == "Up", "#D94854", 'grey')),
         border = ifelse(tit$h12 == "Down", '#FFE9AA', ifelse(tit$h12 == "Up", "#D94854", 'grey')),
         #border = ifelse(tit$DPA20 == "Yes", "orange", "grey"),
         hide = tit$number == 0,
         cex = 0.7
)
# Out:
# plot without title

# %%
pdf(file = 'J668_mock_Fov7_snaky_format_not.pdf')
alluvial(tit[,1:7], freq=tit$number,
         col = ifelse(tit$h12 == "Down", '#FFE9AA', ifelse(tit$h12 == "Up", "#D94854", 'grey')),
         border = ifelse(tit$h12 == "Down", '#FFE9AA', ifelse(tit$h12 == "Up", "#D94854", 'grey')),
         hide = tit$number == 0,
         cex = 0.7
)
dev.off()
# Out:
# png
#   2

# %%
## mock_v991
## 基因差异表达动态变化桑基图
rm(list=ls())
library(ggplot2)
library(alluvial)
setwd('F:/VD_FOV_3Dgenome/RNA_Seq/DEG/J668_mock_v991')
tit = read.csv('J668_mock_v991_snaky_format_not.txt', header = T, sep = '\t')
alluvial(tit[,1:7], freq=tit$number,
         #col = tit$DPA20,
         #col = ['#72D9C6','#C3D9B8','#F1C848'],
         #border = tit$DPA20,
         col = ifelse(tit$h12 == "Down", '#FFE9AA', ifelse(tit$h12 == "Up", "#D94854", 'grey')),
         border = ifelse(tit$h12 == "Down", '#FFE9AA', ifelse(tit$h12 == "Up", "#D94854", 'grey')),
         #border = ifelse(tit$DPA20 == "Yes", "orange", "grey"),
         hide = tit$number == 0,
         cex = 0.7
)
# Out:
# plot without title

# %%
pdf(file = 'J668_mock_v991_snaky_format_not.pdf')
alluvial(tit[,1:7], freq=tit$number,
         col = ifelse(tit$h12 == "Down", '#FFE9AA', ifelse(tit$h12 == "Up", "#D94854", 'grey')),
         border = ifelse(tit$h12 == "Down", '#FFE9AA', ifelse(tit$h12 == "Up", "#D94854", 'grey')),
         hide = tit$number == 0,
         cex = 0.7
)
dev.off()
# Out:
# png
#   2

# %%
## glr19_Fov7 基因差异表达动态变化桑基图
rm(list=ls())
library(ggplot2)
library(alluvial)
setwd('F:/VD_FOV_3Dgenome/RNA_Seq/DEG/glr19_mock_Fov7')
tit = read.csv('glr19_mock_Fov7_snaky_format_not.txt', header = T, sep = '\t')
alluvial(tit[,1:7], freq=tit$number,
         #col = tit$DPA20,
         #col = ['#72D9C6','#C3D9B8','#F1C848'],
         #border = tit$DPA20,
         col = ifelse(tit$h12 == "Down", '#FFE9AA', ifelse(tit$h12 == "Up", "#D94854", 'grey')),
         border = ifelse(tit$h12 == "Down", '#FFE9AA', ifelse(tit$h12 == "Up", "#D94854", 'grey')),
         #border = ifelse(tit$DPA20 == "Yes", "orange", "grey"),
         hide = tit$number == 0,
         cex = 0.7
)
# Out:
# plot without title

# %%
pdf(file = 'glr19_mock_Fov7_snaky_format_not.pdf')
alluvial(tit[,1:7], freq=tit$number,
         col = ifelse(tit$h12 == "Down", '#FFE9AA', ifelse(tit$h12 == "Up", "#D94854", 'grey')),
         border = ifelse(tit$h12 == "Down", '#FFE9AA', ifelse(tit$h12 == "Up", "#D94854", 'grey')),
         hide = tit$number == 0,
         cex = 0.7
)
dev.off()
# Out:
# png
#   2

# %%
## 分析某一个Go term 所包含的差异基因的动态变化过程
rm(list=ls())
library(ggplot2)
library(alluvial)
setwd('F:/VD_FOV_3Dgenome/RNA_Seq/DEG/glr19_mock_Fov7/all_go_term')
tit = read.csv('glr19_mock_Fov7_DEGid_snaky.txt', header = T, sep = '\t')
# tit[,1:7]
alluvial(tit[,1:6], freq=tit$number,
         #col = tit$DPA20,
         #col = ['#72D9C6','#C3D9B8','#F1C848'],
         #border = tit$DPA20,
         col = ifelse(tit$min10 == "Down", '#FFE9AA', ifelse(tit$min10 == "Up", "#D94854", 'grey')),
         border = ifelse(tit$min10 == "Down", '#FFE9AA', ifelse(tit$min10 == "Up", "#D94854", 'grey')),
         #border = ifelse(tit$DPA20 == "Yes", "orange", "grey"),
         hide = tit$number == 0,
         cex = 0.7
)
# Out:
# plot without title

# %%
pdf(file = 'glr19_mock_Fov7_DEGid_snaky_calcium.pdf')
alluvial(tit[,1:6], freq=tit$number,
         col = ifelse(tit$min10 == "Down", '#FFE9AA', ifelse(tit$min10 == "Up", "#D94854", 'grey')),
         border = ifelse(tit$min10 == "Down", '#FFE9AA', ifelse(tit$min10 == "Up", "#D94854", 'grey')),
         hide = tit$number == 0,
         cex = 0.7
)
dev.off()
# Out:
# png
#   2

# %%
## 分析某一个Go term 所包含的差异基因的动态变化过程
rm(list=ls())
library(ggplot2)
library(alluvial)
setwd('F:/VD_FOV_3Dgenome/RNA_Seq/DEG/glr19_mock_Fov7/all_go_term')
tit = read.csv('glr19_mock_Fov7_reactive oxygen_DEGid_snaky.txt', header = T, sep = '\t')
# tit[,1:7]
alluvial(tit[,1:6], freq=tit$number,
         #col = tit$DPA20,
         #col = ['#72D9C6','#C3D9B8','#F1C848'],
         #border = tit$DPA20,
         col = ifelse(tit$min10 == "Down", '#FFE9AA', ifelse(tit$min10 == "Up", "#D94854", 'grey')),
         border = ifelse(tit$min10 == "Down", '#FFE9AA', ifelse(tit$min10 == "Up", "#D94854", 'grey')),
         #border = ifelse(tit$DPA20 == "Yes", "orange", "grey"),
         hide = tit$number == 0,
         cex = 0.7
)
# Out:
# plot without title

# %%
pdf(file = 'glr19_mock_Fov7_reactive oxygen_DEGid_snaky.pdf')
alluvial(tit[,1:6], freq=tit$number,
         col = ifelse(tit$min10 == "Down", '#FFE9AA', ifelse(tit$min10 == "Up", "#D94854", 'grey')),
         border = ifelse(tit$min10 == "Down", '#FFE9AA', ifelse(tit$min10 == "Up", "#D94854", 'grey')),
         hide = tit$number == 0,
         cex = 0.7
)
dev.off()
# Out:
# png
#   2

# %%
## 分析某一个Go term 所包含的差异基因的动态变化过程
rm(list=ls())
library(ggplot2)
library(alluvial)
setwd('F:/VD_FOV_3Dgenome/RNA_Seq/DEG/J668_mock_Fov7/all_go_term')
tit = read.csv('J668_mock_Fov7_DEGid_snaky.txt', header = T, sep = '\t')
# tit[,1:7]
alluvial(tit[,1:6], freq=tit$number,
         #col = tit$DPA20,
         #col = ['#72D9C6','#C3D9B8','#F1C848'],
         #border = tit$DPA20,
         col = ifelse(tit$min5 == "Down", '#FFE9AA', ifelse(tit$min5 == "Up", "#D94854", 'grey')),
         border = ifelse(tit$min5 == "Down", '#FFE9AA', ifelse(tit$min5 == "Up", "#D94854", 'grey')),
         #border = ifelse(tit$DPA20 == "Yes", "orange", "grey"),
         hide = tit$number == 0,
         cex = 0.7
)
# Out:
# plot without title

# %%
pdf(file = 'J668_mock_Fov7_DEGid_snaky_calcium.pdf')
alluvial(tit[,1:6], freq=tit$number,
         col = ifelse(tit$min5 == "Down", '#FFE9AA', ifelse(tit$min5 == "Up", "#D94854", 'grey')),
         border = ifelse(tit$min5 == "Down", '#FFE9AA', ifelse(tit$min5 == "Up", "#D94854", 'grey')),
         hide = tit$number == 0,
         cex = 0.7
)
dev.off()
# Out:
# png
#   2

# %%
## 分析某一个Go term 所包含的差异基因的动态变化过程
rm(list=ls())
library(ggplot2)
library(alluvial)
setwd('F:/VD_FOV_3Dgenome/RNA_Seq/DEG/J668_mock_Fov7/all_go_term')
tit = read.csv('J668_mock_Fov7_reactive oxygen_DEGid_snaky.txt', header = T, sep = '\t')
# tit[,1:7]
alluvial(tit[,1:6], freq=tit$number,
         #col = tit$DPA20,
         #col = ['#72D9C6','#C3D9B8','#F1C848'],
         #border = tit$DPA20,
         col = ifelse(tit$min5 == "Down", '#FFE9AA', ifelse(tit$min5 == "Up", "#D94854", 'grey')),
         border = ifelse(tit$min5 == "Down", '#FFE9AA', ifelse(tit$min5 == "Up", "#D94854", 'grey')),
         #border = ifelse(tit$DPA20 == "Yes", "orange", "grey"),
         hide = tit$number == 0,
         cex = 0.7
)
# Out:
# plot without title

# %%
pdf(file = 'J668_mock_Fov7_DEGid_reactive oxygen_snaky.pdf')
alluvial(tit[,1:6], freq=tit$number,
         col = ifelse(tit$min5 == "Down", '#FFE9AA', ifelse(tit$min5 == "Up", "#D94854", 'grey')),
         border = ifelse(tit$min5 == "Down", '#FFE9AA', ifelse(tit$min5 == "Up", "#D94854", 'grey')),
         hide = tit$number == 0,
         cex = 0.7
)
dev.off()
# Out:
# png
#   2

# %%
## 分析某一个Go term 所包含的差异基因的动态变化过程
rm(list=ls())
library(ggplot2)
library(alluvial)
setwd('F:/VD_FOV_3Dgenome/RNA_Seq/DEG/J668_mock_v991/all_go_term')
tit = read.csv('J668_mock_v991_DEGid_snaky.txt', header = T, sep = '\t')
# tit[,1:7]
alluvial(tit[,1:6], freq=tit$number,
         #col = tit$DPA20,
         #col = ['#72D9C6','#C3D9B8','#F1C848'],
         #border = tit$DPA20,
         col = ifelse(tit$min5 == "Down", '#FFE9AA', ifelse(tit$min5 == "Up", "#D94854", 'grey')),
         border = ifelse(tit$min5 == "Down", '#FFE9AA', ifelse(tit$min5 == "Up", "#D94854", 'grey')),
         #border = ifelse(tit$DPA20 == "Yes", "orange", "grey"),
         hide = tit$number == 0,
         cex = 0.7
)
# Out:
# plot without title

# %%
pdf(file = 'J668_mock_v991_DEGid_snaky_calcium.pdf')
alluvial(tit[,1:6], freq=tit$number,
         col = ifelse(tit$min5 == "Down", '#FFE9AA', ifelse(tit$min5 == "Up", "#D94854", 'grey')),
         border = ifelse(tit$min5 == "Down", '#FFE9AA', ifelse(tit$min5 == "Up", "#D94854", 'grey')),
         hide = tit$number == 0,
         cex = 0.7
)
dev.off()
# Out:
# png
#   2

# %%
## 分析某一个Go term 所包含的差异基因的动态变化过程
rm(list=ls())
library(ggplot2)
library(alluvial)
setwd('F:/VD_FOV_3Dgenome/RNA_Seq/DEG/J668_mock_v991/all_go_term')
tit = read.csv('J668_mock_v991_reactive oxygen_DEGid_snaky.txt', header = T, sep = '\t')
# tit[,1:7]
alluvial(tit[,1:6], freq=tit$number,
         #col = tit$DPA20,
         #col = ['#72D9C6','#C3D9B8','#F1C848'],
         #border = tit$DPA20,
         col = ifelse(tit$min5 == "Down", '#FFE9AA', ifelse(tit$min5 == "Up", "#D94854", 'grey')),
         border = ifelse(tit$min5 == "Down", '#FFE9AA', ifelse(tit$min5 == "Up", "#D94854", 'grey')),
         #border = ifelse(tit$DPA20 == "Yes", "orange", "grey"),
         hide = tit$number == 0,
         cex = 0.7
)
# Out:
# plot without title

# %%
pdf(file = 'J668_mock_v991_reactive oxygen_DEGid_snaky.pdf')
alluvial(tit[,1:6], freq=tit$number,
         col = ifelse(tit$min5 == "Down", '#FFE9AA', ifelse(tit$min5 == "Up", "#D94854", 'grey')),
         border = ifelse(tit$min5 == "Down", '#FFE9AA', ifelse(tit$min5 == "Up", "#D94854", 'grey')),
         hide = tit$number == 0,
         cex = 0.7
)
dev.off()
# Out:
# png
#   2
