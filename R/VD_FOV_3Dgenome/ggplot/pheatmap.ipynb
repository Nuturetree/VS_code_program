# %%
library(ComplexHeatmap)
library(circlize)
setwd('F:/VD_FOV_3Dgenome/RNA_Seq/DEG/J668_mock_Fov7')
df = as.matrix(read.table('J668_mock_Fov7J668_all_DEG_GO.txt', sep='\t', header=T, row.names = 1))
exp <- apply(df, 1, scale)
rownames(exp) <- colnames(df)
exp <- t(exp)
col_fun <- colorRamp2(
  c(-2, 0, 2), 
  c("#ed2f6a", "white", "#01665e")
  )
col_fun(seq(-3, 3))
pheatmap(exp, cluster_cols=F, col=col_fun,  clustering_distance_rows = "spearman", show_rownames=F)
# Out:
# [1] "#ED2F6AFF" "#ED2F6AFF" "#FFA3B1FF" "#FFFFFFFF" "#8BB0ABFF" "#01665EFF"
# [7] "#01665EFF"
# plot without title

# %%
library(ComplexHeatmap)
library(circlize)
setwd('F:/VD_FOV_3Dgenome/RNA_Seq/DEG/J668_mock_v991')
df = as.matrix(read.table('J668_mock_v991_all_DEG_GO.txt', sep='\t', header=T, row.names = 1))
exp <- apply(df, 1, scale)
rownames(exp) <- colnames(df)
exp <- t(exp)
col_fun <- colorRamp2(
  c(-2, 0, 2), 
  c("#ed2f6a", "white", "#01665e")
  )
col_fun(seq(-3, 3))
pheatmap(exp, cluster_cols=F, col=col_fun,  clustering_distance_rows = "spearman", show_rownames=F)
# Out:
# [1] "#ED2F6AFF" "#ED2F6AFF" "#FFA3B1FF" "#FFFFFFFF" "#8BB0ABFF" "#01665EFF"
# [7] "#01665EFF"
# plot without title

# %%
library(ComplexHeatmap)
library(circlize)
setwd('F:/VD_FOV_3Dgenome/RNA_Seq/DEG/glr19_mock_Fov7')
df = as.matrix(read.table('glr19_mock_Fov7_all_DEG_GO.txt', sep='\t', header=T, row.names = 1))
exp <- apply(df, 1, scale)
rownames(exp) <- colnames(df)
exp <- t(exp)
col_fun <- colorRamp2(
  c(-2, 0, 2), 
  c("#ed2f6a", "white", "#01665e")
  )
col_fun(seq(-3, 3))
pheatmap(exp, cluster_cols=F, col=col_fun,  clustering_distance_rows = "spearman", show_rownames=F)
# Out:
# [1] "#ED2F6AFF" "#ED2F6AFF" "#FFA3B1FF" "#FFFFFFFF" "#8BB0ABFF" "#01665EFF"
# [7] "#01665EFF"
# plot without title

# %%
library(ComplexHeatmap)
library(circlize)
setwd('F:/VD_FOV_3Dgenome/RNA_Seq/DEG/glr19_mock_Fov7')
df = as.matrix(read.table('glr19_mock_Fov7_all_DEG_GO_top10.txt', sep='\t', header=T, row.names = 1))
df_normal <- scale(df)
#exp <- apply(df, 2, scale)
#colnames(exp) <- rownames(df)
#exp <- t(exp)
col_fun <- colorRamp2(
  c(-1, 0, 1), 
  c("#01665e", "white","#ed2f6a")
  )
pheatmap(df_normal, cluster_cols=F, cluster_row=F, col=col_fun)
# Out:
# plot without title

# %%
library(ComplexHeatmap)
library(circlize)
setwd('F:/VD_FOV_3Dgenome/RNA_Seq/DEG/J668_mock_Fov7')
df = as.matrix(read.table('J668_mock_Fov7_all_DEG_GO_top10.txt', sep='\t', header=T, row.names = 1))
df_normal <- scale(df)
View(df_normal)
col_fun <- colorRamp2(
  c(-1, 0, 1), 
  c("#01665e", "white","#ed2f6a")
  )
pheatmap(df_normal, cluster_cols=F, cluster_row=F, col=col_fun)
# Out:
#            qvalue_1min qvalue_5min qvalue_10min qvalue_30min qvalue_90min
# GO:0071456  0.7121128   0.7661023   0.8310111           NA    0.8575604
# GO:0036294  0.7121128   0.7661023   0.8310111           NA    0.8575604
# GO:0071453  0.7121128   0.7661023   0.8310111           NA    0.8575604
# GO:0001666  0.6777831   0.6247774   0.7275057           NA    0.7063114
# GO:0036293  0.5831078   0.5133733   0.7105771           NA    0.6402090
# GO:0070482  0.5784065   0.5133733   0.7105771           NA    0.6385881
# GO:0009698  0.1110182          NA  -1.1338306    2.4455581   -0.7363253
# GO:0009699 -0.6479845          NA          NA   -0.1206336   -1.0738856
# GO:0019748 -1.7071801  -1.7012411          NA   -0.1206336   -1.3136541
# GO:0009808 -1.7314892          NA          NA           NA   -1.4339247
# GO:0009611         NA   0.1252565          NA    0.3017126           NA
# GO:0000278         NA  -0.6417964          NA           NA           NA
# ...

# %%
library(ComplexHeatmap)
library(circlize)
setwd('F:/VD_FOV_3Dgenome/RNA_Seq/DEG/J668_mock_v991')
df = as.matrix(read.table('J668_mock_v991_all_DEG_GO_top10.txt', sep='\t', header=T, row.names = 1))
df_normal <- scale(df)
View(df_normal)
col_fun <- colorRamp2(
  c(-1, 0, 1), 
  c("#01665e", "white","#ed2f6a")
  )
pheatmap(df_normal, cluster_cols=F, cluster_row=F, col=col_fun)
# Out:
#            qvalue_1min qvalue_5min qvalue_10min qvalue_30min qvalue_90min
# GO:0001666  0.7980499   0.6886665           NA   0.4884327    0.7241695
# GO:0036293  0.7824233   0.7242659           NA   0.5009764    0.7241695
# GO:0070482  0.7824233   0.7242159           NA   0.5003090    0.7189269
# GO:0071456  0.7313567   0.7716518           NA   0.7770952    0.7241695
# GO:0036294  0.7164638   0.8354173           NA   0.9009960    0.7241695
# GO:0071453  0.7164638   0.8354173           NA   0.9009960    0.7241695
# GO:0009698 -0.7761554          NA   0.05234512  -0.3291652   -1.3877999
# GO:0009699 -0.8627646          NA           NA  -1.7177548           NA
# GO:0044550 -1.2717724          NA  -1.07427035          NA           NA
# GO:0019748 -1.6164886          NA   1.41543268  -1.6927201           NA
# GO:0009611         NA  -0.7532972   1.78110304  -0.3291652           NA
# GO:0042742         NA  -1.1193993           NA          NA           NA
# ...

# %%
### 分析时期基因表达水平
setwd("G:/Billfish/VD_FOV_3Dgenome/RNA_Seq/DEG/ETI_PTI/PTI/TPM/oxygen")
library(ComplexHeatmap)
options(repr.plot.width=12,repr.plot.height=12)
df = as.matrix(read.table('oxygen_TPM_zscore_normal_01.bed', sep='\t', header=T, row.names = 1))
col_fun = circlize::colorRamp2(c(0, 0.5, 1), c( "#005A5A", "#D2D2D2", "#DD2929"))
# Heatmap(df, name = "ratio", rect_gp = gpar(type = "none"), col = col_fun, 
#     cell_fun = function(j, i, x, y, width, height, fill) {
#         grid.circle(x = x, y = y, r = abs(df[i, j])/2 * min(unit.c(width, height)), 
#                 gp = gpar(fill = col_fun(df[i, j]), col = NA))
#     }, 
#     cluster_rows = TRUE, cluster_columns = FALSE, show_row_names = FALSE)
    
Heatmap(df, name = "ratio", rect_gp = gpar(type = "none"), col = col_fun, 
    cell_fun = function(j, i, x, y, width, height, fill) {
        grid.circle(x = x, y = y, r = abs(df[i, j])/2 * min(unit.c(width, height)), 
                gp = gpar(fill = col_fun(df[i, j]), col = NA))
    }, 
    cluster_rows = TRUE, cluster_columns = FALSE)
# Out:
# plot without title

# %%
pdf(file = "oxygen_TPM_zscore_normal_01.pdf", width=3.4, height=4)
Heatmap(df, name = "ratio", rect_gp = gpar(type = "none"), col = col_fun, 
    cell_fun = function(j, i, x, y, width, height, fill) {
        grid.circle(x = x, y = y, r = abs(df[i, j])/2 * min(unit.c(width, height)), 
                gp = gpar(fill = col_fun(df[i, j]), col = NA))
    }, 
    cluster_rows = TRUE, cluster_columns = FALSE, show_row_names = FALSE)
dev.off()
# Out:
# png
#   2

# %%
### 分析时期基因表达水平， 与活性氧所引起的细胞程序性死亡相关
setwd("G:/Billfish/VD_FOV_3Dgenome/RNA_Seq/DEG/ETI_PTI/PTI/TPM/oxygen")
library(ComplexHeatmap)
options(repr.plot.width=6,repr.plot.height=6)
df = as.matrix(read.table('oxygen_TPM_zscore_normal_01.bed', sep='\t', header=T, row.names = 1))
oxygen_dath = c('Ghir_A05G023090', 'Ghir_A08G023350', 'Ghir_A08G023360', 'Ghir_A13G016370', 'Ghir_A13G016380', 'Ghir_A13G016390', 'Ghir_A13G022470', 'Ghir_A13G022480', 'Ghir_D13G017130', 'Ghir_D13G017140', 'Ghir_D13G023210')
df_need = df[oxygen_dath, ]
#print(df_need)
col_fun = circlize::colorRamp2(c(0, 0.5, 1), c( "#005A5A", "#D2D2D2", "#DD2929"))    
Heatmap(df_need, name = "ratio", rect_gp = gpar(type = "none"), col = col_fun, 
    cell_fun = function(j, i, x, y, width, height, fill) {
        grid.circle(x = x, y = y, r = abs(df_need[i, j])/2 * min(unit.c(width, height)), 
                gp = gpar(fill = col_fun(df_need[i, j]), col = NA))
    }, 
    cluster_rows = TRUE, cluster_columns = FALSE)
# Out:
# plot without title

# %%
### 分析时期基因表达水平
setwd("G:/Billfish/VD_FOV_3Dgenome/RNA_Seq/DEG/ETI_PTI/PTI/TPM/calcium")
library(ComplexHeatmap)
options(repr.plot.width=12,repr.plot.height=12)
df = as.matrix(read.table('calcium_TPM_zscore_normal_01.bed', sep='\t', header=T, row.names = 1))
col_fun = circlize::colorRamp2(c(0, 0.5, 1), c( "#005A5A", "#D2D2D2", "#DD2929"))    
Heatmap(df, name = "ratio", rect_gp = gpar(type = "none"), col = col_fun, 
    cell_fun = function(j, i, x, y, width, height, fill) {
        grid.circle(x = x, y = y, r = abs(df[i, j])/2 * min(unit.c(width, height)), 
                gp = gpar(fill = col_fun(df[i, j]), col = NA))
    }, 
    cluster_rows = TRUE, cluster_columns = FALSE)
# Out:
# plot without title

# %%
pdf(file = "calcium_TPM_zscore_normal_01.pdf", width=3.4, height=4)
Heatmap(df, name = "ratio", rect_gp = gpar(type = "none"), col = col_fun, 
    cell_fun = function(j, i, x, y, width, height, fill) {
        grid.circle(x = x, y = y, r = abs(df[i, j])/2 * min(unit.c(width, height)), 
                gp = gpar(fill = col_fun(df[i, j]), col = NA))
    }, 
    cluster_rows = TRUE, cluster_columns = FALSE, show_row_names = FALSE)
dev.off()
# Out:
# png
#   2

# %%
### 分析时期基因表达水平， 钙离子调节的细胞外渗
setwd("G:/Billfish/VD_FOV_3Dgenome/RNA_Seq/DEG/ETI_PTI/PTI/TPM/calcium")
library(ComplexHeatmap)
options(repr.plot.width=6,repr.plot.height=6)
df = as.matrix(read.table('calcium_TPM_zscore_normal_01.bed', sep='\t', header=T, row.names = 1))
oxygen_dath = c('Ghir_D03G014390', 'Ghir_A03G004500', 'Ghir_A08G022880','Ghir_D08G023800')
df_need = df[oxygen_dath, ]
#print(df_need)
col_fun = circlize::colorRamp2(c(0, 0.5, 1), c( "#005A5A", "#D2D2D2", "#DD2929"))    
Heatmap(df_need, name = "ratio", rect_gp = gpar(type = "none"), col = col_fun, 
    cell_fun = function(j, i, x, y, width, height, fill) {
        grid.circle(x = x, y = y, r = abs(df_need[i, j])/2 * min(unit.c(width, height)), 
                gp = gpar(fill = col_fun(df_need[i, j]), col = NA))
    }, 
    cluster_rows = TRUE, cluster_columns = FALSE)
# Out:
# plot without title
