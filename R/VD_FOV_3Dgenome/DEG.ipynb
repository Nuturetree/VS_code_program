# %%
### 分析差异表达基因,J668_mock_Fov7
rm(list=ls())
setwd('F:/VD_FOV_3Dgenome/RNA_Seq/DEG/J668_mock_Fov7')
library(DESeq2)
times <- list('1min', '5min', '10min', '30min', '90min', '180min', '12h')
for (t in times){
    sample = paste('J668_mock_Fov7_',t,'_read_pair.bed', sep="")
    out_f = paste('J668_mock_Fov7_',t,'_DEG.bed', sep="")
    countData <- read.table(sample, sep='\t', header=T, row.names=1)

    condition <- factor(c("control", "control", "treat", "treat"))
    colData <- data.frame(row.names=colnames(countData), condition)
    all(rownames(colData)) == colnames(countData)
    dds <- DESeqDataSetFromMatrix(countData, DataFrame(colData), design=~condition)
    #View(dds)
    dds <- DESeq(dds)
    resultsNames(dds)
    res <- results(dds)
    table(res$padj==0)
    mcols(res, use.names=TRUE)
    res <- res[order(res$padj), ]
    res <- subset(res, padj != 0)
    GeneId <- row.names(res)
    logFC <- res$log2FoldChange
    padj <- res$padj
    data <- data.frame(GeneId=GeneId, logFC=logFC, padj=padj)
    data$sig[(data$padj>0.05)|((data$logFC < 1)&(data$logFC> -1))] <- "Not"
    data$sig[data$padj <= 0.05 & data$logFC >= 1] <- "Up"
    data$sig[data$padj <= 0.05 & data$logFC <= -1] <- "Down"
    data_out = subset(data, sig != 'Not')
    write.table(data_out, file=out_f, sep='\t', row.names=F)
}

# %%
### 分析差异表达基因,J668_mock_Fov7
rm(list=ls())
setwd('G:/Billfish/VD_FOV_3Dgenome/RNA_Seq/DEG/J668_mock_Fov7')
library(DESeq2)
times <- list('1min', '5min', '10min', '30min', '90min', '180min', '12h')
for (t in times){
    sample = paste('J668_mock_Fov7_',t,'_read_pair.bed', sep="")
    out_f = paste('J668_mock_Fov7_',t,'_DEG2.bed', sep="")
    countData <- read.table(sample, sep='\t', header=T, row.names=1)

    condition <- factor(c("control", "control", "treat", "treat"))
    colData <- data.frame(row.names=colnames(countData), condition)
    all(rownames(colData)) == colnames(countData)
    dds <- DESeqDataSetFromMatrix(countData, DataFrame(colData), design=~condition)
    #View(dds)
    dds <- DESeq(dds)
    resultsNames(dds)
    res <- results(dds)
    table(res$padj==0)
    mcols(res, use.names=TRUE)
    res <- res[order(res$padj), ]
    #res <- subset(res, padj != 0)
    GeneId <- row.names(res)
    logFC <- res$log2FoldChange
    padj <- res$padj
    data <- data.frame(GeneId=GeneId, logFC=logFC, padj=padj)
    data$sig[(data$padj>0.05)|((data$logFC < 1)&(data$logFC> -1))] <- "Not"
    data$sig[data$padj <= 0.05 & data$logFC >= 1] <- "Up"
    data$sig[data$padj <= 0.05 & data$logFC <= -1] <- "Down"
    #data_out = subset(data, sig != 'Not')
    write.table(data, file=out_f, sep='\t', row.names=F)
}

# %%
### 分析差异表达基因,J668_mock_v991
rm(list=ls())
setwd('F:/VD_FOV_3Dgenome/RNA_Seq/DEG/J668_mock_v991')
library(DESeq2)
times <- list('1min', '5min', '10min', '30min', '90min', '180min', '12h')
for (t in times){
    sample = paste('J668_mock_v991_',t,'_read_pair.bed', sep="")
    out_f = paste('J668_mock_v991_',t,'_DEG.bed', sep="")
    countData <- read.table(sample, sep='\t', header=T, row.names=1)
    condition <- factor(c("control", "control", "treat", "treat"))
    colData <- data.frame(row.names=colnames(countData), condition)
    all(rownames(colData)) == colnames(countData)
    dds <- DESeqDataSetFromMatrix(countData, DataFrame(colData), design=~condition)
    #View(dds)
    dds <- DESeq(dds)
    resultsNames(dds)
    res <- results(dds)
    table(res$padj==0)
    mcols(res, use.names=TRUE)
    res <- res[order(res$padj), ]
    res <- subset(res, padj != 0)
    GeneId <- row.names(res)
    logFC <- res$log2FoldChange
    padj <- res$padj
    data <- data.frame(GeneId=GeneId, logFC=logFC, padj=padj)
    data$sig[(data$padj>0.05)|((data$logFC < 1)&(data$logFC> -1))] <- "Not"
    data$sig[data$padj <= 0.05 & data$logFC >= 1] <- "Up"
    data$sig[data$padj <= 0.05 & data$logFC <= -1] <- "Down"
    data_out = subset(data, sig != 'Not')
    write.table(data_out, file=out_f, sep='\t', row.names=F)
}

# %%
### 分析差异表达基因,J668_mock_v991
rm(list=ls())
setwd('G:/Billfish/VD_FOV_3Dgenome/RNA_Seq/DEG/J668_mock_v991')
library(DESeq2)
times <- list('1min', '5min', '10min', '30min', '90min', '180min', '12h')
for (t in times){
    sample = paste('J668_mock_v991_',t,'_read_pair.bed', sep="")
    out_f = paste('J668_mock_v991_',t,'_DEG2.bed', sep="")
    countData <- read.table(sample, sep='\t', header=T, row.names=1)
    condition <- factor(c("control", "control", "treat", "treat"))
    colData <- data.frame(row.names=colnames(countData), condition)
    all(rownames(colData)) == colnames(countData)
    dds <- DESeqDataSetFromMatrix(countData, DataFrame(colData), design=~condition)
    #View(dds)
    dds <- DESeq(dds)
    resultsNames(dds)
    res <- results(dds)
    table(res$padj==0)
    mcols(res, use.names=TRUE)
    res <- res[order(res$padj), ]
    #res <- subset(res, padj != 0)
    GeneId <- row.names(res)
    logFC <- res$log2FoldChange
    padj <- res$padj
    data <- data.frame(GeneId=GeneId, logFC=logFC, padj=padj)
    data$sig[(data$padj>0.05)|((data$logFC < 1)&(data$logFC> -1))] <- "Not"
    data$sig[data$padj <= 0.05 & data$logFC >= 1] <- "Up"
    data$sig[data$padj <= 0.05 & data$logFC <= -1] <- "Down"
    #data_out = subset(data, sig != 'Not')
    write.table(data, file=out_f, sep='\t', row.names=F)
}

# %%
### 分析差异表达基因,glr_mock_fov7
rm(list=ls())
setwd('F:/VD_FOV_3Dgenome/RNA_Seq/DEG/glr19_mock_Fov7')
library(DESeq2)
times <- list('1min', '5min', '10min', '30min', '90min', '180min', '12h')
for (t in times){
    sample = paste('glr19_mock_Fov7_',t,'_read_pair.bed', sep="")
    out_f = paste('glr19_mock_Fov7_',t,'_DEG.bed', sep="")
    countData <- read.table(sample, sep='\t', header=T, row.names=1)
    condition <- factor(c("control", "control", "treat", "treat"))
    colData <- data.frame(row.names=colnames(countData), condition)
    all(rownames(colData)) == colnames(countData)
    dds <- DESeqDataSetFromMatrix(countData, DataFrame(colData), design=~condition)
    #View(dds)
    dds <- DESeq(dds)
    resultsNames(dds)
    res <- results(dds)
    table(res$padj==0)
    mcols(res, use.names=TRUE)
    res <- res[order(res$padj), ]
    res <- subset(res, padj != 0)
    GeneId <- row.names(res)
    logFC <- res$log2FoldChange
    padj <- res$padj
    data <- data.frame(GeneId=GeneId, logFC=logFC, padj=padj)
    data$sig[(data$padj>0.05)|((data$logFC < 1)&(data$logFC> -1))] <- "Not"
    data$sig[data$padj <= 0.05 & data$logFC >= 1] <- "Up"
    data$sig[data$padj <= 0.05 & data$logFC <= -1] <- "Down"
    data_out = subset(data, sig != 'Not')
    write.table(data_out, file=out_f, sep='\t', row.names=F)
}

# %%
### 分析差异表达基因,J668_mock_v991
rm(list=ls())
setwd('G:/Billfish/VD_FOV_3Dgenome/RNA_Seq/DEG/Glr19_mock_Fov7')
library(DESeq2)
times <- list('1min', '5min', '10min', '30min', '90min', '180min', '12h')
for (t in times){
    sample = paste('glr19_mock_Fov7_',t,'_read_pair.bed', sep="")
    out_f = paste('Glr19_mock_Fov7_',t,'_DEG2.bed', sep="")
    countData <- read.table(sample, sep='\t', header=T, row.names=1)
    condition <- factor(c("control", "control", "treat", "treat"))
    colData <- data.frame(row.names=colnames(countData), condition)
    all(rownames(colData)) == colnames(countData)
    dds <- DESeqDataSetFromMatrix(countData, DataFrame(colData), design=~condition)
    #View(dds)
    dds <- DESeq(dds)
    resultsNames(dds)
    res <- results(dds)
    table(res$padj==0)
    mcols(res, use.names=TRUE)
    res <- res[order(res$padj), ]
    #res <- subset(res, padj != 0)
    GeneId <- row.names(res)
    logFC <- res$log2FoldChange
    padj <- res$padj
    data <- data.frame(GeneId=GeneId, logFC=logFC, padj=padj)
    data$sig[(data$padj>0.05)|((data$logFC < 1)&(data$logFC> -1))] <- "Not"
    data$sig[data$padj <= 0.05 & data$logFC >= 1] <- "Up"
    data$sig[data$padj <= 0.05 & data$logFC <= -1] <- "Down"
    #data_out = subset(data, sig != 'Not')
    write.table(data, file=out_f, sep='\t', row.names=F)
}

# %%
### 分析差异表达基因,J668_mock_v991
rm(list=ls())
setwd('G:/Billfish/VD_FOV_3Dgenome/RNA_Seq/DEG/Glr19_mock_Fov7')
library(DESeq2)
times <- list('1min', '5min', '10min', '30min', '90min', '180min', '12h')
for (t in times){
    sample = paste('glr19_mock_Fov7_',t,'_read_pair.bed', sep="")
    out_f = paste('Glr19_mock_Fov7_',t,'_DEG2.bed', sep="")
    countData <- read.table(sample, sep='\t', header=T, row.names=1)
    condition <- factor(c("control", "control", "treat", "treat"))
    colData <- data.frame(row.names=colnames(countData), condition)
    all(rownames(colData)) == colnames(countData)
    dds <- DESeqDataSetFromMatrix(countData, DataFrame(colData), design=~condition)
    #View(dds)
    dds <- DESeq(dds)
    resultsNames(dds)
    res <- results(dds)
    table(res$padj==0)
    mcols(res, use.names=TRUE)
    res <- res[order(res$padj), ]
    #res <- subset(res, padj != 0)
    GeneId <- row.names(res)
    logFC <- res$log2FoldChange
    padj <- res$padj
    data <- data.frame(GeneId=GeneId, logFC=logFC, padj=padj)
    data$sig[(data$padj>0.05)|((data$logFC < 1)&(data$logFC> -1))] <- "Not"
    data$sig[data$padj <= 0.05 & data$logFC >= 1] <- "Up"
    data$sig[data$padj <= 0.05 & data$logFC <= -1] <- "Down"
    #data_out = subset(data, sig != 'Not')
    write.table(data, file=out_f, sep='\t', row.names=F)
}

# %%
### 分析差异表达基因,J668_Fov7_V991
rm(list=ls())
setwd('G:/Billfish/VD_FOV_3Dgenome/RNA_Seq/DEG/J668_Fov7_V991')
library(DESeq2)
#times <- list('1min', '5min', '10min', '30min', '90min', '180min', '720min')
times <- list('720min')
for (t in times){
    sample = paste('J668_Fov7_V991_',t,'_read_pair.bed', sep="")
    out_f = paste('J668_Fov7_V991_',t,'_DEG2.bed', sep="")
    countData <- read.table(sample, sep='\t', header=T, row.names=1)
    condition <- factor(c("control", "control", "treat", "treat"))
    colData <- data.frame(row.names=colnames(countData), condition)
    all(rownames(colData)) == colnames(countData)
    dds <- DESeqDataSetFromMatrix(countData, DataFrame(colData), design=~condition)
    #View(dds)
    dds <- DESeq(dds)
    resultsNames(dds)
    res <- results(dds)
    table(res$padj==0)
    mcols(res, use.names=TRUE)
    res <- res[order(res$padj), ]
    #res <- subset(res, padj != 0)
    GeneId <- row.names(res)
    logFC <- res$log2FoldChange
    padj <- res$padj
    data <- data.frame(GeneId=GeneId, logFC=logFC, padj=padj)
    data$sig[(data$padj>0.05)|((data$logFC < 1)&(data$logFC> -1))] <- "Not"
    data$sig[data$padj <= 0.05 & data$logFC >= 1] <- "Up"
    data$sig[data$padj <= 0.05 & data$logFC <= -1] <- "Down"
    #data_out = subset(data, sig != 'Not')
    #write.table(data_out, file=out_f, sep='\t', row.names=F)
    write.table(data, file=out_f, sep='\t', row.names=F)

}
# Out:
# Warning message in all(rownames(colData)):
# "coercing argument of type 'character' to logical"
# estimating size factors
#
# estimating dispersions
#
# gene-wise dispersion estimates
#
# mean-dispersion relationship
#
# final dispersion estimates
#
# fitting model and testing

# %%
### 分析差异表达基因,mock_Glr19_J668
rm(list=ls())
setwd('G:/Billfish/VD_FOV_3Dgenome/RNA_Seq/DEG/mock_Glr19_J668')
library(DESeq2)
times <- list('1min', '5min', '10min', '30min', '90min', '180min', '12h')
for (t in times){
    sample = paste('mock_Glr19_J668_',t,'_read_pair.bed', sep="")
    out_f = paste('mock_Glr19_J668_',t,'_DEG.bed', sep="")
    countData <- read.table(sample, sep='\t', header=T, row.names=1)
    condition <- factor(c("control", "control", "treat", "treat"))
    colData <- data.frame(row.names=colnames(countData), condition)
    all(rownames(colData)) == colnames(countData)
    dds <- DESeqDataSetFromMatrix(countData, DataFrame(colData), design=~condition)
    #View(dds)
    dds <- DESeq(dds)
    resultsNames(dds)
    res <- results(dds)
    table(res$padj==0)
    mcols(res, use.names=TRUE)
    res <- res[order(res$padj), ]
    res <- subset(res, padj != 0)
    GeneId <- row.names(res)
    logFC <- res$log2FoldChange
    padj <- res$padj
    data <- data.frame(GeneId=GeneId, logFC=logFC, padj=padj)
    data$sig[(data$padj>0.05)|((data$logFC < 1)&(data$logFC> -1))] <- "Not"
    data$sig[data$padj <= 0.05 & data$logFC >= 1] <- "Up"
    data$sig[data$padj <= 0.05 & data$logFC <= -1] <- "Down"
    data_out = subset(data, sig != 'Not')
    write.table(data_out, file=out_f, sep='\t', row.names=F)
}

# %%
### 分析差异表达基因,Fov7_Glr19_J668
rm(list=ls())
setwd('G:/Billfish/VD_FOV_3Dgenome/RNA_Seq/DEG/Fov7_Glr19_J668')
library(DESeq2)
times <- list('1min', '5min', '10min', '30min', '90min', '180min', '12h')
for (t in times){
    sample = paste('Fov7_Glr19_J668_',t,'_read_pair.bed', sep="")
    out_f = paste('Fov7_Glr19_J668_',t,'_DEG.bed', sep="")
    countData <- read.table(sample, sep='\t', header=T, row.names=1)
    condition <- factor(c("control", "control", "treat", "treat"))
    colData <- data.frame(row.names=colnames(countData), condition)
    all(rownames(colData)) == colnames(countData)
    dds <- DESeqDataSetFromMatrix(countData, DataFrame(colData), design=~condition)
    #View(dds)
    dds <- DESeq(dds)
    resultsNames(dds)
    res <- results(dds)
    table(res$padj==0)
    mcols(res, use.names=TRUE)
    res <- res[order(res$padj), ]
    res <- subset(res, padj != 0)
    GeneId <- row.names(res)
    logFC <- res$log2FoldChange
    padj <- res$padj
    data <- data.frame(GeneId=GeneId, logFC=logFC, padj=padj)
    data$sig[(data$padj>0.05)|((data$logFC < 1)&(data$logFC> -1))] <- "Not"
    data$sig[data$padj <= 0.05 & data$logFC >= 1] <- "Up"
    data$sig[data$padj <= 0.05 & data$logFC <= -1] <- "Down"
    data_out = subset(data, sig != 'Not')
    write.table(data_out, file=out_f, sep='\t', row.names=F)
}
# Out:
# Warning message in all(rownames(colData)):
# "coercing argument of type 'character' to logical"
# estimating size factors
#
# estimating dispersions
#
# gene-wise dispersion estimates
#
# mean-dispersion relationship
#
# final dispersion estimates
#
# fitting model and testing
#
# Warning message in all(rownames(colData)):
# "coercing argument of type 'character' to logical"
# estimating size factors
#
# estimating dispersions
#
# gene-wise dispersion estimates
#
# mean-dispersion relationship
#
# final dispersion estimates
#
# fitting model and testing
#
# Warning message in all(rownames(colData)):
# "coercing argument of type 'character' to logical"
# estimating size factors
#
# estimating dispersions
#
# gene-wise dispersion estimates
#
# mean-dispersion relationship
#
# final dispersion estimates
#
# fitting model and testing
#
# Warning message in all(rownames(colData)):
# "coercing argument of type 'character' to logical"
# estimating size factors
#
# estimating dispersions
#
# gene-wise dispersion estimates
#
# mean-dispersion relationship
#
# final dispersion estimates
#
# fitting model and testing
#
# Warning message in all(rownames(colData)):
# "coercing argument of type 'character' to logical"
# estimating size factors
#
# estimating dispersions
#
# gene-wise dispersion estimates
#
# mean-dispersion relationship
#
# final dispersion estimates
#
# fitting model and testing
#
# Warning message in all(rownames(colData)):
# "coercing argument of type 'character' to logical"
# estimating size factors
#
# estimating dispersions
#
# gene-wise dispersion estimates
#
# mean-dispersion relationship
#
# final dispersion estimates
#
# fitting model and testing
#
# Warning message in file(file, "rt"):
# "cannot open file 'Fov7_Glr19_J668_12h_read_pair.bed': No such file or directory"
# Error in file(file, "rt"): cannot open the connection
# Traceback:
#
# 1. read.table(sample, sep = "\t", header = T, row.names = 1)
# 2. file(file, "rt")

# %%
## 分析差异表达
rm(list=ls())
setwd('G:/Billfish/VD_FOV_3Dgenome/RNA_Seq_new/DEG')
library(DESeq2)
times <- list('1min', '5min', '10min', '30min', '90min', '180min', '720min')
#times <- list('1min')
# one
# C = "J668_mock"
# T = "J668_V991"
# two
# C = "J668_mock"
# T = "J668_Fov7"
# three
# C = "Glr19_mock"
# T = "Glr19_Fov7"
# four
# C = "J668_Fov7"
# T = "Glr19_Fov7"
# # five
C = "J668_Fov7"
T = "J668_V991"

df_reads <- read.table("Jin668_glr48_Fov_V991_reads_wide.bed", sep="\t", header=TRUE, row.names=1)
for (t in times){
    #sample = paste('Fov7_Glr19_J668_',t,'_read_pair.bed', sep="")
    out_f = paste(C,T, t,'_DEG.bed', sep="-")
    c_rep1 = paste(C,t,'rep1', sep="_")
    c_rep2 = paste(C,t,'rep2', sep="_")
    t_rep1 = paste(T,t,'rep1', sep="_")
    t_rep2 = paste(T,t,'rep2', sep="_")
    countData = subset(df_reads, select=c(c_rep1, c_rep2, t_rep1, t_rep2))

    condition <- factor(c("control", "control", "treat", "treat"))
    colnames(countData) <- c("control-1", "control-2", "treat-1", "treat-2")
    #colData <- data.frame(row.names=colnames(countData), condition)
    colData <- data.frame(condition = factor(rep(c('control', 'treat'), each = 2), levels = c('control', 'treat')))
    # print(colData)
    
    # all(rownames(colData)) == colnames(countData)
    # print(rownames(colData))
    # print(colnames(countData))
    dds <- DESeqDataSetFromMatrix(countData, DataFrame(colData), design=~condition)
    #View(dds)
    dds <- DESeq(dds)
    resultsNames(dds)
    res <- results(dds)
    table(res$padj==0)
    mcols(res, use.names=TRUE)
    res <- res[order(res$padj), ]
    res <- subset(res, padj != 0)
    GeneId <- row.names(res)
    logFC <- res$log2FoldChange
    padj <- res$padj
    data <- data.frame(GeneId=GeneId, logFC=logFC, padj=padj)
    data$sig[(data$padj>0.05)|((data$logFC < 1)&(data$logFC> -1))] <- "Not"
    data$sig[data$padj <= 0.05 & data$logFC >= 1] <- "Up"
    data$sig[data$padj <= 0.05 & data$logFC <= -1] <- "Down"
    data_out = subset(data, sig != 'Not')
    write.table(data_out, file=out_f, sep='\t', row.names=F)
}

# %%
# 创建示例DataFrame
df <- data.frame(
  fiber_10DPA = c(1, 2, 3),
  fiber_20DPA = c(4, 5, 6),
  fiber_30DPA = c(7, 8, 9)
)

# 定义要选择的列名
k1 <- paste('fiber', "10DPA", sep='_')
k2 <- paste('fiber', "20DPA", sep='_')

# 使用subset函数选择列名等于k1和k2的列
selected_cols <- subset(df, select = c(k1, k2))
selected_cols
# Out:
#   fiber_10DPA fiber_20DPA
# 1 1           4
# 2 2           5
# 3 3           6

# %%
## 做Go富集分析
#setwd('F:/VD_FOV_3Dgenome/RNA_Seq/DEG/J668_mock_Fov7')
#setwd('F:/VD_FOV_3Dgenome/RNA_Seq/DEG/J668_mock_v991')
setwd('F:/VD_FOV_3Dgenome/RNA_Seq/DEG/glr19_mock_Fov7')
library(clusterProfiler)
library(org.At.tair.db)
times <- list('1min', '5min', '10min', '30min', '90min', '180min', '12h')
for (t in times){
    #input_n <- paste('J668_mock_Fov7_', t, '_DEG_geneid.txt', sep="")
    #output_n <- paste("all_go_term/", 'J668_mock_Fov7_', t, '_DEG_GO.txt', sep="")
    #input_n <- paste('J668_mock_v991_', t, '_DEG_geneid.txt', sep="")
    #output_n <- paste('J668_mock_v991_', t, '_DEG_GO.txt', sep="")
    #output_n <- paste("all_go_term/", 'J668_mock_v991_', t, '_DEG_GO.txt', sep="")    
    input_n <- paste('glr19_mock_Fov7_', t, '_DEG_geneid.txt', sep="")
    #output_n <- paste('glr19_mock_Fov7_', t, '_DEG_GO.txt', sep="")
    output_n <- paste("all_go_term/", 'glr19_mock_Fov7_', t, '_DEG_GO.txt', sep="")
    genes <- read.table(input_n, sep='\t', header=T)
    geneid <- genes$AtId
    #ego = enrichGO(geneid, OrgDb = "org.At.tair.db", keyType="TAIR", ont="BP", pAdjustMethod = "BH", pvalueCutoff  = 0.01, qvalueCutoff  = 0.05, readable= TRUE)
    ego = enrichGO(geneid, OrgDb = "org.At.tair.db", keyType="TAIR", ont = "ALL", pAdjustMethod = "BH", pvalueCutoff  = 0.01, qvalueCutoff  = 0.05, readable= TRUE)
    write.table(summary(ego), output_n, sep='\t', row.names=FALSE)
}

# %%
# ## 将symbol转换为基因id
# library(org.At.tair.db)
# # #! Glr19 mock Fov7
# setwd('F:/VD_FOV_3Dgenome/RNA_Seq/DEG/glr19_mock_Fov7/all_go_term')
# # df <- read.table('glr19_mock_Fov7_DEGid.txt', sep = '\t')
# df <- read.table('glr19_mock_Fov7_reactive oxygen_DEGid.txt', sep = '\t')
# # df_tmp <- select(org.At.tair.db, keys=df$V1 , columns=c("TAIR"), keytype="SYMBOL")
# # write.table(df_tmp, 'glr19_mock_Fov7_DEGid_pairs.txt', sep = '\t', row.names=FALSE)
# write.table(df_tmp, 'glr19_mock_Fov7_reactive oxygen_DEGid_pairs.txt', sep = '\t', row.names=FALSE)

# #! J668 mock v991
# setwd('F:/VD_FOV_3Dgenome/RNA_Seq/DEG/J668_mock_v991/all_go_term')
# #df <- read.table('J668_mock_v991_DEGid.txt', sep = '\t')
# df <- read.table('J668_mock_v991_reactive oxygen_DEGid.txt', sep = '\t')
# df_tmp <- select(org.At.tair.db, keys=df$V1, columns=c("TAIR"), keytype="SYMBOL")
# #write.table(df_tmp, 'J668_mock_v991_DEGid_pairs.txt', sep = '\t', row.names = FALSE)
# write.table(df_tmp, 'J668_mock_v991_reactive oxygen_DEGid_pairs.txt', sep = '\t', row.names = FALSE)

#! J668 mock Fov7
# setwd('F:/VD_FOV_3Dgenome/RNA_Seq/DEG/J668_mock_Fov7/all_go_term')
# df <- read.table('J668_mock_Fov7_DEGid.txt', sep = '\t')
# #df <- read.table('J668_mock_Fov7_reactive oxygen_DEGid.txt', sep = '\t')
# df_tmp <- select(org.At.tair.db, keys=df$V1, columns=c("TAIR"), keytype="SYMBOL")
# write.table(df_tmp, 'J668_mock_Fov7_DEGid_pairs.txt', sep = '\t', row.names = FALSE)
#write.table(df_tmp, 'J668_mock_Fov7_reactive oxygen_DEGid_pairs.txt', sep = '\t', row.names = FALSE)


## 将symbol转换为基因id, 版本2
library(org.At.tair.db)
# #! Glr19 mock Fov7
setwd('G:/VD_FOV_3Dgenome/RNA_Seq/DEG/glr19_mock_Fov7/all_go_term/time_target_gene')
df <- read.table('glr19_mock_Fov7_calcium_Attags.txt', sep = '\t', header = T)
df_tmp <- select(org.At.tair.db, keys=df$value , columns=c("TAIR"), keytype="SYMBOL")
write.table(df_tmp, 'glr19_mock_Fov7_calcium_AtID.txt', sep = '\t', row.names=FALSE)

# #! J668 mock Fov7
setwd('G:/VD_FOV_3Dgenome/RNA_Seq/DEG/J668_mock_Fov7/all_go_term/time_target_gene')
df <- read.table('J668_mock_Fov7_calcium_Attags.txt', sep = '\t', header = T)
df_tmp <- select(org.At.tair.db, keys=df$value , columns=c("TAIR"), keytype="SYMBOL")
write.table(df_tmp, 'J668_mock_Fov7_calcium_AtID.txt', sep = '\t', row.names=FALSE)

#! J668 mock Fov7
setwd('G:/VD_FOV_3Dgenome/RNA_Seq/DEG/J668_mock_v991/all_go_term/time_target_gene')
df <- read.table('J668_mock_v991_calcium_Attags.txt', sep = '\t', header = T)
df_tmp <- select(org.At.tair.db, keys=df$value , columns=c("TAIR"), keytype="SYMBOL")
write.table(df_tmp, 'J668_mock_v991_calcium_AtID.txt', sep = '\t', row.names=FALSE)

# %%
## 将top34的第一类symbol转换为拟南芥基因ID
library(org.At.tair.db)
setwd("G:/VD_FOV_3Dgenome/RNA_Seq/DEG/Go_terms/top34")
## glr_fov7 
df <- read.table('glr_fov7_cliques_one_geneid.txt', sep='\t')
df_tmp <- select(org.At.tair.db, keys=df$V1, columns=c('TAIR'), keytype='SYMBOL')
write.table(df_tmp, "glr19_fov7_symbol_geneid.txt", sep="\t", row.names=FALSE)
## j668_fov7 
df <- read.table('j668_fov7_cliques_one_geneid.txt', sep='\t')
df_tmp <- select(org.At.tair.db, keys=df$V1, columns=c('TAIR'), keytype='SYMBOL')
write.table(df_tmp, "j668_fov7_symbol_geneid.txt", sep="\t", row.names=FALSE)
## j668_v991
df <- read.table('j668_v991_cliques_one_geneid.txt', sep='\t')
df_tmp <- select(org.At.tair.db, keys=df$V1, columns=c('TAIR'), keytype='SYMBOL')
write.table(df_tmp, "j668_v991_symbol_geneid.txt", sep="\t", row.names=FALSE)

# %%
## 分析J668 0min 与其它时间段差异表达基因
rm(list=ls())
setwd('G:/Billfish/VD_FOV_3Dgenome/RNA_Seq/DEG/0min_DEG/J668')
library(DESeq2)
#times <- list('1min', '5min', '10min', '30min', '90min', '180min', '720min')
times <- list('720min')
for (t in times){
    sample = paste(t, '/', 'J668_0min_', t ,'_mock_read_pair.bed', sep="")
    out_f = paste(t, '/', 'J668_0min_', t ,'_mock_DEG.bed', sep="")
    countData <- read.table(sample, sep='\t', header=T, row.names=1)
    condition <- factor(c("control", "control", "treat", "treat"))
    colData <- data.frame(row.names=colnames(countData), condition)
    all(rownames(colData)) == colnames(countData)
    dds <- DESeqDataSetFromMatrix(countData, DataFrame(colData), design=~condition)
    #View(dds)
    dds <- DESeq(dds)
    resultsNames(dds)
    res <- results(dds)
    table(res$padj==0)
    mcols(res, use.names=TRUE)
    res <- res[order(res$padj), ]
    res <- subset(res, padj != 0)
    GeneId <- row.names(res)
    logFC <- res$log2FoldChange
    padj <- res$padj
    data <- data.frame(GeneId=GeneId, logFC=logFC, padj=padj)
    data$sig[(data$padj>0.05)|((data$logFC < 1)&(data$logFC> -1))] <- "Not"
    data$sig[data$padj <= 0.05 & data$logFC >= 1] <- "Up"
    data$sig[data$padj <= 0.05 & data$logFC <= -1] <- "Down"
    data_out = subset(data, sig != 'Not')
    write.table(data_out, file=out_f, sep='\t', row.names=F)
}

# %%
## 分析Glr19 0min 与其它时间段差异表达基因
rm(list=ls())
setwd('G:/Billfish/VD_FOV_3Dgenome/RNA_Seq/DEG/0min_DEG/Glr19')
library(DESeq2)
times <- list('1min', '5min', '10min', '30min', '90min', '180min', '720min')
for (t in times){
    sample = paste(t, '/', 'Glr19_0min_', t ,'_mock_read_pair.bed', sep="")
    out_f = paste(t, '/', 'Glr19_0min_', t ,'_mock_DEG.bed', sep="")
    countData <- read.table(sample, sep='\t', header=T, row.names=1)
    condition <- factor(c("control", "control", "treat", "treat"))
    colData <- data.frame(row.names=colnames(countData), condition)
    all(rownames(colData)) == colnames(countData)
    dds <- DESeqDataSetFromMatrix(countData, DataFrame(colData), design=~condition)
    #View(dds)
    dds <- DESeq(dds)
    resultsNames(dds)
    res <- results(dds)
    table(res$padj==0)
    mcols(res, use.names=TRUE)
    res <- res[order(res$padj), ]
    res <- subset(res, padj != 0)
    GeneId <- row.names(res)
    logFC <- res$log2FoldChange
    padj <- res$padj
    data <- data.frame(GeneId=GeneId, logFC=logFC, padj=padj)
    data$sig[(data$padj>0.05)|((data$logFC < 1)&(data$logFC> -1))] <- "Not"
    data$sig[data$padj <= 0.05 & data$logFC >= 1] <- "Up"
    data$sig[data$padj <= 0.05 & data$logFC <= -1] <- "Down"
    data_out = subset(data, sig != 'Not')
    write.table(data_out, file=out_f, sep='\t', row.names=F)
}
