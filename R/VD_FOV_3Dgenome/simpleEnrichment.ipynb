# %%
## glr19_mock_fov7, 1min, 5min, 10min, 30min, 90min, 180min, 12h
setwd("G:/Billfish/VD_FOV_3Dgenome/RNA_Seq/DEG/glr19_mock_Fov7/all_go_term")
rm(list=ls())
library(simplifyEnrichment)
library(cola)
#! read data
df_1min <- read.table('glr19_mock_Fov7_1min_DEG_GO.txt', sep='\t', header=T)
df_5min <- read.table('glr19_mock_Fov7_5min_DEG_GO.txt', sep='\t', header=T)
df_10min <- read.table('glr19_mock_Fov7_10min_DEG_GO.txt', sep='\t', header=T)
df_30min <- read.table('glr19_mock_Fov7_30min_DEG_GO.txt', sep='\t', header=T)
df_90min <- read.table('glr19_mock_Fov7_90min_DEG_GO.txt', sep='\t', header=T)
df_180min <- read.table('glr19_mock_Fov7_180min_DEG_GO.txt', sep='\t', header=T)
df_12h <- read.table('glr19_mock_Fov7_12h_DEG_GO.txt', sep='\t', header=T)

#! choose data
df_1min_BP <- df_1min[df_1min$ONTOLOGY=="BP",]
df_5min_BP <- df_5min[df_5min$ONTOLOGY=="BP",]
df_10min_BP <- df_10min[df_10min$ONTOLOGY=="BP",]
df_30min_BP <- df_30min[df_30min$ONTOLOGY=="BP",]
df_90min_BP <- df_90min[df_90min$ONTOLOGY=="BP",]
df_180min_BP <- df_180min[df_180min$ONTOLOGY=="BP",]
df_12h_BP <- df_12h[df_12h$ONTOLOGY=="BP",]

#! concat data
#! no 12h
# all_data <- list(df_1min_BP, df_5min_BP, df_10min_BP, df_30min_BP, df_90min_BP, df_180min_BP)
# names(all_data) <- c('1min', '5min', '10min', '30min', '90min', '180min')
# pdf("glr19_mock_fov7_all_Go_term.pdf", width=10, height=7)
# simplifyGOFromMultipleLists(all_data)
# dev.off()

#! contain 12h
all_data <- list(df_1min_BP, df_5min_BP, df_10min_BP, df_30min_BP, df_90min_BP, df_180min_BP, df_12h_BP)
names(all_data) <- c('1min', '5min', '10min', '30min', '90min', '180min', '12h')
pdf("glr19_mock_fov7_all_Go_term_12h.pdf", width=10, height=7)
simplifyGOFromMultipleLists(all_data)
dev.off()

# %%
## J668_mock_fov7, 1min, 5min, 10min, 30min, 90min, 180min, 12h
setwd("G:/VD_FOV_3Dgenome/RNA_Seq/DEG/J668_mock_Fov7/all_go_term")
rm(list=ls())
library(simplifyEnrichment)
library(cola)
#! read data
df_1min <- read.table('J668_mock_Fov7_1min_DEG_GO.txt', sep='\t', header=T)
df_5min <- read.table('J668_mock_Fov7_5min_DEG_GO.txt', sep='\t', header=T)
df_10min <- read.table('J668_mock_Fov7_10min_DEG_GO.txt', sep='\t', header=T)
df_30min <- read.table('J668_mock_Fov7_30min_DEG_GO.txt', sep='\t', header=T)
df_90min <- read.table('J668_mock_Fov7_90min_DEG_GO.txt', sep='\t', header=T)
df_180min <- read.table('J668_mock_Fov7_180min_DEG_GO.txt', sep='\t', header=T)
df_12h <- read.table('J668_mock_Fov7_12h_DEG_GO.txt', sep='\t', header=T)

#! choose data
df_1min_BP <- df_1min[df_1min$ONTOLOGY=="BP",]
df_5min_BP <- df_5min[df_5min$ONTOLOGY=="BP",]
df_10min_BP <- df_10min[df_10min$ONTOLOGY=="BP",]
df_30min_BP <- df_30min[df_30min$ONTOLOGY=="BP",]
df_90min_BP <- df_90min[df_90min$ONTOLOGY=="BP",]
df_180min_BP <- df_180min[df_180min$ONTOLOGY=="BP",]
df_12h_BP <- df_12h[df_12h$ONTOLOGY=="BP",]

#! concat data
#! no contain 12h
# all_data <- list(df_1min_BP, df_5min_BP, df_10min_BP, df_30min_BP, df_90min_BP, df_180min_BP)
# names(all_data) <- c('1min', '5min', '10min', '30min', '90min', '180min')
# pdf("J668_mock_fov7_all_Go_term.pdf", width=10, height=7)
# simplifyGOFromMultipleLists(all_data)
# dev.off()

#! contain 12h
all_data <- list(df_1min_BP, df_5min_BP, df_10min_BP, df_30min_BP, df_90min_BP, df_180min_BP, df_12h_BP)
names(all_data) <- c('1min', '5min', '10min', '30min', '90min', '180min', '12h')
pdf("J668_mock_fov7_all_Go_term_12h.pdf", width=10, height=7)
simplifyGOFromMultipleLists(all_data)
dev.off()
# Out:
# Use column 'ID' as `go_id_column`.
# Use column 'p.adjust' as `padj_column`.
# 436/436 GO IDs left for clustering.
# 'magick' package is suggested to install to give better rasterization.
#
# Set `ht_opt$message = FALSE` to turn off this message.
#
# You haven't provided value for `ont`, guess it as `BP`.
# Cluster 436 terms by 'binary_cut'... 131 clusters, used 0.8071051 secs.
# 'magick' package is suggested to install to give better rasterization.
#
# Set `ht_opt$message = FALSE` to turn off this message.
# png
#   2

# %%
## J668_mock_fov7, 1min, 5min, 10min, 30min, 90min, 180min, 12h
setwd("G:/VD_FOV_3Dgenome/RNA_Seq/DEG/J668_mock_v991/all_go_term")
rm(list=ls())
library(simplifyEnrichment)
library(cola)
#! read data
df_1min <- read.table('J668_mock_v991_1min_DEG_GO.txt', sep='\t', header=T)
df_5min <- read.table('J668_mock_v991_5min_DEG_GO.txt', sep='\t', header=T)
df_10min <- read.table('J668_mock_v991_10min_DEG_GO.txt', sep='\t', header=T)
df_30min <- read.table('J668_mock_v991_30min_DEG_GO.txt', sep='\t', header=T)
df_90min <- read.table('J668_mock_v991_90min_DEG_GO.txt', sep='\t', header=T)
df_180min <- read.table('J668_mock_v991_180min_DEG_GO.txt', sep='\t', header=T)
df_12h <- read.table('J668_mock_v991_12h_DEG_GO.txt', sep='\t', header=T)

#! choose data
df_1min_BP <- df_1min[df_1min$ONTOLOGY=="BP",]
df_5min_BP <- df_5min[df_5min$ONTOLOGY=="BP",]
df_10min_BP <- df_10min[df_10min$ONTOLOGY=="BP",]
df_30min_BP <- df_30min[df_30min$ONTOLOGY=="BP",]
df_90min_BP <- df_90min[df_90min$ONTOLOGY=="BP",]
df_180min_BP <- df_180min[df_180min$ONTOLOGY=="BP",]
df_12h_BP <- df_12h[df_12h$ONTOLOGY=="BP",]

#! concat data
#! no contain 12h
# all_data <- list(df_1min_BP, df_5min_BP, df_10min_BP, df_30min_BP, df_90min_BP, df_180min_BP)
# names(all_data) <- c('1min', '5min', '10min', '30min', '90min', '180min')
# pdf("J668_mock_v991_all_Go_term.pdf", width=10, height=7)
# simplifyGOFromMultipleLists(all_data)
# dev.off()

#! contain 12h
all_data <- list(df_1min_BP, df_5min_BP, df_10min_BP, df_30min_BP, df_90min_BP, df_180min_BP, df_12h_BP)
names(all_data) <- c('1min', '5min', '10min', '30min', '90min', '180min', '12h')
pdf("J668_mock_v991_all_Go_term_12h.pdf", width=10, height=7)
simplifyGOFromMultipleLists(all_data)
dev.off()
# Out:
# Use column 'ID' as `go_id_column`.
# Use column 'p.adjust' as `padj_column`.
# 391/391 GO IDs left for clustering.
# 'magick' package is suggested to install to give better rasterization.
#
# Set `ht_opt$message = FALSE` to turn off this message.
#
# You haven't provided value for `ont`, guess it as `BP`.
# Cluster 391 terms by 'binary_cut'... 155 clusters, used 0.970232 secs.
# 'magick' package is suggested to install to give better rasterization.
#
# Set `ht_opt$message = FALSE` to turn off this message.
# png
#   2

# %%
### 对三个比较的所有Go term做相关性分析
setwd("G:/VD_FOV_3Dgenome/RNA_Seq/DEG/Go_terms/all")
rm(list=ls())
library(simplifyEnrichment)
library(cola)
#! read data
#! glr_fov7
df_glr_fov7_1min <- read.table('G:/VD_FOV_3Dgenome/RNA_Seq/DEG/glr19_mock_Fov7/all_go_term/glr19_mock_Fov7_1min_DEG_GO.txt', sep='\t', header=T)
df_glr_fov7_5min <- read.table('G:/VD_FOV_3Dgenome/RNA_Seq/DEG/glr19_mock_Fov7/all_go_term/glr19_mock_Fov7_5min_DEG_GO.txt', sep='\t', header=T)
df_glr_fov7_10min <- read.table('G:/VD_FOV_3Dgenome/RNA_Seq/DEG/glr19_mock_Fov7/all_go_term/glr19_mock_Fov7_10min_DEG_GO.txt', sep='\t', header=T)
df_glr_fov7_30min <- read.table('G:/VD_FOV_3Dgenome/RNA_Seq/DEG/glr19_mock_Fov7/all_go_term/glr19_mock_Fov7_30min_DEG_GO.txt', sep='\t', header=T)
df_glr_fov7_90min <- read.table('G:/VD_FOV_3Dgenome/RNA_Seq/DEG/glr19_mock_Fov7/all_go_term/glr19_mock_Fov7_90min_DEG_GO.txt', sep='\t', header=T)
df_glr_fov7_180min <- read.table('G:/VD_FOV_3Dgenome/RNA_Seq/DEG/glr19_mock_Fov7/all_go_term/glr19_mock_Fov7_180min_DEG_GO.txt', sep='\t', header=T)
df_glr_fov7_12h <- read.table('G:/VD_FOV_3Dgenome/RNA_Seq/DEG/glr19_mock_Fov7/all_go_term/glr19_mock_Fov7_12h_DEG_GO.txt', sep='\t', header=T)
#! j668_fov7
df_j668_fov7_1min <- read.table('G:/VD_FOV_3Dgenome/RNA_Seq/DEG/J668_mock_Fov7/all_go_term/J668_mock_Fov7_1min_DEG_GO.txt', sep='\t', header=T)
df_j668_fov7_5min <- read.table('G:/VD_FOV_3Dgenome/RNA_Seq/DEG/J668_mock_Fov7/all_go_term/J668_mock_Fov7_5min_DEG_GO.txt', sep='\t', header=T)
df_j668_fov7_10min <- read.table('G:/VD_FOV_3Dgenome/RNA_Seq/DEG/J668_mock_Fov7/all_go_term/J668_mock_Fov7_10min_DEG_GO.txt', sep='\t', header=T)
df_j668_fov7_30min <- read.table('G:/VD_FOV_3Dgenome/RNA_Seq/DEG/J668_mock_Fov7/all_go_term/J668_mock_Fov7_30min_DEG_GO.txt', sep='\t', header=T)
df_j668_fov7_90min <- read.table('G:/VD_FOV_3Dgenome/RNA_Seq/DEG/J668_mock_Fov7/all_go_term/J668_mock_Fov7_90min_DEG_GO.txt', sep='\t', header=T)
df_j668_fov7_180min <- read.table('G:/VD_FOV_3Dgenome/RNA_Seq/DEG/J668_mock_Fov7/all_go_term/J668_mock_Fov7_180min_DEG_GO.txt', sep='\t', header=T)
df_j668_fov7_12h <- read.table('G:/VD_FOV_3Dgenome/RNA_Seq/DEG/J668_mock_Fov7/all_go_term/J668_mock_Fov7_12h_DEG_GO.txt', sep='\t', header=T)
#! j668_v991
df_j668_v991_1min <- read.table('G:/VD_FOV_3Dgenome/RNA_Seq/DEG/J668_mock_v991/all_go_term/J668_mock_v991_1min_DEG_GO.txt', sep='\t', header=T)
df_j668_v991_5min <- read.table('G:/VD_FOV_3Dgenome/RNA_Seq/DEG/J668_mock_v991/all_go_term/J668_mock_v991_5min_DEG_GO.txt', sep='\t', header=T)
df_j668_v991_10min <- read.table('G:/VD_FOV_3Dgenome/RNA_Seq/DEG/J668_mock_v991/all_go_term/J668_mock_v991_10min_DEG_GO.txt', sep='\t', header=T)
df_j668_v991_30min <- read.table('G:/VD_FOV_3Dgenome/RNA_Seq/DEG/J668_mock_v991/all_go_term/J668_mock_v991_30min_DEG_GO.txt', sep='\t', header=T)
df_j668_v991_90min <- read.table('G:/VD_FOV_3Dgenome/RNA_Seq/DEG/J668_mock_v991/all_go_term/J668_mock_v991_90min_DEG_GO.txt', sep='\t', header=T)
df_j668_v991_180min <- read.table('G:/VD_FOV_3Dgenome/RNA_Seq/DEG/J668_mock_v991/all_go_term/J668_mock_v991_180min_DEG_GO.txt', sep='\t', header=T)
df_j668_v991_12h <- read.table('G:/VD_FOV_3Dgenome/RNA_Seq/DEG/J668_mock_v991/all_go_term/J668_mock_v991_12h_DEG_GO.txt', sep='\t', header=T)

# #! choose data one
# df_glr_fov7_1min <- df_glr_fov7_1min[df_glr_fov7_1min$ONTOLOGY=="BP",]
# df_glr_fov7_5min <- df_glr_fov7_5min[df_glr_fov7_5min$ONTOLOGY=="BP",]
# df_glr_fov7_10min <- df_glr_fov7_10min[df_glr_fov7_10min$ONTOLOGY=="BP",]
# df_glr_fov7_30min <- df_glr_fov7_30min[df_glr_fov7_30min$ONTOLOGY=="BP",]
# df_glr_fov7_90min <- df_glr_fov7_90min[df_glr_fov7_90min$ONTOLOGY=="BP",]
# df_glr_fov7_180min <- df_glr_fov7_180min[df_glr_fov7_180min$ONTOLOGY=="BP",]
# df_glr_fov7_12h <- df_glr_fov7_12h[df_glr_fov7_12h$ONTOLOGY=="BP",]
# df_j668_fov7_1min <- df_j668_fov7_1min[df_j668_fov7_1min$ONTOLOGY=="BP",]
# df_j668_fov7_5min <- df_j668_fov7_5min[df_j668_fov7_5min$ONTOLOGY=="BP",]
# df_j668_fov7_10min <- df_j668_fov7_10min[df_j668_fov7_10min$ONTOLOGY=="BP",]
# df_j668_fov7_30min <- df_j668_fov7_30min[df_j668_fov7_30min$ONTOLOGY=="BP",]
# df_j668_fov7_90min <- df_j668_fov7_90min[df_j668_fov7_90min$ONTOLOGY=="BP",]
# df_j668_fov7_180min <- df_j668_fov7_180min[df_j668_fov7_180min$ONTOLOGY=="BP",]
# df_j668_fov7_12h <- df_j668_fov7_12h[df_j668_fov7_12h$ONTOLOGY=="BP",]
# df_j668_v991_1min <- df_j668_v991_1min[df_j668_v991_1min$ONTOLOGY=="BP",]
# df_j668_v991_5min <- df_j668_v991_5min[df_j668_v991_5min$ONTOLOGY=="BP",]
# df_j668_v991_10min <- df_j668_v991_10min[df_j668_v991_10min$ONTOLOGY=="BP",]
# df_j668_v991_30min <- df_j668_v991_30min[df_j668_v991_30min$ONTOLOGY=="BP",]
# df_j668_v991_90min <- df_j668_v991_90min[df_j668_v991_90min$ONTOLOGY=="BP",]
# df_j668_v991_180min <- df_j668_v991_180min[df_j668_v991_180min$ONTOLOGY=="BP",]
# df_j668_v991_12h <- df_j668_v991_12h[df_j668_v991_12h$ONTOLOGY=="BP",]

#! choose data two
df_glr_fov7_1min <- df_glr_fov7_1min[df_glr_fov7_1min$ONTOLOGY=="BP" ,][1:34, ]
df_glr_fov7_5min <- df_glr_fov7_5min[df_glr_fov7_5min$ONTOLOGY=="BP",][1:34, ]
df_glr_fov7_10min <- df_glr_fov7_10min[df_glr_fov7_10min$ONTOLOGY=="BP",][1:34, ]
df_glr_fov7_30min <- df_glr_fov7_30min[df_glr_fov7_30min$ONTOLOGY=="BP",][1:34, ]
df_glr_fov7_90min <- df_glr_fov7_90min[df_glr_fov7_90min$ONTOLOGY=="BP",][1:34, ]
df_glr_fov7_180min <- df_glr_fov7_180min[df_glr_fov7_180min$ONTOLOGY=="BP",][1:34, ]
df_glr_fov7_12h <- df_glr_fov7_12h[df_glr_fov7_12h$ONTOLOGY=="BP",][1:34, ]
df_j668_fov7_1min <- df_j668_fov7_1min[df_j668_fov7_1min$ONTOLOGY=="BP",][1:34, ]
df_j668_fov7_5min <- df_j668_fov7_5min[df_j668_fov7_5min$ONTOLOGY=="BP",][1:34, ]
df_j668_fov7_10min <- df_j668_fov7_10min[df_j668_fov7_10min$ONTOLOGY=="BP",][1:34, ]
df_j668_fov7_30min <- df_j668_fov7_30min[df_j668_fov7_30min$ONTOLOGY=="BP",][1:34, ]
df_j668_fov7_90min <- df_j668_fov7_90min[df_j668_fov7_90min$ONTOLOGY=="BP",][1:34, ]
df_j668_fov7_180min <- df_j668_fov7_180min[df_j668_fov7_180min$ONTOLOGY=="BP",][1:34, ]
df_j668_fov7_12h <- df_j668_fov7_12h[df_j668_fov7_12h$ONTOLOGY=="BP",][1:34, ]
df_j668_v991_1min <- df_j668_v991_1min[df_j668_v991_1min$ONTOLOGY=="BP",][1:34, ]
df_j668_v991_5min <- df_j668_v991_5min[df_j668_v991_5min$ONTOLOGY=="BP",][1:34, ]
df_j668_v991_10min <- df_j668_v991_10min[df_j668_v991_10min$ONTOLOGY=="BP",][1:34, ]
df_j668_v991_30min <- df_j668_v991_30min[df_j668_v991_30min$ONTOLOGY=="BP",][1:34, ]
df_j668_v991_90min <- df_j668_v991_90min[df_j668_v991_90min$ONTOLOGY=="BP",][1:34, ]
df_j668_v991_180min <- df_j668_v991_180min[df_j668_v991_180min$ONTOLOGY=="BP",][1:34, ]
df_j668_v991_12h <- df_j668_v991_12h[df_j668_v991_12h$ONTOLOGY=="BP",][1:34, ]


# #! contact data
all_data <- list(df_j668_v991_1min, df_j668_v991_5min, df_j668_v991_10min, df_j668_v991_30min, df_j668_v991_90min, df_j668_v991_180min, df_j668_v991_12h, 
                 df_j668_fov7_1min, df_j668_fov7_5min, df_j668_fov7_10min, df_j668_fov7_30min, df_j668_fov7_90min, df_j668_fov7_180min, df_j668_fov7_12h,
                 df_glr_fov7_1min, df_glr_fov7_5min, df_glr_fov7_10min, df_glr_fov7_30min, df_glr_fov7_90min, df_glr_fov7_180min, df_glr_fov7_12h)
names(all_data) <- c('J668_v991_1min', 'J668_v991_5min', 'J668_v991_10min', 'J668_v991_30min', 'J668_v991_90min', 'J668_v991_180min', 'J668_v991_12h', 
                     'J668_fov7_1min', 'J668_fov7_5min', 'J668_fov7_10min', 'J668_fov7_30min', 'J668_fov7_90min', 'J668_fov7_180min', 'J668_fov7_12h',
                     'glr19_fov7_1min', 'glr19_fov7_5min', 'glr19_fov7_10min', 'glr19_fov7_30min', 'glr19_fov7_90min', 'glr19_fov7_180min', 'glr19_fov7_12h')
pdf("G:/VD_FOV_3Dgenome/RNA_Seq/DEG/Go_terms/top34/all_Go_terms_top34.pdf", width=13, height=7)
simplifyGOFromMultipleLists(all_data)
dev.off()
# Out:
# 载入需要的程辑包：BiocGenerics
#
# 载入需要的程辑包：parallel
#
#
# 载入程辑包：'BiocGenerics'
#
#
# The following objects are masked from 'package:parallel':
#
#     clusterApply, clusterApplyLB, clusterCall, clusterEvalQ,
#     clusterExport, clusterMap, parApply, parCapply, parLapply,
#     parLapplyLB, parRapply, parSapply, parSapplyLB
#
#
# The following objects are masked from 'package:stats':
#
#     IQR, mad, sd, var, xtabs
#
#
# The following objects are masked from 'package:base':
#
#     anyDuplicated, append, as.data.frame, basename, cbind, colnames,
#     dirname, do.call, duplicated, eval, evalq, Filter, Find, get, grep,
#     grepl, intersect, is.unsorted, lapply, Map, mapply, match, mget,
#     order, paste, pmax, pmax.int, pmin, pmin.int, Position, rank,
#     rbind, Reduce, rownames, sapply, setdiff, sort, table, tapply,
#     union, unique, unsplit, which.max, which.min
#
#
# 载入需要的程辑包：grid
#
#
#
#
#
# ...
# simplifyEnrichment version 1.4.0
# ...

# %%
## choose cliques one \
df_cliques_one <- simplifyGOFromM
ultipleLists(all_data)
df_cliques_one <- df_cliques_one[df_cliques_one$cluster==1,]
# Out:
# Use column 'ID' as `go_id_column`.
# Use column 'p.adjust' as `padj_column`.
# 154/154 GO IDs left for clustering.
# 'magick' package is suggested to install to give better rasterization.
#
# Set `ht_opt$message = FALSE` to turn off this message.
#
# You haven't provided value for `ont`, guess it as `BP`.
# Cluster 154 terms by 'binary_cut'... 75 clusters, used 0.2020791 secs.
# 'magick' package is suggested to install to give better rasterization.
#
# Set `ht_opt$message = FALSE` to turn off this message.
# plot without title

# %%
one_cliques_GO <- df_cliques_one$id
df_cliques_all_infomation <- all_data$J668_v991_1min[which(all_data$J668_v991_1min$ID %in% one_cliques_GO), ]
df_cliques_all_infomation

# %%
one_cliques_GO
# Out:
#  [1] "GO:0001666" "GO:0036293" "GO:0070482" "GO:0071456" "GO:0036294"
#  [6] "GO:0071453" "GO:0009611" "GO:0001101" "GO:0006979" "GO:0009651"
# [11] "GO:0042742" "GO:0070542" "GO:0009753" "GO:0009620" "GO:0009415"
# [16] "GO:0009414" "GO:0009751" "GO:0014070" "GO:0071398" "GO:0031668"
# [21] "GO:0071496" "GO:0009991" "GO:0042594" "GO:0031669" "GO:0009267"
# [26] "GO:0031667" "GO:0050832" "GO:0031347" "GO:0050776" "GO:0080134"
# [31] "GO:0071395" "GO:0032101" "GO:0071396" "GO:0009636" "GO:0009409"
# [36] "GO:0010038" "GO:0097237" "GO:0009744" "GO:0034285" "GO:0098754"
# [41] "GO:0048585" "GO:0009966" "GO:0016036"

# %%
library(simplifyEnrichment)
df_cliques = simplifyGOFromMultipleLists(all_data)
df_cliques_id = df_cliques$id
options(repr.plot.width=10, repr.plot.height=10)
set.seed(888)
mat = GO_similarity(df_cliques_id)
compare_clustering_methods(mat, plot_type = "heatmap")
# Out:
# Use column 'ID' as `go_id_column`.
# Use column 'p.adjust' as `padj_column`.
# 154/154 GO IDs left for clustering.
# 'magick' package is suggested to install to give better rasterization.
#
# Set `ht_opt$message = FALSE` to turn off this message.
#
# You haven't provided value for `ont`, guess it as `BP`.
# Cluster 154 terms by 'binary_cut'... 75 clusters, used 0.2329352 secs.
# 'magick' package is suggested to install to give better rasterization.
#
# Set `ht_opt$message = FALSE` to turn off this message.
#
# You haven't provided value for `ont`, guess it as `BP`.
# Cluster 154 terms by 'binary_cut'... 66 clusters, used 0.2961781 secs.
# Cluster 154 terms by 'kmeans'... 12 clusters, used 0.06347108 secs.
# Cluster 154 terms by 'dynamicTreeCut'...
# Error in cluster_terms(mat, me, verbose = verbose) :
#   Error : You need to manually install package 'dynamicTreeCut' from CRAN.
#
# Cluster 154 terms by 'apcluster'...
# Error in cluster_terms(mat, me, verbose = verbose) :
# ...

# %%
### 统计第一类所包含的Go terms
df_cliques_one <- simplifyGOFromMultipleLists(all_data)
df_cliques_one <- df_cliques_one[df_cliques_one$cluster==1,]
one_cliques_GO <- df_cliques_one$id
write.table( one_cliques_GO,"G:/VD_FOV_3Dgenome/RNA_Seq/DEG/Go_terms/top34/one_clues_Go_term.txt",sep='\t',row.names=FALSE, col.names=FALSE)
# Out:
# Use column 'ID' as `go_id_column`.
# Use column 'p.adjust' as `padj_column`.
# 154/154 GO IDs left for clustering.
# 'magick' package is suggested to install to give better rasterization.
#
# Set `ht_opt$message = FALSE` to turn off this message.
#
# You haven't provided value for `ont`, guess it as `BP`.
# Cluster 154 terms by 'binary_cut'... 75 clusters, used 0.1968091 secs.
# 'magick' package is suggested to install to give better rasterization.
#
# Set `ht_opt$message = FALSE` to turn off this message.
# plot without title

# %%
## 尝试Go term 进行聚类分析
setwd("G:/Billfish/VD_FOV_3Dgenome/RNA_Seq/DEG/DEG_type/J668_Fov7_V991/clusterprofiler")
rm(list=ls())
library(simplifyEnrichment)
library(cola)
df_20DPA = read.table("BF_uniq_1min_GO.bed", sep='\t', header=T)
#df_stigma = read.table("stigma_Go.txt", sep='\t', header=T)#
df_20DPA_BP = df_20DPA[df_20DPA$ONTOLOGY=='BP', ]
#df_BP = df[df$ONTOLOGY=="BP",]
all_data <- list(df_20DPA_BP$ID)
#print(all_data)
names(all_data) <- c("BF_uniq_1min")
#all_data
mat = GO_similarity(all_data$BF_uniq_1min, measure="Lin")

# pdf("BF_uniq_1min_GO.pdf", width=10, height=7)
# simplifyGO(mat,exclude_words=c('process'), method='MCL')
# dev.off()
df = simplifyGO(mat,exclude_words=c('process'), method='MCL')
# Out:
# You haven't provided value for `ont`, guess it as `BP`.
#
# Cluster 224 terms by 'MCL'...
#  81 clusters, used 0.3024299 secs.
#
# Perform keywords enrichment for 7 GO lists...
# plot without title

# %%
write.table(df, "BF_uniq_1min_GO_cluster.bed", sep="\t", row.names=F)

# %%
write.csv(mat,"BF_uniq_1min_GO_similar.bed" )

# %%
## 尝试Go term 进行聚类分析 
setwd("G:/Billfish/VD_FOV_3Dgenome/RNA_Seq/DEG/DEG_type/J668_Fov7_V991/clusterprofiler/001_005")
rm(list=ls())
library(simplifyEnrichment)
library(cola)
df_20DPA = read.table("BF_uniq_1min_GO.bed", sep='\t', header=T)
#names(df_20DPA) = c('ID', 'ONTOLOGY', 'Description', 'input_gene_number', 'all_gene_number', 'pvalue', 'geneid', 'FDR')
df_20DPA_BP = df_20DPA[df_20DPA$ONTOLOGY=='BP', ]
all_data <- list(df_20DPA_BP$ID)
names(all_data) <- c("BF_uniq_1min")
mat = GO_similarity(all_data$BF_uniq_1min, measure="Lin")
#compare_clustering_methods(mat, plot_type = "heatmap")
pdf("BF_uniq_1min_GO.pdf", width=10, height=7)
simplifyGO(mat,exclude_words=c('process'), method='kmeans', order_by_size=TRUE)
dev.off()
df = simplifyGO(mat,exclude_words=c('process'), method='kmeans', order_by_size=TRUE)
write.table(df, "BF_uniq_1min_GO_cluster.bed", sep="\t", row.names=F)
write.csv(mat,"BF_uniq_1min_GO_similar.bed" )
# Out:
# You haven't provided value for `ont`, guess it as `BP`.
#
# Cluster 90 terms by 'kmeans'...
#  9 clusters, used 0.0149138 secs.
#
# Perform keywords enrichment for 9 GO lists...
# png
#   2
# Cluster 90 terms by 'kmeans'...
#  8 clusters, used 0.01466298 secs.
#
# Perform keywords enrichment for 8 GO lists...
# plot without title

# %%
## 尝试Go term 进行聚类分析  BF 1 min
setwd("G:/Billfish/VD_FOV_3Dgenome/RNA_Seq/DEG/DEG_type/J668_Fov7_V991/Go_terms/BF_1min")
rm(list=ls())
library(simplifyEnrichment)
library(cola)
df_20DPA = read.table("J668_Fov7_V991_1min_BF_uniq_Go.bed", sep='\t', header=F)
names(df_20DPA) = c('ID', 'ONTOLOGY', 'Description', 'input_gene_number', 'all_gene_number', 'pvalue', 'geneid', 'FDR')
df_20DPA_BP = df_20DPA[df_20DPA$ONTOLOGY=='biological_process', ]
all_data <- list(df_20DPA_BP$ID)
names(all_data) <- c("BF_uniq_1min")
mat = GO_similarity(all_data$BF_uniq_1min, measure="Lin")
#compare_clustering_methods(mat, plot_type = "heatmap")
pdf("BF_uniq_1min_GO.pdf", width=10, height=7)
simplifyGO(mat,exclude_words=c('process'), method='MCL', order_by_size=TRUE)
dev.off()
df = simplifyGO(mat,exclude_words=c('process'), method='MCL')
write.table(df, "BF_uniq_1min_GO_cluster.bed", sep="\t", row.names=F)
write.csv(mat,"BF_uniq_1min_GO_similar.bed" )

# %%
## 尝试Go term 进行聚类分析 Up_Up 5 min
setwd("G:/Billfish/VD_FOV_3Dgenome/RNA_Seq/DEG/DEG_type/J668_Fov7_V991/Go_terms/Up_Up_5min")
rm(list=ls())
library(simplifyEnrichment)
library(cola)
df_20DPA = read.table("J668_Fov7_V991_5min_Up_Up_Go.bed", sep='\t', header=F)
names(df_20DPA) = c('ID', 'ONTOLOGY', 'Description', 'input_gene_number', 'all_gene_number', 'pvalue', 'geneid', 'FDR')
df_20DPA_BP = df_20DPA[df_20DPA$ONTOLOGY=='biological_process', ]
all_data <- list(df_20DPA_BP$ID)
names(all_data) <- c("Up_Up_5min")
mat = GO_similarity(all_data$Up_Up_5min, measure="Lin")
#compare_clustering_methods(mat, plot_type = "heatmap")
pdf("Up_Up_5min_GO.pdf", width=10, height=7)
simplifyGO(mat,exclude_words=c('process'), method='MCL', order_by_size=TRUE)
dev.off()
df = simplifyGO(mat,exclude_words=c('process'), method='MCL')
write.table(df, "Up_Up_5min_GO_cluster.bed", sep="\t", row.names=F)
write.csv(mat,"Up_Up_5min_GO_similar.csv" )
# Out:
# You haven't provided value for `ont`, guess it as `BP`.
#
# 7/293 GO terms are removed.
#
# Cluster 286 terms by 'MCL'...
#  60 clusters, used 0.3750858 secs.
#
# Perform keywords enrichment for 4 GO lists...
# png
#   2
# Cluster 286 terms by 'MCL'...
#  60 clusters, used 0.3623209 secs.
#
# Perform keywords enrichment for 4 GO lists...
# plot without title

# %%
## 尝试Go term 进行聚类分析 LT 10 min
setwd("G:/Billfish/VD_FOV_3Dgenome/RNA_Seq/DEG/DEG_type/J668_Fov7_V991/Go_terms/LT_10min")
rm(list=ls())
library(simplifyEnrichment)
library(cola)
df_20DPA = read.table("J668_Fov7_V991_10min_LT_uniq_Go.bed", sep='\t', header=F)
names(df_20DPA) = c('ID', 'ONTOLOGY', 'Description', 'input_gene_number', 'all_gene_number', 'pvalue', 'geneid', 'FDR')
df_20DPA_BP = df_20DPA[df_20DPA$ONTOLOGY=='biological_process', ]
all_data <- list(df_20DPA_BP$ID)
names(all_data) <- c("LT_10min")
mat = GO_similarity(all_data$LT_10min, measure="Lin")
#compare_clustering_methods(mat, plot_type = "heatmap")
pdf("LT_10min_GO.pdf", width=10, height=7)
simplifyGO(mat,exclude_words=c('process'), method='MCL', order_by_size=TRUE)
dev.off()
df = simplifyGO(mat,exclude_words=c('process'), method='MCL')
write.table(df, "LT_10min_GO_cluster.bed", sep="\t", row.names=F)
write.csv(mat,"LT_10min_GO_similar.csv" )
# Out:
# You haven't provided value for `ont`, guess it as `BP`.
#
# 2/170 GO terms are removed.
#
# Cluster 168 terms by 'MCL'...
#  34 clusters, used 0.1510649 secs.
#
# Perform keywords enrichment for 3 GO lists...
# png
#   2
# Cluster 168 terms by 'MCL'...
#  34 clusters, used 0.08753419 secs.
#
# Perform keywords enrichment for 3 GO lists...
# plot without title

# %%
## 尝试Go term 进行聚类分析 Down_Down 30 min
setwd("G:/Billfish/VD_FOV_3Dgenome/RNA_Seq/DEG/DEG_type/J668_Fov7_V991/Go_terms/Down_Down_30min")
rm(list=ls())
library(simplifyEnrichment)
library(cola)
df_20DPA = read.table("J668_Fov7_V991_30min_Down_Down_Go.bed", sep='\t', header=F)
names(df_20DPA) = c('ID', 'ONTOLOGY', 'Description', 'input_gene_number', 'all_gene_number', 'pvalue', 'geneid', 'FDR')
df_20DPA_BP = df_20DPA[df_20DPA$ONTOLOGY=='biological_process', ]
all_data <- list(df_20DPA_BP$ID)
names(all_data) <- c("Down_Down_30min")
mat = GO_similarity(all_data$Down_Down_30min, measure="Lin")
#compare_clustering_methods(mat, plot_type = "heatmap")
pdf("Down_30min_GO.pdf", width=10, height=7)
simplifyGO(mat,exclude_words=c('process'), method='MCL', order_by_size=TRUE)
dev.off()
df = simplifyGO(mat,exclude_words=c('process'), method='MCL')
write.table(df, "Down_30min_Go_cluster.bed", sep="\t", row.names=F)
write.csv(mat,"Down_30min_GO_similar.csv" )
# Out:
# You haven't provided value for `ont`, guess it as `BP`.
#
# 4/159 GO terms are removed.
#
# Cluster 155 terms by 'MCL'...
#  24 clusters, used 0.1032779 secs.
#
# Perform keywords enrichment for 4 GO lists...
# png
#   2
# Cluster 155 terms by 'MCL'...
#  24 clusters, used 0.1095421 secs.
#
# Perform keywords enrichment for 4 GO lists...
# plot without title

# %%
## 尝试Go term 进行聚类分析 Down_Down 30 min
options(repr.plot.width=10, repr.plot.height=10)
setwd("G:/Billfish/VD_FOV_3Dgenome/RNA_Seq/DEG/DEG_type/J668_Fov7_V991/Go_terms/Down_Down_90min")
rm(list=ls())
library(simplifyEnrichment)
library(cola)
df_20DPA = read.table("J668_Fov7_V991_90min_Down_Down_Go.bed", sep='\t', header=F)
names(df_20DPA) = c('ID', 'ONTOLOGY', 'Description', 'input_gene_number', 'all_gene_number', 'pvalue', 'geneid', 'FDR')
df_20DPA_BP = df_20DPA[df_20DPA$ONTOLOGY=='biological_process', ]
all_data <- list(df_20DPA_BP$ID)
names(all_data) <- c("Down_Down_90min")
mat = GO_similarity(all_data$Down_Down_90min, measure="Lin")
#compare_clustering_methods(mat, plot_type = "heatmap")


pdf("Down_90min_GO.pdf", width=10, height=7)
simplifyGO(mat,exclude_words=c('process'), method='MCL', order_by_size=TRUE)
dev.off()
df = simplifyGO(mat,exclude_words=c('process'), method='MCL')
write.table(df, "Down_90min_Go_cluster.bed", sep="\t", row.names=F)
write.csv(mat,"Down_90min_GO_similar.csv" )
# Out:
# You haven't provided value for `ont`, guess it as `BP`.
#
# 1/42 GO term is removed.
#
# Cluster 41 terms by 'MCL'...
#  20 clusters, used 0.005733967 secs.
#
# Perform keywords enrichment for 20 GO lists...
# png
#   2
# Cluster 41 terms by 'MCL'...
#  20 clusters, used 0.005987167 secs.
#
# Perform keywords enrichment for 20 GO lists...
# plot without title

# %%
## 尝试Go term 进行聚类分析 Down_Down 180 min
options(repr.plot.width=10, repr.plot.height=10)
setwd("G:/Billfish/VD_FOV_3Dgenome/RNA_Seq/DEG/DEG_type/J668_Fov7_V991/Go_terms/Down_Down_180min")
rm(list=ls())
library(simplifyEnrichment)
library(cola)
df_20DPA = read.table("J668_Fov7_V991_180min_Down_Down_Go.bed", sep='\t', header=F)
names(df_20DPA) = c('ID', 'ONTOLOGY', 'Description', 'input_gene_number', 'all_gene_number', 'pvalue', 'geneid', 'FDR')
df_20DPA_BP = df_20DPA[df_20DPA$ONTOLOGY=='biological_process', ]
all_data <- list(df_20DPA_BP$ID)
names(all_data) <- c("Down_Down_180min")
mat = GO_similarity(all_data$Down_Down_180min, measure="Lin")
#compare_clustering_methods(mat, plot_type = "heatmap")


pdf("Down_180min_GO.pdf", width=10, height=7)
simplifyGO(mat,exclude_words=c('process'), method='MCL', order_by_size=TRUE)
dev.off()
df = simplifyGO(mat,exclude_words=c('process'), method='MCL')
write.table(df, "Down_180min_Go_cluster.bed", sep="\t", row.names=F)
write.csv(mat,"Down_180min_GO_similar.csv" )
# Out:
# You haven't provided value for `ont`, guess it as `BP`.
#
# 4/70 GO terms are removed.
#
# Cluster 66 terms by 'MCL'...
#  15 clusters, used 0.01083517 secs.
#
# Perform keywords enrichment for 15 GO lists...
# png
#   2
# Cluster 66 terms by 'MCL'...
#  15 clusters, used 0.01187396 secs.
#
# Perform keywords enrichment for 15 GO lists...
# plot without title

# %%
## 尝试Go term 进行聚类分析 opposite 180 min
options(repr.plot.width=10, repr.plot.height=10)
setwd("G:/Billfish/VD_FOV_3Dgenome/RNA_Seq/DEG/DEG_type/J668_Fov7_V991/Go_terms/opposite_180min")
rm(list=ls())
library(simplifyEnrichment)
library(cola)
df_20DPA = read.table("J668_Fov7_V991_180min_opposite_Go.bed", sep='\t', header=F)
names(df_20DPA) = c('ID', 'ONTOLOGY', 'Description', 'input_gene_number', 'all_gene_number', 'pvalue', 'geneid', 'FDR')
df_20DPA_BP = df_20DPA[df_20DPA$ONTOLOGY=='biological_process', ]
all_data <- list(df_20DPA_BP$ID)
names(all_data) <- c("opposite_180min")
mat = GO_similarity(all_data$opposite_180min, measure="Lin")
#compare_clustering_methods(mat, plot_type = "heatmap")


pdf("opposite_180min_GO.pdf", width=10, height=7)
simplifyGO(mat,exclude_words=c('process'), method='MCL', order_by_size=TRUE)
dev.off()
df = simplifyGO(mat,exclude_words=c('process'), method='MCL')
write.table(df, "opposite_180min_Go_cluster.bed", sep="\t", row.names=F)
write.csv(mat,"opposite_180min_GO_similar.csv" )
# Out:
# You haven't provided value for `ont`, guess it as `BP`.
#
# 2/101 GO terms are removed.
#
# Cluster 99 terms by 'MCL'...
#  24 clusters, used 0.02722907 secs.
#
# Perform keywords enrichment for 24 GO lists...
# png
#   2
# Cluster 99 terms by 'MCL'...
#  24 clusters, used 0.02622104 secs.
#
# Perform keywords enrichment for 24 GO lists...
# plot without title

# %%
## 尝试Go term 进行聚类分析 Down_Down 720 min
options(repr.plot.width=10, repr.plot.height=10)
setwd("G:/Billfish/VD_FOV_3Dgenome/RNA_Seq/DEG/DEG_type/J668_Fov7_V991/Go_terms/Down_Down_720min")
rm(list=ls())
library(simplifyEnrichment)
library(cola)
df_20DPA = read.table("J668_Fov7_V991_720min_Down_Down_Go.bed", sep='\t', header=F)
names(df_20DPA) = c('ID', 'ONTOLOGY', 'Description', 'input_gene_number', 'all_gene_number', 'pvalue', 'geneid', 'FDR')
df_20DPA_BP = df_20DPA[df_20DPA$ONTOLOGY=='biological_process', ]
all_data <- list(df_20DPA_BP$ID)
names(all_data) <- c("Down_Down_720min")
mat = GO_similarity(all_data$Down_Down_720min, measure="Lin")
#compare_clustering_methods(mat, plot_type = "heatmap")


pdf("Down_7200min_GO.pdf", width=10, height=7)
simplifyGO(mat,exclude_words=c('process'), method='MCL', order_by_size=TRUE)
dev.off()
df = simplifyGO(mat,exclude_words=c('process'), method='MCL')
write.table(df, "Down_720min_Go_cluster.bed", sep="\t", row.names=F)
write.csv(mat,"Down_720min_GO_similar.csv" )
# Out:
# You haven't provided value for `ont`, guess it as `BP`.
#
# 4/75 GO terms are removed.
#
# Cluster 71 terms by 'MCL'...
#  16 clusters, used 0.01478791 secs.
#
# Perform keywords enrichment for 16 GO lists...
# png
#   2
# Cluster 71 terms by 'MCL'...
#  16 clusters, used 0.01482201 secs.
#
# Perform keywords enrichment for 16 GO lists...
# plot without title

# %%
## 尝试Go term 进行聚类分析 opposite 720 min
options(repr.plot.width=10, repr.plot.height=10)
setwd("G:/Billfish/VD_FOV_3Dgenome/RNA_Seq/DEG/DEG_type/J668_Fov7_V991/Go_terms/opposite_720min")
rm(list=ls())
library(simplifyEnrichment)
library(cola)
df_20DPA = read.table("J668_Fov7_V991_720min_opposite_Go.bed", sep='\t', header=F)
names(df_20DPA) = c('ID', 'ONTOLOGY', 'Description', 'input_gene_number', 'all_gene_number', 'pvalue', 'geneid', 'FDR')
df_20DPA_BP = df_20DPA[df_20DPA$ONTOLOGY=='biological_process', ]
all_data <- list(df_20DPA_BP$ID)
names(all_data) <- c("opposite_720min")
mat = GO_similarity(all_data$opposite_720min, measure="Lin")
#compare_clustering_methods(mat, plot_type = "heatmap")


pdf("opposite_720min_GO.pdf", width=10, height=7)
simplifyGO(mat,exclude_words=c('process'), method='MCL', order_by_size=TRUE)
dev.off()
df = simplifyGO(mat,exclude_words=c('process'), method='MCL')
write.table(df, "opposite_720min_Go_cluster.bed", sep="\t", row.names=F)
write.csv(mat,"opposite_720min_GO_similar.csv" )
# Out:
# You haven't provided value for `ont`, guess it as `BP`.
#
# Cluster 44 terms by 'MCL'...
#  9 clusters, used 0.006728888 secs.
#
# Perform keywords enrichment for 9 GO lists...
# png
#   2
# Cluster 44 terms by 'MCL'...
#  9 clusters, used 0.005910158 secs.
#
# Perform keywords enrichment for 9 GO lists...
# plot without title

# %%
## 尝试Go term 进行聚类分析 LT 90 min
setwd("G:/Billfish/VD_FOV_3Dgenome/RNA_Seq/DEG/DEG_type/J668_Fov7_V991/Go_terms/LT_90min")
rm(list=ls())
library(simplifyEnrichment)
library(cola)
df_20DPA = read.table("J668_Fov7_V991_90min_LT_uniq_Go.bed", sep='\t', header=F)
names(df_20DPA) = c('ID', 'ONTOLOGY', 'Description', 'input_gene_number', 'all_gene_number', 'pvalue', 'geneid', 'FDR')
df_20DPA_BP = df_20DPA[df_20DPA$ONTOLOGY=='biological_process', ]
all_data <- list(df_20DPA_BP$ID)
names(all_data) <- c("LT_90min")
mat = GO_similarity(all_data$LT_90min, measure="Lin")
#compare_clustering_methods(mat, plot_type = "heatmap")

pdf("LT_90min_GO.pdf", width=10, height=7)
simplifyGO(mat,exclude_words=c('process'), method='MCL', order_by_size=TRUE)
dev.off()
df = simplifyGO(mat,exclude_words=c('process'), method='MCL')
write.table(df, "LT_90min_GO_cluster.bed", sep="\t", row.names=F)
write.csv(mat,"LT_90min_GO_similar.csv" )
# Out:
# You haven't provided value for `ont`, guess it as `BP`.
#
# 4/212 GO terms are removed.
#
# Cluster 208 terms by 'MCL'...
#  48 clusters, used 0.4546409 secs.
#
# Perform keywords enrichment for 5 GO lists...
# png
#   2
# Cluster 208 terms by 'MCL'...
#  48 clusters, used 0.1495829 secs.
#
# Perform keywords enrichment for 5 GO lists...
# plot without title

# %%
## 尝试Go term 进行聚类分析 
setwd("G:/Billfish/VD_FOV_3Dgenome/RNA_Seq/DEG/time_go_term_ljy")
rm(list=ls())
library(simplifyEnrichment)
library(cola)
df_20DPA = read.table("J668_Fov7_V991_90min_LT_uniq_Go.bed", sep='\t', header=F)
names(df_20DPA) = c('ID', 'ONTOLOGY', 'Description', 'input_gene_number', 'all_gene_number', 'pvalue', 'geneid', 'FDR')
df_20DPA_BP = df_20DPA[df_20DPA$ONTOLOGY=='biological_process', ]
all_data <- list(df_20DPA_BP$ID)
names(all_data) <- c("LT_90min")
mat = GO_similarity(all_data$LT_90min, measure="Lin")
#compare_clustering_methods(mat, plot_type = "heatmap")


pdf("LT_90min_GO.pdf", width=10, height=7)
simplifyGO(mat,exclude_words=c('process'), method='MCL', order_by_size=TRUE)
dev.off()
df = simplifyGO(mat,exclude_words=c('process'), method='MCL')
write.table(df, "LT_90min_GO_cluster.bed", sep="\t", row.names=F)
write.csv(mat,"LT_90min_GO_similar.csv" )
