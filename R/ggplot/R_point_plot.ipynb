# %%
##分析差异三维空间结构所能够导致基因差异表达的GO
rm(list = ls())
options(repr.plot.width=15,repr.plot.height=6)
setwd('F:/Multip_species_3Dgenome/Hi-C/diff_3Dgenome_diff_gene')
library(ggplot2)
library(ggpubr)
df <- read.csv('bio_process_go_T_format.txt', sep = '\t', header = T)
fg <- ggplot(df, aes(x=-log10(pvalues), y=bioprocess, size=gene_number, color=-log10(pvalues)))+
geom_point()+
labs(x=NULL, y=NULL)+
theme(panel.background = element_blank(), 
      panel.grid = element_blank(),
      axis.line=element_line(linetype=1,color="black"),
      legend.position=c(0.25, 0.7),
      axis.ticks.length = unit(0.5, 'cm'),
      axis.text = element_text(size = 16)
      
     )+
scale_color_gradient2(low="#FBE723", mid ='#21918C', high="#440256", midpoint = 2.5)+
scale_size_area(max_size = 10)
fg
ggsave(plot =fg, filename = 'bio_process_go_T_format.pdf', height =8, width = 9)
# Out:
# plot without title

# %%
##3-79 分析由动态TAD boundary区间所包含的差异表达基因所具备的Go
rm(list = ls())
options(repr.plot.width=15,repr.plot.height=6)
setwd('F:/fiber/airticle/GB_modification/dynamic_3Dgenome_gene')
library(ggplot2)
library(ggpubr)
df <- read.csv('TADdiff_GoTerm_0005.txt', sep = '\t', header = T)
fg <- ggplot(df, aes(x=-log10(pvalues), y=bioprocess, size=gene_number, color=-log10(pvalues)))+
geom_point()+
labs(x=NULL, y=NULL)+
theme(panel.background = element_blank(), 
      panel.grid = element_blank(),
      axis.line=element_line(linetype=1,color="black"),
      #legend.position=c(0.25, 0.7),
      axis.ticks.length = unit(0.5, 'cm'),
      axis.text = element_text(size = 16)
     )+
scale_color_gradient(low="#F0AB97",  high="red")+
scale_size_area(max_size = 10)
fg
ggsave(plot =fg, filename = 'TADdiff_GoTerm_0005.txt.pdf', height =6, width = 12.5)
# Out:
# plot without title

# %%
##3-79 分析由动态loop锚点区间所包含的差异表达基因所具备的Go
rm(list = ls())
options(repr.plot.width=15,repr.plot.height=6)
setwd('F:/fiber/airticle/GB_modification/dynamic_3Dgenome_gene')
library(ggplot2)
library(ggpubr)
df <- read.csv('loop_dynamic_GoTerm_0005_fiber.txt', sep = '\t', header = T)
fg <- ggplot(df, aes(x=-log10(pvalues), y=bioprocess, size=gene_number, color=-log10(pvalues)))+
geom_point()+
labs(x=NULL, y=NULL)+
theme(panel.background = element_blank(), 
      panel.grid = element_blank(),
      axis.line=element_line(linetype=1,color="black"),
      #legend.position=c(0.25, 0.7),
      axis.ticks.length = unit(0.5, 'cm'),
      axis.text = element_text(size = 16)
     )+
scale_color_gradient(low="#F0AB97",  high="red")+
scale_size_area(max_size = 10)
fg
ggsave(plot =fg, filename = 'loop_dynamic_GoTerm_0005_fiber.pdf', height =6, width = 12.5)
# Out:
# plot without title
