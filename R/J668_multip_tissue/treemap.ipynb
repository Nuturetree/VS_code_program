# %%
# library
setwd("G:/Billfish/J668_multip_tissue_3D-genome/new_RNA_Seq/DEG/hg/")
library(treemap)
df = read.csv("J668_hg_bias_number_tree.csv", header=T)
treemap(df,
            index=c("group","subgroup"),
            vSize="value",
            type="index"
            ) 
pdf("J668_hg_bias_number_tree.pdf")
treemap(df,
            index=c("group","subgroup"),
            vSize="value",
            type="index"
            ) 
dev.off()
# Out:
# png
#   2
# plot without title
