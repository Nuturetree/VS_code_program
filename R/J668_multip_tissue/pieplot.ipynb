# %%
library(ggplot2)
library(jjPlot)
setwd("G:/Billfish/J668_multip_tissue_3D-genome/RNA_seq/reads/T_VS_T")
df <- read.table("all_DEG_statistics.bed", sep='\t', header=T)
df <- within(df, start <- factor(start, levels = c('anthers', 'cotyledon', 'ovules',  'hypocotyl', 'leaf', 'petals', 'radicle', 'root', 'stem', 'stigma')))
with(df, levels(start))
df <- within(df, end <- factor(end, levels = c('anthers', 'cotyledon', 'ovules',  'hypocotyl', 'leaf', 'petals', 'radicle', 'root', 'stem', 'stigma')))
with(df, levels(end))
# df <- within(df, times <- factor(times, levels = c("1 min", "5 min", "10 min", "30 min", "90 min", "180 min", "720 min")))
# with(df, levels(times)
#df_Dt <- df[df$subg=='Dt', ]
fg <- ggplot(df,aes(x = start,y = end, group = group)) +
    geom_jjPointPie(aes(pievar = number, fill=sig, filltype = sig, explode = sig, width = 0.8), 
    explode.dist = 0.05)+
    scale_fill_manual(values=c( '#4DBBD5', '#E64B35'))+
    theme_bw(base_size = 14)+
    theme(panel.grid = element_blank(),
    axis.text.x = element_text(color="black", angle = 315, hjust=0),
    axis.text.y = element_text(color="black"),
    legend.position=c(0.8, 0.2),
    axis.ticks.length = unit(0.25, "cm"))
fg
#ggsave(plot =fg, filename = 'all_DEG_statistics.pdf', height =4, width = 4.5)
#ggsave(plot =fg, filename = 'Dt_DEG_number2.pdf', height =3, width = 5)
# Out:
#  [1] "anthers"   "cotyledon" "ovules"    "hypocotyl" "leaf"      "petals"
#  [7] "radicle"   "root"      "stem"      "stigma"
#  [1] "anthers"   "cotyledon" "ovules"    "hypocotyl" "leaf"      "petals"
#  [7] "radicle"   "root"      "stem"      "stigma"
# plot without title

# %%
library(ggplot2)
library(jjPlot)
setwd("G:/Billfish/J668_multip_tissue_3D-genome/Chip_Seq/diffbind")
df <- read.csv("J668_diffChIP_DEG.csv",  header=T)
df <- within(df, tissueA <- factor(tissueA, levels = c('anther', 'ovule', 'root', 'radicle', 'leaf', 'hypocotyl', 'cotyledon', 'stem', 'petal', 'stigma')))
with(df, levels(tissueA))
df <- within(df,  tissueB<- factor(tissueB, levels = c('anther', 'ovule', 'root', 'radicle', 'leaf', 'hypocotyl', 'cotyledon', 'stem', 'petal', 'stigma')))
with(df, levels(tissueB))
# df <- within(df, times <- factor(times, levels = c("1 min", "5 min", "10 min", "30 min", "90 min", "180 min", "720 min")))
# with(df, levels(times)
#df_Dt <- df[df$subg=='Dt', ]
fg <- ggplot(df,aes(x = tissueA, y = tissueB, group = group)) +
    geom_jjPointPie(aes(pievar = number, fill=table, filltype = table, explode = table, width = 0.8), 
    explode.dist = 0)+
    labs(x=NULL, y=NULL) + 
    scale_fill_manual(values=c( '#DCD2C6',  '#DCD2C6', '#8A77A5', '#dbe196'))+
    theme_bw(base_size = 14)+
    theme(panel.grid = element_blank(),
    axis.text.x = element_text(color="black", angle = 270, vjust=0.5),
    axis.text.y = element_text(color="black"),
    legend.position='None',
    axis.ticks.length = unit(0.25, "cm"))
fg
ggsave(plot =fg, filename = 'all_DEG_statistics.pdf', height =4, width = 4)
# Out:
#  [1] "anther"    "ovule"     "root"      "radicle"   "leaf"      "hypocotyl"
#  [7] "cotyledon" "stem"      "petal"     "stigma"
#  [1] "anther"    "ovule"     "root"      "radicle"   "leaf"      "hypocotyl"
#  [7] "cotyledon" "stem"      "petal"     "stigma"
# plot without title

# %%
library(ggplot2)
library(jjPlot)
setwd("G:/Billfish/J668_multip_tissue_3D-genome/new_RNA_Seq/DEG/tissue/epigenome")
df <- read.csv("J668_tiss_piar_DEG_chir.csv",  header=T)
df <- within(df, tissueA <- factor(tissueA, levels = c('anther', 'ovule', 'root', 'radicle', 'leaf', 'hypocotyl', 'cotyledon', 'stem', 'petal', 'stigma')))
with(df, levels(tissueA))
df <- within(df,  tissueB<- factor(tissueB, levels = c('anther', 'ovule', 'root', 'radicle', 'leaf', 'hypocotyl', 'cotyledon', 'stem', 'petal', 'stigma')))
with(df, levels(tissueB))
# df <- within(df, times <- factor(times, levels = c("1 min", "5 min", "10 min", "30 min", "90 min", "180 min", "720 min")))
# with(df, levels(times)
#df_Dt <- df[df$subg=='Dt', ]
fg <- ggplot(df,aes(x = tissueA, y = tissueB, group = group)) +
    geom_jjPointPie(aes(pievar = number, fill=table, filltype = table, explode = table, width = 0.8), 
    explode.dist = 0)+
    labs(x=NULL, y=NULL) + 
    scale_fill_manual(values=c( '#DCD2C6',  '#DCD2C6',  '#4DBBD5', '#E64B35'))+
    theme_bw(base_size = 14)+
    theme(panel.grid = element_blank(),
    axis.text.x = element_text(color="black", angle = 270, vjust=0.5),
    axis.text.y = element_text(color="black"),
    legend.position='None',
    axis.ticks.length = unit(0.25, "cm"))
fg
ggsave(plot =fg, filename = 'J668_tiss_piar_DEG_chir.pdf', height =4, width = 4)
# Out:
#  [1] "anther"    "ovule"     "root"      "radicle"   "leaf"      "hypocotyl"
#  [7] "cotyledon" "stem"      "petal"     "stigma"
#  [1] "anther"    "ovule"     "root"      "radicle"   "leaf"      "hypocotyl"
#  [7] "cotyledon" "stem"      "petal"     "stigma"
# plot without title

# %%
library(ggplot2)
library(jjPlot)
setwd("G:/Billfish/J668_multip_tissue_3D-genome/new_RNA_Seq/DEG/tissue/epigenome")
df <- read.csv("J668_tiss_piar_DEG_chir_ab.csv",  header=T)
df <- within(df, tissueA <- factor(tissueA, levels = c('ovule', 'radicle', 'hypocotyl', 'cotyledon', 'stem', 'stigma')))
with(df, levels(tissueA))
df <- within(df,  tissueB<- factor(tissueB, levels = c('ovule', 'radicle', 'hypocotyl', 'cotyledon', 'stem', 'stigma')))
with(df, levels(tissueB))
# df <- within(df, times <- factor(times, levels = c("1 min", "5 min", "10 min", "30 min", "90 min", "180 min", "720 min")))
# with(df, levels(times)
#df_Dt <- df[df$subg=='Dt', ]
fg <- ggplot(df,aes(x = tissueA, y = tissueB, group = group)) +
    geom_jjPointPie(aes(pievar = number, fill=table, filltype = table, explode = table, width = 1), 
    explode.dist = 0)+
    labs(x=NULL, y=NULL) + 
    scale_fill_manual(values=c( '#DCD2C6',  '#DCD2C6',  '#4DBBD5', '#E64B35'))+
    theme_bw(base_size = 14)+
    theme(panel.grid = element_blank(),
    axis.text.x = element_text(color="black", angle = 270, vjust=0.5),
    axis.text.y = element_text(color="black"),
    legend.position='None',
    axis.ticks.length = unit(0.25, "cm"))
fg
Wggsave(plot =fg, filename = 'J668_tiss_piar_DEG_chir_ab.pdf', height =4, width = 4)
# Out:
# Warning message:
# "package 'ggplot2' was built under R version 4.2.3"
# Loading required package: tidyverse
#
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.2 ──
# ✔ tibble  3.1.8      ✔ dplyr   1.0.10
# ✔ tidyr   1.2.1      ✔ stringr 1.5.0
# ✔ readr   2.1.3      ✔ forcats 1.0.0
# ✔ purrr   0.3.5
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# [1] "ovule"     "radicle"   "hypocotyl" "cotyledon" "stem"      "stigma"
# [1] "ovule"     "radicle"   "hypocotyl" "cotyledon" "stem"      "stigma"
# plot without title

# %%
library(ggplot2)
library(jjPlot)
setwd("G:/Billfish/J668_multip_tissue_3D-genome/new_RNA_Seq/homo_gene2/gene_bias/epigenome")
df <- read.csv("hypocotyl_sta.csv",  header=T)
# df <- within(df, tissueA <- factor(tissueA, levels = c('ovule', 'radicle', 'hypocotyl', 'cotyledon', 'stem', 'stigma')))
# with(df, levels(tissueA))
# df <- within(df,  tissueB<- factor(tissueB, levels = c('ovule', 'radicle', 'hypocotyl', 'cotyledon', 'stem', 'stigma')))
# with(df, levels(tissueB))
fg <- ggplot(df,aes(x = epigenome, y = bias_tags, group = tags)) +
    geom_jjPointPie(aes(pievar = number, fill=table, filltype = table, explode = table, width = 3), 
    explode.dist = 0)+
    labs(x=NULL, y=NULL) + 
    scale_fill_manual(values=c( '#DCD2C6',  '#4DBBD5', '#E64B35'))+
    theme_bw(base_size = 14)+
    theme(panel.grid = element_blank(),
    axis.text.x = element_text(color="black", angle = 270, vjust=0.5),
    axis.text.y = element_text(color="black"),
    legend.position='None',
    axis.ticks.length = unit(0.25, "cm"))
fg
ggsave(plot =fg, filename = 'hypocotyl_sta.pdf', height =2, width = 2)
# Out:
# plot without title

# %%
library(ggplot2)
setwd("G:/Billfish/J668_multip_tissue_3D-genome/HiC/loops/Cis-element/THR_Cis_overlap")
df <- read.csv("THR.csv",  header=T)
fg <- ggplot(df, aes(x=tags2, y=number, fill=tags)) +
geom_bar(stat = "identity", position = "fill", color="black", size=0.3)+
coord_polar(theta = 'y')
fg
ggsave(plot =fg, filename = 'THR.pdf', height =4, width = 4)
# Out:
# plot without title

# %%
library(ggplot2)
setwd("G:/Billfish/J668_multip_tissue_3D-genome/HiC/loops/Cis-element/THR_Cis_overlap")
df <- read.csv("THR_cis.csv",  header=T)
fg <- ggplot(df, aes(x=tags2, y=number, fill=tags)) +
geom_bar(stat = "identity", position = "fill", color="black", size=0.3)+
coord_polar(theta = 'y')
fg
ggsave(plot =fg, filename = 'THR_cis.pdf', height =4, width = 4)
# Out:
# plot without title

# %%
library(ggplot2)
library(paletteer)
setwd("G:/Billfish/J668_multip_tissue_3D-genome/HiC/loops/loop_conserved_dynamic")
df <- read.csv("conserved_loop.csv",  header=T)
fg <- ggplot(df, aes(x=as.factor(tags2), y=number, fill=as.factor(tags))) +
geom_bar(stat = "identity", position = "stack", color="black", size=0.3)+
coord_polar(theta = 'y')+
scale_fill_paletteer_d("ggthemes::Tableau_20")
#scale_fill_paletteer_c("grDevices::PRGn")

fg
ggsave(plot =fg, filename = 'conserved_loop.pdf', height =4, width = 4)
# Out:
# plot without title

# %%
install.packages('ggthemes')
# Out:
# package 'ggthemes' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\pc\AppData\Local\Temp\Rtmp8mYc9i\downloaded_packages
