# %%
## 尝试Go term 进行聚类分析 fiber_0DPA, 5DPA, 10DPA, 20DPA
options(repr.plot.width=10, repr.plot.height=10)
setwd("G:/Billfish/J668_multip_tissue_3D-genome/RNA_seq/tau_gini/tissues_Go/0DPA_5DPA_10DPA_20DPA")
rm(list=ls())
library(simplifyEnrichment)
library(cola)
df_20DPA = read.table("fiber_development_DPA.bed", sep='\t', header=T, quote="")
df_20DPA_BP = df_20DPA[df_20DPA$ONTOLOGY=='BP', ]
all_data <- list(df_20DPA_BP$ID)
names(all_data) <- c("LT_90min")
mat = GO_similarity(all_data$LT_90min, measure="Rel")
compare_clustering_methods(mat, plot_type = "heatmap")
# pdf("fiber_development_DPA.pdf", width=10, height=7)
# simplifyGO(mat,exclude_words=c('process'), method='MCL', order_by_size=TRUE)
# dev.off()
# df = simplifyGO(mat,exclude_words=c('process'), method='MCL')
# write.table(df, "fiber_development_DPA_cluster.bed", sep="\t", row.names=F)
# write.csv(mat,"fiber_development_DPA_similar.csv" )
# Out:
# You haven't provided value for `ont`, guess it as `BP`.
#
# Cluster 222 terms by 'binary_cut'...
#  79 clusters, used 0.5448031 secs.
#
# Cluster 222 terms by 'kmeans'...
#  9 clusters, used 0.170186 secs.
#
# Cluster 222 terms by 'pam'...
#  19 clusters, used 0.4458821 secs.
#
# Cluster 222 terms by 'dynamicTreeCut'...
#  17 clusters, used 0.03317499 secs.
#
# Cluster 222 terms by 'apcluster'...
#  15 clusters, used 0.07197499 secs.
#
# Cluster 222 terms by 'hdbscan'...
#  12 clusters, used 0.02310705 secs.
#
# Cluster 222 terms by 'fast_greedy'...
#  64 clusters, used 0.007452011 secs.
#
# Cluster 222 terms by 'louvain'...
#  64 clusters, used 0.007533073 secs.
#
# Cluster 222 terms by 'walktrap'...
#  63 clusters, used 0.01457405 secs.
#
# Cluster 222 terms by 'MCL'...
#  65 clusters, used 0.2336881 secs.
# plot without title

# %%
## 尝试Go term 进行聚类分析 fiber_0DPA, 5DPA, 10DPA, 20DPA
options(repr.plot.width=10, repr.plot.height=10)
setwd("G:/Billfish/J668_multip_tissue_3D-genome/RNA_seq/reads/0DPA_vs_5DPA")
rm(list=ls())
library(simplifyEnrichment)
library(cola)
df_20DPA = read.table("5DPA_high_Go.bed", sep='\t', header=T)
print(dim(df_20DPA))
df_20DPA_BP = df_20DPA[df_20DPA$ONTOLOGY=='BP', ]
all_data <- list(df_20DPA_BP$ID)
#print(all_data)
names(all_data) <- c("LT_90min")
mat = GO_similarity(all_data$LT_90min, measure="Lin")
compare_clustering_methods(mat, plot_type = "heatmap")
# pdf("fiber_development_DPA.pdf", width=10, height=7)
# simplifyGO(mat,exclude_words=c('process'), method='MCL', order_by_size=TRUE)
# dev.off()
# df = simplifyGO(mat,exclude_words=c('process'), method='MCL')
# write.table(df, "5DPA_high_cluster.bed", sep="\t", row.names=F)
# write.csv(mat,"5DPA_high_similar.csv" )

# %%
## 尝试Go term 进行聚类分析 fiber_0DPA, 5DPA, 10DPA, 20DPA
options(repr.plot.width=10, repr.plot.height=10)
setwd("G:/Billfish/J668_multip_tissue_3D-genome/RNA_seq/reads/5DPA_vs_10DPA")
rm(list=ls())
library(simplifyEnrichment)
library(cola)
df_20DPA = read.table("10DPA_high_Go.bed", sep='\t', header=T)
print(dim(df_20DPA))
df_20DPA_BP = df_20DPA[df_20DPA$ONTOLOGY=='BP', ]
all_data <- list(df_20DPA_BP$ID)
#print(all_data)
names(all_data) <- c("LT_90min")
mat = GO_similarity(all_data$LT_90min, measure="Resnik")
compare_clustering_methods(mat, plot_type = "heatmap")
# pdf("10DPA_high.pdf", width=10, height=7)
# simplifyGO(mat,exclude_words=c('process'), method='dynamicTreeCut', order_by_size=TRUE)
# dev.off()
# df = simplifyGO(mat,exclude_words=c('process'), method='dynamicTreeCut')
# write.table(df, "10DPA_high_cluster.bed", sep="\t", row.names=F)
# write.csv(mat,"10DPA_high_similar.csv" )
# Out:
# [1] 70  3
# You haven't provided value for `ont`, guess it as `BP`.
#
# Cluster 39 terms by 'binary_cut'...
#  21 clusters, used 0.05111003 secs.
#
# Cluster 39 terms by 'kmeans'...
#  5 clusters, used 0.002972126 secs.
#
# Cluster 39 terms by 'pam'...
#  4 clusters, used 0.001013041 secs.
#
# Cluster 39 terms by 'dynamicTreeCut'...
#  3 clusters, used 0.003190994 secs.
#
# Cluster 39 terms by 'apcluster'...
#  6 clusters, used 0.004187107 secs.
#
# Cluster 39 terms by 'hdbscan'...
#  3 clusters, used 0.0009300709 secs.
#
# Cluster 39 terms by 'fast_greedy'...
#  20 clusters, used 0.001005888 secs.
#
# Cluster 39 terms by 'louvain'...
#  20 clusters, used 0.001133919 secs.
#
# Cluster 39 terms by 'walktrap'...
#  16 clusters, used 0.001193047 secs.
#
# Cluster 39 terms by 'MCL'...
#  20 clusters, used 0.005658865 secs.
# plot without title
