# %%
### 绘制AB compartment 转化热图
setwd('G:/J668_multip_tissue_3D-genome/HiC/compartment/dcHiC/diff_compartment')
library(ggplot2)
options(repr.plot.width=12)
df <- read.csv('all_diff_compartment_long.txt', sep = '\t', header = T)
#AB_data <- read.csv('At_change_bin_R.txt', sep = '\t', header = T)
df <- within(df, variable <- factor(variable, levels = c( 'anthers', 'cotyledon', 'fiber_5DPA', 'fiber_10DPA', 'fiber_20DPA', 'hypocotyl', 'leaf', 'petals', 'radicle', 'root', 'stem', 'stigma')))
with(df, levels(variable)) 
df <- within(df, value <- factor(value, levels = c( 'A3', 'A2', 'A1', 'A0', 'B0', 'B1', 'B2', 'B3')))
with(df, levels(value)) 
p <- ggplot(df, aes(x=variable, y=index))+
    #geom_raster(aes(fill=status))+
  geom_tile(aes(fill=as.factor(value)))+
  theme(panel.background = element_blank(),axis.line = element_line(colour="black"))+
  theme(axis.ticks.x = element_blank())+
  theme(axis.ticks.y = element_blank())+
  theme(axis.title.y=element_blank())+
  theme(axis.title.x=element_blank())+
  theme(legend.position="top")+
  #theme(legend = 'none')+
  scale_fill_manual(values=c("#BD2A2E", "#F23030", "#F28705", "#F2CB05", "#9AEBA3", "#45C4B0", "#13678A" ,'#012030' ))+
  coord_flip()
p
ggsave(plot =p, filename = 'all_diff_compartment_long.pdf', height = 5, width = 12,  dpi = 300)
# Out:
#  [1] "anthers"     "cotyledon"   "fiber_5DPA"  "fiber_10DPA" "fiber_20DPA"
#  [6] "hypocotyl"   "leaf"        "petals"      "radicle"     "root"
# [11] "stem"        "stigma"
# [1] "A3" "A2" "A1" "A0" "B0" "B1" "B2" "B3"
# plot without title

# %%
### 绘制AB compartment 转化热图
setwd('G:/J668_multip_tissue_3D-genome/HiC/compartment/dcHiC/diff_compartment')
library(ggplot2)
options(repr.plot.width=12)
df <- read.csv('all_diff_compartment_long_sort_number.txt', sep = '\t', header = T)
#AB_data <- read.csv('At_change_bin_R.txt', sep = '\t', header = T)
df <- within(df, variable <- factor(variable, levels = c( 'anthers', 'cotyledon', 'fiber_5DPA', 'fiber_10DPA', 'fiber_20DPA', 'hypocotyl', 'leaf', 'petals', 'radicle', 'root', 'stem', 'stigma')))
with(df, levels(variable)) 
df <- within(df, value <- factor(value, levels = c( 'A3', 'A2', 'A1', 'A0', 'B0', 'B1', 'B2', 'B3')))
with(df, levels(value)) 
p <- ggplot(df, aes(x=index, y=variable))+
    #geom_raster(aes(fill=status))+
  #facet_grid(.~numbers) +
  geom_tile(aes(fill=as.factor(value)))+
  theme(panel.background = element_blank(),axis.line = element_line(colour="black"))+
  theme(axis.ticks.x = element_blank())+
  theme(axis.ticks.y = element_blank())+
  theme(axis.title.y=element_blank())+
  theme(axis.title.x=element_blank())+
  theme(legend.position="top")+
  #theme(legend = 'none')+
  scale_fill_manual(values=c("#BD2A2E", "#F23030", "#F28705", "#F2CB05", "#9AEBA3", "#45C4B0", "#13678A" ,'#012030' ))
  #coord_flip()

p2 <- p+
  theme(axis.text.x =element_text(angle =90,hjust =0.5,vjust = 0.5))+
  xlab(NULL) + ylab(NULL)+
  #theme(panel.border = element_rect(fill=NA,color="black", size=1, linetype="solid"))+
  geom_vline(aes(xintercept=c(960)), size=1)+
geom_vline(aes(xintercept=c(2882)), size=1)
p2
ggsave(plot =p2, filename = 'all_diff_compartment_long_sort_number.pdf', height = 5, width = 12,  dpi = 300)
# Out:
#  [1] "anthers"     "cotyledon"   "fiber_5DPA"  "fiber_10DPA" "fiber_20DPA"
#  [6] "hypocotyl"   "leaf"        "petals"      "radicle"     "root"
# [11] "stem"        "stigma"
# [1] "A3" "A2" "A1" "A0" "B0" "B1" "B2" "B3"
# plot without title

# %%
## 对lemon-tree 聚类的前五类结果做图分析
### 绘制AB compartment 转化热图
setwd('G:/Billfish/J668_multip_tissue_3D-genome/RNA_seq/cluster')
library(ggplot2)
library(reshape2)
library(paletteer)
options(repr.plot.width=12)

df <- read.csv('J668_all_tissue_average_TPM_cluster_anthers.txt', sep = '\t', header = T)
df_long <- melt(df, id = c('GeneId'))
# df <- within(df, variable <- factor(variable, levels = c( 'anthers', 'cotyledon', 'fiber_5DPA', 'fiber_10DPA', 'fiber_20DPA', 'hypocotyl', 'leaf', 'petals', 'radicle', 'root', 'stem', 'stigma')))
# with(df, levels(variable)) 
p <- ggplot(df_long, aes(x=GeneId, y=variable))+
  geom_tile(aes(fill=log2(value+0.0001)))+
  theme(panel.background = element_blank(),axis.line = element_line(colour="black"))+
  theme(axis.ticks.x = element_blank())+
  theme(axis.ticks.y = element_blank())+
  theme(axis.title.y=element_blank())+
  theme(axis.title.x=element_blank())+
  theme(axis.text.x=element_blank())+
  theme(axis.text.y=element_text(colour="black", size=12))+
  theme(legend.position='top')+
  #scale_fill_gradient(low='#FFFFFF', high='#D4172F')
  scale_fill_gradient2(low='#FFFFFF', mid = '#8CFFE5', high='#D4172F')
p
ggsave(plot =p, filename = 'J668_all_tissue_average_TPM_cluster_anthers.pdf', height = 5, width = 12,  dpi = 300)
# Out:
# plot without title

# %%
## 对lemon-tree 聚类的前五类结果做图分析
### 绘制AB compartment 转化热图
setwd('G:/Billfish/J668_multip_tissue_3D-genome/RNA_seq/cluster')
library(ggplot2)
library(reshape2)
library(paletteer)
options(repr.plot.width=12)

df <- read.csv('J668_all_tissue_average_TPM_cluster_leaf.txt', sep = '\t', header = T)
df_long <- melt(df, id = c('GeneId'))
# df <- within(df, variable <- factor(variable, levels = c( 'anthers', 'cotyledon', 'fiber_5DPA', 'fiber_10DPA', 'fiber_20DPA', 'hypocotyl', 'leaf', 'petals', 'radicle', 'root', 'stem', 'stigma')))
# with(df, levels(variable)) 
p <- ggplot(df_long, aes(x=GeneId, y=variable))+
  geom_tile(aes(fill=log2(value+0.0001)))+
  theme(panel.background = element_blank(),axis.line = element_line(colour="black"))+
  theme(axis.ticks.x = element_blank())+
  theme(axis.ticks.y = element_blank())+
  theme(axis.title.y=element_blank())+
  theme(axis.title.x=element_blank())+
  theme(axis.text.x=element_blank())+
  theme(axis.text.y=element_text(colour="black", size=12))+
  theme(legend.position='top')+
  #scale_fill_gradient(low='#FFFFFF', high='#D4172F')
  scale_fill_gradient2(low='#FFFFFF', mid = '#8CFFE5', high='#D4172F')
p
ggsave(plot =p, filename = 'J668_all_tissue_average_TPM_cluster_leaf.pdf', height = 5, width = 12,  dpi = 300)
# Out:
# plot without title
