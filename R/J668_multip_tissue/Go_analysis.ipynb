# %%
## 分析lemon-tree 聚类结果的Go term
rm=list(ls())
setwd('G:/Billfish/J668_multip_tissue_3D-genome/RNA_seq/cluster')
library(clusterProfiler)
library(org.At.tair.db)
df <- read.table("lemon-tree_clusters.txt", sep='\t', header=T)
for (i in seq(0,330))
{
    df_cluster = df[df$cluster_id==i, ]
    output_f = paste("lemon-tree_cluster_", as.character(i), ".txt", sep="")
    df_cluster_gid = df_cluster$Atha_id
    ego = enrichGO(df_cluster_gid, OrgDb = "org.At.tair.db", keyType="TAIR", ont = "ALL", pAdjustMethod = "BH", pvalueCutoff  = 0.01, qvalueCutoff  = 0.05, readable= TRUE)
    write.table(summary(ego), output_f, sep='\t', row.names=FALSE)
}

# %%
## 分析lemon-tree 聚类结果的anthers
rm=list(ls())
#setwd('G:/Billfish/J668_multip_tissue_3D-genome/RNA_seq/tissue_uniq_exp_gene/lemon_tree/anthers')
#setwd('G:/Billfish/J668_multip_tissue_3D-genome/RNA_seq/tissue_uniq_exp_gene/lemon_tree/fiber_20DPA')
#setwd('G:/Billfish/J668_multip_tissue_3D-genome/RNA_seq/tissue_uniq_exp_gene/lemon_tree/fiber_10DPA')
#setwd('G:/Billfish/J668_multip_tissue_3D-genome/RNA_seq/tissue_uniq_exp_gene/lemon_tree/cotyledon')
#setwd('G:/Billfish/J668_multip_tissue_3D-genome/RNA_seq/tissue_uniq_exp_gene/lemon_tree/fiber_5DPA_10DPA')
#etwd('G:/Billfish/J668_multip_tissue_3D-genome/RNA_seq/tissue_uniq_exp_gene/lemon_tree/hypocotyl')
#setwd('G:/Billfish/J668_multip_tissue_3D-genome/RNA_seq/tissue_uniq_exp_gene/lemon_tree/leaf')
setwd('G:/Billfish/J668_multip_tissue_3D-genome/RNA_seq/tissue_uniq_exp_gene/lemon_tree/ovules')
#setwd('G:/Billfish/J668_multip_tissue_3D-genome/RNA_seq/tissue_uniq_exp_gene/lemon_tree/petals')
#setwd('G:/Billfish/J668_multip_tissue_3D-genome/RNA_seq/tissue_uniq_exp_gene/lemon_tree/radicle')
#setwd('G:/Billfish/J668_multip_tissue_3D-genome/RNA_seq/tissue_uniq_exp_gene/lemon_tree/root')
#setwd('G:/Billfish/J668_multip_tissue_3D-genome/RNA_seq/tissue_uniq_exp_gene/lemon_tree/stem')
#setwd('G:/Billfish/J668_multip_tissue_3D-genome/RNA_seq/tissue_uniq_exp_gene/lemon_tree/stigma')
library(clusterProfiler)
library(org.At.tair.db)
df <- read.table("lemon_clusters.txt", sep='\t', header=T)
# ego = enrichGO(df$Atha_id, OrgDb = "org.At.tair.db", keyType="TAIR", ont = "ALL", pAdjustMethod = "BH", pvalueCutoff  = 0.01, qvalueCutoff  = 0.05, readable= TRUE)
# write.table(summary(ego), "tight_clusters_go.txt", sep='\t', row.names=FALSE)
for (i in seq(20,100))
{
    df_cluster = df[df$cluster_id==i, ]
    output_f = paste("lemon-tree_cluster_", as.character(i), ".txt", sep="")
    df_cluster_gid = df_cluster$Atha_id
    ego = enrichGO(df_cluster_gid, OrgDb = "org.At.tair.db", keyType="TAIR", ont = "ALL", pAdjustMethod = "BH", pvalueCutoff  = 0.01, qvalueCutoff  = 0.05, readable= TRUE)
    write.table(summary(ego), output_f, sep='\t', row.names=FALSE)
}

# %%
## 分析Mfuzz + lemon-tree 聚类结果的anthers
rm=list(ls())
for (i in seq(16, 31))
{
    paths <- paste("G:/Billfish/J668_multip_tissue_3D-genome/RNA_seq/Mfuzz/cluster", as.character(i), sep="")
    setwd(paths)
    library(clusterProfiler)
    library(org.At.tair.db)
    df <- read.table("lemon_clusters.txt", sep='\t', header=T)
    # ego = enrichGO(df$Atha_id, OrgDb = "org.At.tair.db", keyType="TAIR", ont = "ALL", pAdjustMethod = "BH", pvalueCutoff  = 0.01, qvalueCutoff  = 0.05, readable= TRUE)
    # write.table(summary(ego), "tight_clusters_go.txt", sep='\t', row.names=FALSE)
    for (i in seq(1,30))
    {
        df_cluster = df[df$cluster_id==i, ]
        output_f = paste("lemon-tree_cluster_", as.character(i), ".txt", sep="")
        df_cluster_gid = df_cluster$Atha_id
        ego = enrichGO(df_cluster_gid, OrgDb = "org.At.tair.db", keyType="TAIR", ont = "ALL", pAdjustMethod = "BH", pvalueCutoff  = 0.01, qvalueCutoff  = 0.05, readable= TRUE)
        write.table(summary(ego), output_f, sep='\t', row.names=FALSE)
    }
}

# %%
## 分析lemon-tree 聚类结果的anthers
rm=list(ls())
setwd('G:/Billfish/J668_multip_tissue_3D-genome/RNA_seq/tissue_uniq_exp_gene/lemon_tree/anthers')
library(clusterProfiler)
library(org.At.tair.db)
df <- read.table("lemon_clusters.txt", sep='\t', header=T)
for (i in seq(0,330))
{
    df_cluster = df[df$cluster_id==i, ]
    output_f = paste("lemon-tree_cluster_", as.character(i), ".txt", sep="")
    df_cluster_gid = df_cluster$Atha_id
    ego = enrichGO(df_cluster_gid, OrgDb = "org.At.tair.db", keyType="TAIR", ont = "ALL", pAdjustMethod = "BH", pvalueCutoff  = 0.01, qvalueCutoff  = 0.05, readable= TRUE)
    write.table(summary(ego), output_f, sep='\t', row.names=FALSE)
}

# %%
## 对Go term 结果作图
rm(list = ls())
options(repr.plot.width=15,repr.plot.height=6)
setwd('G:/Billfish/J668_multip_tissue_3D-genome/RNA_seq/cluster/lemon_cluster_Go/A_go_figure')
library(ggplot2)
library(ggpubr)
df <- read.csv('lemon-tree_cluster_182_go.txt', sep = '\t', header = T)
fg <- ggplot(df, aes(x=-log10(FDR), y=bioprocess, size=gene_number, color=-log10(FDR)))+
geom_point()+
labs(x=NULL, y=NULL)+
theme(panel.background = element_blank(), 
      panel.grid = element_blank(),
      axis.line=element_line(linetype=1,color="black"),
      #legend.position=c(0.25, 0.7),
      axis.ticks.length = unit(0.5, 'cm'),
      axis.text = element_text(size = 16)
     )+
scale_color_gradient(low="#F0AB97",  high="red")+
scale_size_area(max_size = 10)
fg
ggsave(plot =fg, filename = 'lemon-tree_cluster_182_go.pdf', height =8, width = 12.5)
# Out:
# plot without title

# %%
## 对Go term 结果作图
rm(list = ls())
options(repr.plot.width=15,repr.plot.height=6)
setwd('G:/Billfish/J668_multip_tissue_3D-genome/RNA_seq/cluster/lemon_cluster_Go/A_go_figure')
library(ggplot2)
library(ggpubr)
df <- read.csv('lemon-tree_cluster_0_go.txt', sep = '\t', header = T)
fg <- ggplot(df, aes(x=-log10(FDR), y=bioprocess, size=gene_number, color=-log10(FDR)))+
geom_point()+
labs(x=NULL, y=NULL)+
theme(panel.background = element_blank(), 
      panel.grid = element_blank(),
      axis.line=element_line(linetype=1,color="black"),
      #legend.position=c(0.25, 0.7),
      axis.ticks.length = unit(0.5, 'cm'),
      axis.text = element_text(size = 16)
     )+
scale_color_gradient(low="#F0AB97",  high="red")+
scale_size_area(max_size = 10)
fg
ggsave(plot =fg, filename = 'lemon-tree_cluster_0_go.pdf', height =8, width = 12.5)
# Out:
# plot without title

# %%
## 对Go term 结果作图
rm(list = ls())
options(repr.plot.width=15,repr.plot.height=6)
setwd('G:/Billfish/J668_multip_tissue_3D-genome/RNA_seq/tissue_uniq_exp_gene')
library(ggplot2)
library(ggpubr)
df <- read.csv('fiber_20DPA_Go2.txt', sep = '\t', header = T)
fg <- ggplot(df, aes(x=-log10(FDR), y=bioprocess, size=gene_number, color=-log10(FDR)))+
geom_point()+
labs(x=NULL, y=NULL)+
theme(panel.background = element_blank(), 
      panel.grid = element_blank(),
      axis.line=element_line(linetype=1,color="black"),
      #legend.position=c(0.25, 0.7),
      axis.ticks.length = unit(0.5, 'cm'),
      axis.text = element_text(size = 16)
     )+
scale_color_gradient(low="#F0AB97",  high="red")+
scale_size_area(max_size = 15)
fg
ggsave(plot =fg, filename = 'fiber_20DPA_Go2.pdf', height =8, width = 12.5)
ggsave(plot =fg, filename = 'fiber_20DPA_Go2.png', height =8, width = 12.5)
# Out:
# plot without title

# %%
## 分析组织特异性表达基因的Go term
rm=list(ls())
setwd('G:/Billfish/J668_multip_tissue_3D-genome/RNA_seq/tissue_uniq_exp_gene')
library(clusterProfiler)
library(org.At.tair.db)
df <- read.table("all_tissue_expgene_ge_2_Atid.txt", sep='\t', header=T)
all_tissue <- c('anthers', 'leaf', 'hypocotyl', 'cotyledon', 'stem', 'ovules', 'root', 'radicle', 'fiber_5DPA', 'fiber_10DPA', 'fiber_20DPA', 'petals', 'stigma')
for (i in all_tissue)
{
    print(i)
    df_tissue = df[df$max_idx==i, ]
    output_f = paste(as.character(i), "_Go.txt", sep="")
    df_tissue_gid = df_tissue$AtId
    ego = enrichGO(df_tissue_gid, OrgDb = "org.At.tair.db", keyType="TAIR", ont = "ALL", pAdjustMethod = "BH", pvalueCutoff  = 0.01, qvalueCutoff  = 0.05, readable= TRUE)
    write.table(summary(ego), output_f, sep='\t', row.names=FALSE)
}

# %%
## 分析fiber_5PDA, fiber_10DPA组织特异性表达基因的Go term
rm=list(ls())
setwd('G:/Billfish/J668_multip_tissue_3D-genome/RNA_seq/tissue_uniq_exp_gene')
library(clusterProfiler)
library(org.At.tair.db)
df <- read.table("all_tissue_expgene_ge_2_Atid_fiber_5-10DPA.txt", sep='\t', header=T)
all_tissue <- c('fiber_5DPA', 'fiber_10DPA')
for (i in all_tissue)
{
    print(i)
    df_tissue = df[(df$max_idx==i), ]
    print(dim(df_tissue)[1])
    output_f = paste(as.character(i), "_Go.txt", sep="")
    df_tissue_gid = df_tissue$AtId
    ego = enrichGO(df_tissue_gid, OrgDb = "org.At.tair.db", keyType="TAIR", ont = "ALL", pAdjustMethod = "BH", pvalueCutoff  = 0.01, qvalueCutoff  = 0.05, readable= TRUE)
    write.table(summary(ego), output_f, sep='\t', row.names=FALSE)
}
# Out:
# [1] "fiber_5DPA"
# [1] 527
# Warning message in summary(ego):
# "summary method to convert the object to data.frame is deprecated, please use as.data.frame instead."
# [1] "fiber_10DPA"
# [1] 680
# Warning message in summary(ego):
# "summary method to convert the object to data.frame is deprecated, please use as.data.frame instead."

# %%
## 分析Go term 聚类图
setwd("G:/Billfish/J668_multip_tissue_3D-genome/RNA_seq/tissue_uniq_exp_gene")
rm(list=ls())
library(simplifyEnrichment)
library(cola)
df_20DPA = read.table("fiber_20DPA_Go.txt", sep='\t', header=T)
#df_stigma = read.table("stigma_Go.txt", sep='\t', header=T)
#df_20DPA_BP = df_20DPA[df_20DPA$ONTOLOGY=='BP', ]
df_stigma_BP = df_stigma[df_stigma$ONTOLOGY=='BP',]
#df_BP = df[df$ONTOLOGY=="BP",]
all_data <- list(df_20DPA_BP$ID, df_stigma_BP$ID)
names(all_data) <- c("fiber_20DPA", "stigma")
#all_data
mat = GO_similarity(all_data$fiber_20DPA, measure="Wang")
#cluster_terms(mat, method = "kmeans")
pdf("fiber_20DPA_Go.pdf", width=10, height=7)
#simplifyGO(mat, order_by_size = FALSE,exclude_words=c('process'))
simplifyGOFromMultipleLists(all_data, method ='kmeans')
dev.off()

# %%
## 分析组织特异性表达基因Go 富集分析
rm=list(ls())
setwd('G:/Billfish/J668_multip_tissue_3D-genome/RNA_seq/tau_gini/tissues_Go')
library(clusterProfiler)
library(org.At.tair.db)
df <- read.table("TSG_TAIRID.bed", sep='\t', header=T)
#tissues <- c("anthers", 'cotyledon', 'hypocotyl', 'leaf', 'petals', 'radicle', 'root', 'stem', 'stigma', 'ovules', 'fiber_5DPA', 'fiber_10DPA', 'fiber_20DPA')
tissues <- c('petals')
for (t in tissues)
{
    df_tissues = df[df$tags==t, ]
    output_f = paste(as.character(t), "_GO.bed", sep="")
    df_tissues_gid = df_tissues$TAIR_ID
    ego = enrichGO(df_tissues_gid, OrgDb = "org.At.tair.db", keyType="TAIR", ont = "ALL", pAdjustMethod = "BH", pvalueCutoff  = 0.1, qvalueCutoff  = 0.1, readable= TRUE)
    #ego = enrichGO(df_tissue_gid, OrgDb = "org.At.tair.db", keyType="TAIR", ont = "ALL", pAdjustMethod = "BH", pvalueCutoff  = 0.01, qvalueCutoff  = 0.05, readable= TRUE)
    write.table(summary(ego), output_f, sep='\t', row.names=FALSE)
}
# Out:
# Warning message in summary(ego):
# "summary method to convert the object to data.frame is deprecated, please use as.data.frame instead."

# %%
## 分析hypocotyl 的go terms
rm=list(ls())
setwd('G:/Billfish/J668_multip_tissue_3D-genome/new_RNA_Seq/TAU')
output_f = "hypocotyl_TAU_geneid_tair_clusterprofiler_go.bed"
library(clusterProfiler)
library(org.At.tair.db)
df <- read.table("hypocotyl_TAU_geneid_tair.bed", sep='\t', header=T)
ego = enrichGO(df$tair, OrgDb = "org.At.tair.db", keyType="TAIR", ont = "ALL", pAdjustMethod = "BH", pvalueCutoff  = 0.1, qvalueCutoff  = 0.1, readable= TRUE)
write.table(summary(ego), output_f, sep='\t', row.names=FALSE)
# Out:
# Warning message in summary(ego):
# "summary method to convert the object to data.frame is deprecated, please use as.data.frame instead."

# %%
## 分析hypocotyl 的go terms
rm=list(ls())
setwd('G:/Billfish/J668_multip_tissue_3D-genome/new_RNA_Seq/TAU')
output_f = "fiber_10DPA_TAU_geneid_tair_clusterprofiler_go.bed"
library(clusterProfiler)
library(org.At.tair.db)
df <- read.table("fiber_10DPA_TAU_geneid_tair.bed", sep='\t', header=T)
ego = enrichGO(df$tair, OrgDb = "org.At.tair.db", keyType="TAIR", ont = "ALL", pAdjustMethod = "BH", pvalueCutoff  = 0.1, qvalueCutoff  = 0.1, readable= TRUE)
write.table(summary(ego), output_f, sep='\t', row.names=FALSE)
# Out:
# Warning message in summary(ego):
# "summary method to convert the object to data.frame is deprecated, please use as.data.frame instead."

# %%
if (!require("BiocManager", quietly = TRUE))
    install.packages("BiocManager")

BiocManager::install("org.At.tair.db")
# Out:
# 'getOption("repos")' replaces Bioconductor standard repositories, see
# 'help("repositories", package = "BiocManager")' for details.
# Replacement repositories:
#     CRAN: https://cran.r-project.org
#
# Bioconductor version 3.16 (BiocManager 1.30.20), R 4.2.2 (2022-10-31 ucrt)
#
# Installing package(s) 'org.At.tair.db'
#
# Warning message:
# "unable to access index for repository https://bioconductor.org/packages/3.16/data/annotation/bin/windows/contrib/4.2:
#   cannot open URL 'https://bioconductor.org/packages/3.16/data/annotation/bin/windows/contrib/4.2/PACKAGES'"
# Warning message:
# "unable to access index for repository https://bioconductor.org/packages/3.16/data/experiment/bin/windows/contrib/4.2:
#   cannot open URL 'https://bioconductor.org/packages/3.16/data/experiment/bin/windows/contrib/4.2/PACKAGES'"
# installing the source package 'org.At.tair.db'
#
#
# Old packages: 'AnnotationDbi', 'ape', 'aplot', 'BiocFileCache', 'BiocParallel',
# ...

# %%
## 分析组织特异性表达基因Go 富集分析, 将fiber_5DPA和fiber_10DPA 合并在一起
rm=list(ls())
setwd('G:/Billfish/J668_multip_tissue_3D-genome/RNA_seq/tau_gini/tissues_Go')
library(clusterProfiler)
library(org.At.tair.db)
df <- read.table("TSG_TAIRID.bed", sep='\t', header=T)
df_tissues = df[df$tags=='fiber_5DPA' | df$tags=='fiber_10DPA', ]
output_f = paste("fiber_5DPA_10DPA", "_GO.bed", sep="")
df_tissues_gid = df_tissues$TAIR_ID
ego = enrichGO(df_tissues_gid, OrgDb = "org.At.tair.db", keyType="TAIR", ont = "ALL", pAdjustMethod = "BH", pvalueCutoff  = 0.1, qvalueCutoff  = 0.1, readable= TRUE)
write.table(summary(ego), output_f, sep='\t', row.names=FALSE)
# Out:
# Warning message in summary(ego):
# "summary method to convert the object to data.frame is deprecated, please use as.data.frame instead."

# %%
## 分析组织特异性, 且同源高表达基因Go 富集分析
rm=list(ls())
setwd('G:/Billfish/J668_multip_tissue_3D-genome/RNA_seq/tau_gini/tissues_Go/At_Dt_bias')
library(clusterProfiler)
library(org.At.tair.db)
df <- read.table("TSG_hig_bias_tair.bed", sep='\t', header=T)
tissues <- c("anthers", 'cotyledon', 'hypocotyl', 'leaf', 'petals', 'radicle', 'root', 'stem', 'stigma', 'ovules', 'fiber_5DPA', 'fiber_10DPA', 'fiber_20DPA')
for (t in tissues)
{
    for (b in c('BiasA', 'BiasD'))
    {
        df_tissues = df[df$tissue==t&df$bias==b, ]
        output_f = paste(t, '_', b, "_GO.bed", sep="")
        df_tissues_gid = df_tissues$TAIRID
        ego = enrichGO(df_tissues_gid, OrgDb = "org.At.tair.db", keyType="TAIR", ont = "ALL", pAdjustMethod = "BH", pvalueCutoff  = 0.01, qvalueCutoff  = 0.05, readable= TRUE)
        write.table(summary(ego), output_f, sep='\t', row.names=FALSE)
    }

}

# %%
## 分析组织特异性表达基因Go 富集分析
rm=list(ls())
setwd('G:/Billfish/J668_multip_tissue_3D-genome/RNA_seq/tau_gini/tissues_Go/fiber_5DPA_10DPA')
library(clusterProfiler)
library(org.At.tair.db)
df <- read.table("J668_fiber_5DPA.txt", sep='\t', header=T)
#tissues <- c("anthers", 'cotyledon', 'hypocotyl', 'leaf', 'petals', 'radicle', 'root', 'stem', 'stigma', 'ovules', 'fiber_5DPA', 'fiber_10DPA', 'fiber_20DPA')
tissues <- c('fiber_5DPA')
for (t in tissues)
{
    df_tissues = df[df$tags==t, ]
    output_f = paste(as.character(t), "_GO.bed", sep="")
    df_tissues_gid = df_tissues$TAIRID
    ego = enrichGO(df_tissues_gid, OrgDb = "org.At.tair.db", keyType="TAIR", ont = "ALL", pAdjustMethod = "BH", pvalueCutoff  = 0.01, qvalueCutoff  = 0.05, readable= TRUE)
    write.table(summary(ego), output_f, sep='\t', row.names=FALSE)
}
# Out:
# Warning message in summary(ego):
# "summary method to convert the object to data.frame is deprecated, please use as.data.frame instead."

# %%
## 分析组织特异性表达基因Go 富集分析
rm=list(ls())
setwd('G:/Billfish/J668_multip_tissue_3D-genome/RNA_seq/tau_gini/tissues_Go/fiber_5DPA_10DPA')
library(clusterProfiler)
library(org.At.tair.db)
df <- read.table("J668_fiber_10DPA.txt", sep='\t', header=T)
#tissues <- c("anthers", 'cotyledon', 'hypocotyl', 'leaf', 'petals', 'radicle', 'root', 'stem', 'stigma', 'ovules', 'fiber_5DPA', 'fiber_10DPA', 'fiber_20DPA')
tissues <- c('fiber_10DPA')
for (t in tissues)
{
    df_tissues = df[df$tags==t, ]
    #print(df_tissues)
    output_f = paste(as.character(t), "_GO.bed", sep="")
    df_tissues_gid = df_tissues$TAIRID
    ego = enrichGO(df_tissues_gid, OrgDb = "org.At.tair.db", keyType="TAIR", ont = "ALL", pAdjustMethod = "BH", pvalueCutoff  = 0.01, qvalueCutoff  = 0.05, readable= TRUE)
    write.table(summary(ego), output_f, sep='\t', row.names=FALSE)
}
# Out:
# Warning message in summary(ego):
# "summary method to convert the object to data.frame is deprecated, please use as.data.frame instead."

# %%
## 分析组织特异性表达基因Go 富集分析
rm=list(ls())
setwd('G:/Billfish/J668_multip_tissue_3D-genome/RNA_seq/tau_gini/tissues_Go/fiber_5DPA_10DPA')
library(clusterProfiler)
library(org.At.tair.db)
df <- read.table("J668_fiber_5DPA.txt", sep='\t', header=T)
#tissues <- c("anthers", 'cotyledon', 'hypocotyl', 'leaf', 'petals', 'radicle', 'root', 'stem', 'stigma', 'ovules', 'fiber_5DPA', 'fiber_10DPA', 'fiber_20DPA')
tissues <- c('fiber_5DPA')
for (t in tissues)
{
    df_tissues = df[df$tags==t, ]
    #print(df_tissues)
    output_f = paste(as.character(t), "_GO.bed", sep="")
    df_tissues_gid = df_tissues$TAIRID
    ego = enrichGO(df_tissues_gid, OrgDb = "org.At.tair.db", keyType="TAIR", ont = "ALL", pAdjustMethod = "BH", pvalueCutoff  = 0.01, qvalueCutoff  = 0.05, readable= TRUE)
    write.table(summary(ego), output_f, sep='\t', row.names=FALSE)
}
# Out:
# Warning message in summary(ego):
# "summary method to convert the object to data.frame is deprecated, please use as.data.frame instead."

# %%
## 分析纤维发育时期特异性高表达基因的Go term (5DPA)
rm=list(ls())
setwd('G:/Billfish/J668_multip_tissue_3D-genome/RNA_seq/reads/0DPA_vs_5DPA')
library(clusterProfiler)
library(org.At.tair.db)
df <- read.table("5DPA_high_TAIR.bed", sep='\t', header=T)
#tissues <- c("anthers", 'cotyledon', 'hypocotyl', 'leaf', 'petals', 'radicle', 'root', 'stem', 'stigma', 'ovules', 'fiber_5DPA', 'fiber_10DPA', 'fiber_20DPA')
df_gid = df$TAIRID
ego = enrichGO(df_gid, OrgDb = "org.At.tair.db", keyType="TAIR", ont = "ALL", pAdjustMethod = "BH", pvalueCutoff  = 0.00001, qvalueCutoff  = 0.0001, readable= TRUE)
write.table(summary(ego), "5DPA_high_Go.bed", sep='\t', row.names=FALSE)
# Out:
# Warning message in summary(ego):
# "summary method to convert the object to data.frame is deprecated, please use as.data.frame instead."

# %%
## 分析纤维发育时期特异性高表达基因的Go term (5DPA)
rm=list(ls())
setwd('G:/Billfish/J668_multip_tissue_3D-genome/RNA_seq/reads/5DPA_vs_10DPA')
library(clusterProfiler)
library(org.At.tair.db)
df <- read.table("5DPA_high_TAIR.bed", sep='\t', header=T)
#tissues <- c("anthers", 'cotyledon', 'hypocotyl', 'leaf', 'petals', 'radicle', 'root', 'stem', 'stigma', 'ovules', 'fiber_5DPA', 'fiber_10DPA', 'fiber_20DPA')
df_gid = df$TAIRID
ego = enrichGO(df_gid, OrgDb = "org.At.tair.db", keyType="TAIR", ont = "ALL", pAdjustMethod = "BH", pvalueCutoff  = 0.001, qvalueCutoff  = 0.01, readable= TRUE)
write.table(summary(ego), "5DPA_high_Go.bed", sep='\t', row.names=FALSE)
# Out:
# Warning message in summary(ego):
# "summary method to convert the object to data.frame is deprecated, please use as.data.frame instead."

# %%
## 分析纤维发育时期特异性高表达基因的Go term (10DPA)
rm=list(ls())
setwd('G:/Billfish/J668_multip_tissue_3D-genome/RNA_seq/reads/5DPA_vs_10DPA')
library(clusterProfiler)
library(org.At.tair.db)
df <- read.table("10DPA_high_TAIR.bed", sep='\t', header=T)
df_gid = df$TAIRID
ego = enrichGO(df_gid, OrgDb = "org.At.tair.db", keyType="TAIR", ont = "ALL", pAdjustMethod = "BH", pvalueCutoff  = 0.00001, qvalueCutoff  = 0.0001, readable= TRUE)
write.table(summary(ego), "10DPA_high_Go.bed", sep='\t', row.names=FALSE)
# Out:
# Warning message in summary(ego):
# "summary method to convert the object to data.frame is deprecated, please use as.data.frame instead."

# %%
## 分析纤维发育时期特异性高表达基因的Go term (20DPA)
rm=list(ls())
setwd('G:/Billfish/J668_multip_tissue_3D-genome/RNA_seq/reads/10DPA_vs_20DPA')
library(clusterProfiler)
library(org.At.tair.db)
df <- read.table("20DPA_high_TAIR.bed", sep='\t', header=T)
df_gid = df$TAIRID
ego = enrichGO(df_gid, OrgDb = "org.At.tair.db", keyType="TAIR", ont = "ALL", pAdjustMethod = "BH", pvalueCutoff  = 0.00001, qvalueCutoff  = 0.0001, readable= TRUE)
write.table(summary(ego), "20DPA_high_Go.bed", sep='\t', row.names=FALSE)
# Out:
# Warning message in summary(ego):
# "summary method to convert the object to data.frame is deprecated, please use as.data.frame instead."

# %%
## 0DPA vs 5DPA 时5DPA 上调表达基因所富集的Go terms 热图
rm(list = ls())
options(repr.plot.width=15,repr.plot.height=6)
setwd('G:/Billfish/J668_multip_tissue_3D-genome/RNA_seq/reads/0DPA_vs_5DPA')
library(ggplot2)
library(ggpubr)
df <- read.csv('5DPA_high_Go_adjust.bed', sep = '\t', header = T)
fg <- ggplot(df, aes(x=-log10(FDR), y=bioprocess, size=gene_number, color=-log10(FDR)))+
geom_point()+
labs(x=NULL, y=NULL)+
theme(panel.background = element_blank(), 
      panel.grid = element_blank(),
      axis.line=element_line(linetype=1,color="black"),
      #legend.position=c(0.25, 0.7),
      axis.ticks.length = unit(0.5, 'cm'),
      axis.text = element_text(size = 16)
     )+
scale_color_gradient(low="#F0AB97",  high="red")+
scale_size_area(max_size = 15)
fg
ggsave(plot =fg, filename = '5DPA_high_Go_adjust.pdf', height =18, width = 20)
ggsave(plot =fg, filename = '5DPA_high_Go_adjust.png', height =18, width = 20)
# Out:
# plot without title

# %%
## 5DPA vs 10DPA 时10DPA 上调表达基因所富集的Go terms 热图
rm(list = ls())
options(repr.plot.width=15,repr.plot.height=6)
setwd('G:/Billfish/J668_multip_tissue_3D-genome/RNA_seq/reads/5DPA_vs_10DPA')
library(ggplot2)
library(ggpubr)
df <- read.csv('10DPA_high_Go_adjust.bed', sep = '\t', header = T)
fg <- ggplot(df, aes(x=-log10(FDR), y=bioprocess, size=gene_number, color=-log10(FDR)))+
geom_point()+
labs(x=NULL, y=NULL)+
theme(panel.background = element_blank(), 
      panel.grid = element_blank(),
      axis.line=element_line(linetype=1,color="black"),
      #legend.position=c(0.25, 0.7),
      axis.ticks.length = unit(0.5, 'cm'),
      axis.text = element_text(size = 16)
     )+
scale_color_gradient(low="#F0AB97",  high="red")+
scale_size_area(max_size = 15)
fg
ggsave(plot =fg, filename = '10DPA_high_Go_adjust.pdf', height =10, width = 14)
ggsave(plot =fg, filename = '10DPA_high_Go_adjust.png', height =10, width = 14)
# Out:
# plot without title

# %%
## 10DPA vs 20DPA 时20DPA 上调表达基因所富集的Go terms 热图
rm(list = ls())
options(repr.plot.width=15,repr.plot.height=6)
setwd('G:/Billfish/J668_multip_tissue_3D-genome/RNA_seq/reads/10DPA_vs_20DPA')
library(ggplot2)
library(ggpubr)
df <- read.csv('20DPA_high_Go_adjust.bed', sep = '\t', header = T)
fg <- ggplot(df, aes(x=-log10(FDR), y=bioprocess, size=gene_number, color=-log10(FDR)))+
geom_point()+
labs(x=NULL, y=NULL)+
theme(panel.background = element_blank(), 
      panel.grid = element_blank(),
      axis.line=element_line(linetype=1,color="black"),
      #legend.position=c(0.25, 0.7),
      axis.ticks.length = unit(0.5, 'cm'),
      axis.text = element_text(size = 16)
     )+
scale_color_gradient(low="#F0AB97",  high="red")+
scale_size_area(max_size = 15)
fg
ggsave(plot =fg, filename = '20DPA_high_Go_adjust.pdf', height =6, width = 12)
ggsave(plot =fg, filename = '20DPA_high_Go_adjust.png', height =6, width = 12)
# Out:
# plot without title

# %%
## 10DPA vs 20DPA 时20DPA 上调表达基因， 同时与TAU 具有overlap 所富集的Go terms 热图
rm(list = ls())
options(repr.plot.width=15,repr.plot.height=6)
setwd('G:/Billfish/J668_multip_tissue_3D-genome/RNA_seq/reads/10DPA_vs_20DPA')
library(ggplot2)
library(ggpubr)
df <- read.csv('20DPA_up_tau_overlap_TAIR_adjust.bed', sep = '\t', header = T)
fg <- ggplot(df, aes(x=-log10(FDR), y=bioprocess, size=gene_number, color=-log10(FDR)))+
geom_point()+
labs(x=NULL, y=NULL)+
theme(panel.background = element_blank(), 
      panel.grid = element_blank(),
      axis.line=element_line(linetype=1,color="black"),
      #legend.position=c(0.25, 0.7),
      axis.ticks.length = unit(0.5, 'cm'),
      axis.text = element_text(size = 16)
     )+
scale_color_gradient(low="#F0AB97",  high="red")+
scale_size_area(max_size = 15)
fg
ggsave(plot =fg, filename = '20DPA_up_tau_overlap_TAIR_adjust.pdf', height =6, width = 12)
ggsave(plot =fg, filename = '20DPA_up_tau_overlap_TAIR_adjust.png', height =6, width = 12)
# Out:
# plot without title

# %%
## 分析20DPA 相比于10DPA 高表达，同时被TAU计算认为其具有组织特异性基因做Go terms 分析
rm=list(ls())
setwd('G:/Billfish/J668_multip_tissue_3D-genome/RNA_seq/reads/10DPA_vs_20DPA')
library(clusterProfiler)
library(org.At.tair.db)
df <- read.table("20DPA_up_tau_overlap_TAIR.bed", sep='\t', header=T)
#tissues <- c("anthers", 'cotyledon', 'hypocotyl', 'leaf', 'petals', 'radicle', 'root', 'stem', 'stigma', 'ovules', 'fiber_5DPA', 'fiber_10DPA', 'fiber_20DPA')
df_gid = df$TAIRID
ego = enrichGO(df_gid, OrgDb = "org.At.tair.db", keyType="TAIR", ont = "ALL", pAdjustMethod = "BH", pvalueCutoff  = 0.001, qvalueCutoff  = 0.01, readable= TRUE)
write.table(summary(ego), "20DPA_up_tau_overlap_TAIR_GO.bed", sep='\t', row.names=FALSE)
# Out:
# Warning message in summary(ego):
# "summary method to convert the object to data.frame is deprecated, please use as.data.frame instead."

# %%
## 分析5DPA 相比于0DPA 高表达，同时被TAU计算认为其具有组织特异性基因做Go terms 分析
rm=list(ls())
setwd('G:/Billfish/J668_multip_tissue_3D-genome/RNA_seq/reads/0DPA_vs_5DPA')
library(clusterProfiler)
library(org.At.tair.db)
df <- read.table("5DPA_up_tau_overlap_TAIR.bed", sep='\t', header=T)
df_gid = df$TAIRID
ego = enrichGO(df_gid, OrgDb = "org.At.tair.db", keyType="TAIR", ont = "ALL", pAdjustMethod = "BH", pvalueCutoff  = 0.001, qvalueCutoff  = 0.01, readable= TRUE)
write.table(summary(ego), "5DPA_up_tau_overlap_TAIR_GO.bed", sep='\t', row.names=FALSE)
# Out:
# Warning message in summary(ego):
# "summary method to convert the object to data.frame is deprecated, please use as.data.frame instead."

# %%
## 分析10DPA 相比于5DPA 高表达，同时被TAU计算认为其具有组织特异性基因做Go terms 分析
rm=list(ls())
setwd('G:/Billfish/J668_multip_tissue_3D-genome/RNA_seq/reads/5DPA_vs_10DPA')
library(clusterProfiler)
library(org.At.tair.db)
df <- read.table("10DPA_up_tau_overlap_TAIR.bed", sep='\t', header=T)
df_gid = df$TAIRID
ego = enrichGO(df_gid, OrgDb = "org.At.tair.db", keyType="TAIR", ont = "ALL", pAdjustMethod = "BH", pvalueCutoff  = 0.001, qvalueCutoff  = 0.01, readable= TRUE)
write.table(summary(ego), "10DPA_up_tau_overlap_TAIR_GO.bed", sep='\t', row.names=FALSE)
# Out:
# Warning message in summary(ego):
# "summary method to convert the object to data.frame is deprecated, please use as.data.frame instead."

# %%
rm=list(ls())
setwd('G:/Billfish/J668_multip_tissue_3D-genome/RNA_seq/reads/5DPA_vs_10DPA')
library(clusterProfiler)
library(org.At.tair.db)
df <- read.table("10DPA_up_tau_overlap_TAIR.bed", sep='\t', header=T)
df_gid = df$TAIRID
ego = enrichGO(df_gid, OrgDb = "org.At.tair.db", keyType="TAIR", ont = "ALL", pAdjustMethod = "BH", pvalueCutoff  = 0.001, qvalueCutoff  = 0.01, readable= TRUE)

# %%
BiocManager::install("ReactomePA")
# Out:
# Failed to start the Kernel.
#
# Error in loadNamespace(i, c(lib.loc, .libPaths()), versionCheck = vI[[i]]) :
#
#   namespace 'rlang' 1.0.4 is already loaded, but >= 1.0.5 is required
#
# Calls: loadNamespace ... namespaceImport -> loadNamespace -> namespaceImport -> loadNamespace
#
# Execution halted.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
