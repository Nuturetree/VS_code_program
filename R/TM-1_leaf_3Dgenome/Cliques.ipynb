# %%
## test
df = read.table('F:/TM-1_leaf_3D-genome/HiC/TAD/Cliques/Ghir_A01.spline_pass2.significances.txt', sep = '\t', header = T)
df['pvalues'] = t.test(df$cotactCount)
df
# Out:
# Warning message in mean.default(x):
# "参数不是数值也不是逻辑值：回覆NA"
# Error in var(x): 'x'为NULL
# Traceback:
#
# 1. t.test(df$cotactCount)
# 2. t.test.default(df$cotactCount)
# 3. var(x)

# %%
wilcox.test(c(1, 3,4, 5, 6, 7, 8, 9, 10))
# Out:
# 	Wilcoxon signed rank exact test
#
# data:  c(1, 3, 4, 5, 6, 7, 8, 9, 10)
# V = 45, p-value = 0.003906
# alternative hypothesis: true location is not equal to 0

# %%
require("magrittr")
matrix(1:9, ncol = 3) %>% apply(2, t.test)
# Out:
# [[1]]
#
# 	One Sample t-test
#
# data:  newX[, i]
# t = 3.4641, df = 2, p-value = 0.07418
# alternative hypothesis: true mean is not equal to 0
# 95 percent confidence interval:
#  -0.4841377  4.4841377
# sample estimates:
# mean of x
#         2
#
#
# [[2]]
#
# 	One Sample t-test
#
# data:  newX[, i]
# t = 8.6603, df = 2, p-value = 0.01307
# alternative hypothesis: true mean is not equal to 0
# 95 percent confidence interval:
#  2.515862 7.484138
# sample estimates:
# mean of x
#         5
#
#
# [[3]]
#
# 	One Sample t-test
#
# data:  newX[, i]
# t = 13.856, df = 2, p-value = 0.005168
# alternative hypothesis: true mean is not equal to 0
# 95 percent confidence interval:
#   5.515862 10.484138
# sample estimates:
# mean of x
#         8
