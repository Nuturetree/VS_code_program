# %%
## HiC 和PoreC insulation 上的一致性
rm(list=ls())
setwd('F:/TM-1_leaf_3D-genome/Pore-C/TAD/is_relevance') # nolint
library(ggplot2)
library(ggpubr)
loop_data <- read.csv('is_hic_porec_A04.bed', sep = '\t', header = T) 
loop <- ggplot(loop_data, aes(x=porec_normal, y=hic_normal)) +
  stat_density2d(aes(fill = ..level..), geom = 'polygon')+
  geom_density_2d()+
  labs(x='Hi-C', y='Pore-C') + 
  #stat_cor(data=loop_data, method = "spearman")+
  # #geom_smooth(se = FALSE) +
  #facet_grid(days~.)+
  # #coord_cartesian(xlim = c(2.7,10.3))+
  #scale_x_continuous(breaks = seq(0,6,1))+
  #scale_y_continuous(breaks = seq(0, 6,1))+
  theme(
    panel.background = element_blank(), #去掉背景色
    panel.grid.major = element_blank(), #去掉网格
    panel.grid.minor = element_blank(),
    axis.line=element_line(linetype=1,color="black"),  #添加轴线
    #legend.position=c(0.1,0.8), #调整图例,
    axis.ticks.length = unit(0.25, 'cm'),
    #legend.position='none'
  )+
  scale_fill_gradient(low='#F2EAD0', high = '#F24607')
loop
ggsave(plot =loop, filename = 'is_hic_porec_A04_density2.pdf', height =4, width = 4)
# Out:
# plot without title

# %%
##分析TAD 互作在染色体上的分布
setwd('F:/TM-1_leaf_3D-genome/Pore-C/TAD/TAD_interaction') # nolint
rm(list = ls())
library(ggplot2)
df <- read.csv("Dt.txt", sep = "\t", header = T)
all_chr = c("Ghir_A01", 'Ghir_A02', 'Ghir_A03', 'Ghir_A04', 'Ghir_A05', 'Ghir_A06', 'Ghir_A07', 'Ghir_A08', 'Ghir_A09', 'Ghir_A10', 'Ghir_A11', 'Ghir_A12', 'Ghir_A13','Ghir_D01', 'Ghir_D02', 'Ghir_D03', 'Ghir_D04', 'Ghir_D05', 'Ghir_D06', 'Ghir_D07', 'Ghir_D08', 'Ghir_D09', 'Ghir_D10', 'Ghir_D11', 'Ghir_D12', 'Ghir_D13')
#c = "Ghir_D13"
#df_chr <- df[df$chrs == c, ]
#output_f = paste(c, ".pdf")
p <- ggplot(df, aes(x = position)) + geom_density(aes(y = stat(count)))
ggsave(plot = p, filename = "Dt.pdf", height =4, width = 4)

# %%
##分析TAD 互作在染色体上的分布 第二版本
setwd('F:/TM-1_leaf_3D-genome/Pore-C/TAD/TAD_cliques/chr') # nolint
rm(list = ls())
library(ggplot2)
chrs_tags = "Ghir_D13"
input_f = paste(chrs_tags, "_cliques_tags.txt", sep="")
print(input_f)
output_f = paste(chrs_tags, "_cliques_tags.pdf")
df <- read.csv(input_f, sep = "\t", header = T)
df_need <- df[df$tags != "e", ]
#all_chr = c("Ghir_A01", 'Ghir_A02', 'Ghir_A03', 'Ghir_A04', 'Ghir_A05', 'Ghir_A06', 'Ghir_A07', 'Ghir_A08', 'Ghir_A09', 'Ghir_A10', 'Ghir_A11', 'Ghir_A12', 'Ghir_A13','Ghir_D01', 'Ghir_D02', 'Ghir_D03', 'Ghir_D04', 'Ghir_D05', 'Ghir_D06', 'Ghir_D07', 'Ghir_D08', 'Ghir_D09', 'Ghir_D10', 'Ghir_D11', 'Ghir_D12', 'Ghir_D13')
#c = "Ghir_D13"
#df_chr <- df[df$chrs == c, ]
#output_f = paste(c, ".pdf")
p <- ggplot(df_need, aes(x = s, color = tags)) +
    geom_density(size = 2) +
    scale_color_manual(values = c("#ACD7E8", '#C3E8C9', "#FDD5C0", '#F46161'))+
    theme(
    panel.background = element_blank(), #去掉背景色
    panel.grid.major = element_blank(), #去掉网格
    panel.grid.minor = element_blank(),
    axis.line = element_line(linetype = 1,color = "black"),  #添加轴线
    #legend.position=c(0.1,0.8), #调整图例,
    axis.ticks.length = unit(0.25, 'cm'),
    #legend.position='none'
  )
p
ggsave(plot = p, filename = output_f, height = 4, width = 10)
# Out:
# [1] "Ghir_D13_cliques_tags.txt"
# plot without title
