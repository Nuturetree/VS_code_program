# %%
from pprint import pprint as pp
import circlify
data = [
        {'id':'all', 'datum':19836, 'children':[
            {'id':'keep_bias_At', 'datum':184}, {'id':'keep_bias_Dt', 'datum':205}, 
            {'id':'one_bias_At', 'datum': 2146, 'children':[323, 136, 117, 67, 85, 91, 96, 63, 229, 276, 253, 225],},
            {'id':'one_bias_At', 'datum': 2101, 'children':[324,159,114,92,80,102,113,67,265,250,255,218],},]},
        # 0.5, {'id': 'a2', 'datum': 0.5},
        # {'id': 'a0', 'datum': 0.8, 'children': [0.3, 0.2, 0.2, 0.1], },
        # {'id': 'a1', 'datum': 0.1, 'children': [
        #     {'id': 'a1_1', 'datum': 0.05}, {'datum': 0.04}, 0.01],
        # },
    ]
circles = circlify.circlify(data, show_enclosure=True)
pp(circles)
# 展示结果
circlify.bubbles(circles)
# Out:
# [Circle(x=0.0, y=0.0, r=1.0, level=0, ex=None),
#  Circle(x=0.0, y=0.0, r=1.0, level=1, ex={'id': 'all', 'datum': 19836, 'children': [{'id': 'keep_bias_At', 'datum': 184}, {'id': 'keep_bias_Dt', 'datum': 205}, {'id': 'one_bias_At', 'datum': 2146, 'children': [323, 136, 117, 67, 85, 91, 96, 63, 229, 276, 253, 225]}, {'id': 'one_bias_At', 'datum': 2101, 'children': [324, 159, 114, 92, 80, 102, 113, 67, 265, 250, 255, 218]}]}),
#  Circle(x=-0.006077784639060425, y=-0.4109034370243483, r=0.14718341595328283, level=2, ex={'id': 'keep_bias_At', 'datum': 184}),
#  Circle(x=-0.006121080890106744, y=0.42365778302826723, r=0.15535559448921282, level=2, ex={'id': 'keep_bias_Dt', 'datum': 205}),
#  Circle(x=-0.5026490030079497, y=0.0, r=0.4973509969920504, level=2, ex={'id': 'one_bias_At', 'datum': 2101, 'children': [324, 159, 114, 92, 80, 102, 113, 67, 265, 250, 255, 218]}),
# ...

# %%
from pprint import pprint as pp
import circlify
data = [
        {'id':'all', 'datum':19836, 'children':[
            {'id':'keep_bias_At', 'datum':363}, {'id':'keep_bias_Dt', 'datum':396}, 
            {'id':'one_bias_At', 'datum': 1751, 'children':[298, 120, 104, 55, 78, 87, 82, 43, 215, 253, 221, 195],},
            {'id':'one_bias_At', 'datum': 1753, 'children':[292,125,90,70,70,93,80,39,228,216,256,194],},]},
        # 0.5, {'id': 'a2', 'datum': 0.5},
        # {'id': 'a0', 'datum': 0.8, 'children': [0.3, 0.2, 0.2, 0.1], },
        # {'id': 'a1', 'datum': 0.1, 'children': [
        #     {'id': 'a1_1', 'datum': 0.05}, {'datum': 0.04}, 0.01],
        # },
    ]
circles = circlify.circlify(data, show_enclosure=True)
pp(circles)
# 展示结果
circlify.bubbles(circles)
