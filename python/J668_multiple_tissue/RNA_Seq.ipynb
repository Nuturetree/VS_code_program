# %%
import pandas as pd
df = pd.read_csv("F:/J668_multip_tissue_3D-genome/RNA_seq/PCA/J668_all_tissue_FPKM.txt", sep='\t')
dz = df.groupby(by=['GeneId'], as_index=False)['anthers1'].count()
print(dz.query("anthers1==2"))
# Out:
#                 GeneId  anthers1
# 10767  Ghir_A05G024510         2

# %%
# Out:
# (8, 70198)
