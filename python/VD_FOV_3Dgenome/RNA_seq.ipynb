# %%
## 整合差异表达基因 时期动态变化桑基图格式
import pandas as pd
# df_1min = pd.read_csv('F:/VD_FOV_3Dgenome/RNA_Seq/DEG/J668_mock_Fov7/J668_mock_Fov7_1min_DEG.bed', sep='\t')
# df_5min = pd.read_csv('F:/VD_FOV_3Dgenome/RNA_Seq/DEG/J668_mock_Fov7/J668_mock_Fov7_5min_DEG.bed', sep='\t')
# df_10min = pd.read_csv('F:/VD_FOV_3Dgenome/RNA_Seq/DEG/J668_mock_Fov7/J668_mock_Fov7_10min_DEG.bed', sep='\t')
# df_30min = pd.read_csv('F:/VD_FOV_3Dgenome/RNA_Seq/DEG/J668_mock_Fov7/J668_mock_Fov7_30min_DEG.bed', sep='\t')
# df_90min = pd.read_csv('F:/VD_FOV_3Dgenome/RNA_Seq/DEG/J668_mock_Fov7/J668_mock_Fov7_90min_DEG.bed', sep='\t')
# df_180min = pd.read_csv('F:/VD_FOV_3Dgenome/RNA_Seq/DEG/J668_mock_Fov7/J668_mock_Fov7_180min_DEG.bed', sep='\t')
# df_12h = pd.read_csv('F:/VD_FOV_3Dgenome/RNA_Seq/DEG/J668_mock_Fov7/J668_mock_Fov7_12h_DEG.bed', sep='\t')

# df_1min = pd.read_csv('F:/VD_FOV_3Dgenome/RNA_Seq/DEG/J668_mock_v991/J668_mock_v991_1min_DEG.bed', sep='\t')
# df_5min = pd.read_csv('F:/VD_FOV_3Dgenome/RNA_Seq/DEG/J668_mock_v991/J668_mock_v991_5min_DEG.bed', sep='\t')
# df_10min = pd.read_csv('F:/VD_FOV_3Dgenome/RNA_Seq/DEG/J668_mock_v991/J668_mock_v991_10min_DEG.bed', sep='\t')
# df_30min = pd.read_csv('F:/VD_FOV_3Dgenome/RNA_Seq/DEG/J668_mock_v991/J668_mock_v991_30min_DEG.bed', sep='\t')
# df_90min = pd.read_csv('F:/VD_FOV_3Dgenome/RNA_Seq/DEG/J668_mock_v991/J668_mock_v991_90min_DEG.bed', sep='\t')
# df_180min = pd.read_csv('F:/VD_FOV_3Dgenome/RNA_Seq/DEG/J668_mock_v991/J668_mock_v991_180min_DEG.bed', sep='\t')
# df_12h = pd.read_csv('F:/VD_FOV_3Dgenome/RNA_Seq/DEG/J668_mock_v991/J668_mock_v991_12h_DEG.bed', sep='\t')
df_1min = pd.read_csv('F:/VD_FOV_3Dgenome/RNA_Seq/DEG/glr19_mock_Fov7/glr19_mock_Fov7_1min_DEG.bed', sep='\t')
df_5min = pd.read_csv('F:/VD_FOV_3Dgenome/RNA_Seq/DEG/glr19_mock_Fov7/glr19_mock_Fov7_5min_DEG.bed', sep='\t')
df_10min = pd.read_csv('F:/VD_FOV_3Dgenome/RNA_Seq/DEG/glr19_mock_Fov7/glr19_mock_Fov7_10min_DEG.bed', sep='\t')
df_30min = pd.read_csv('F:/VD_FOV_3Dgenome/RNA_Seq/DEG/glr19_mock_Fov7/glr19_mock_Fov7_30min_DEG.bed', sep='\t')
df_90min = pd.read_csv('F:/VD_FOV_3Dgenome/RNA_Seq/DEG/glr19_mock_Fov7/glr19_mock_Fov7_90min_DEG.bed', sep='\t')
df_180min = pd.read_csv('F:/VD_FOV_3Dgenome/RNA_Seq/DEG/glr19_mock_Fov7/glr19_mock_Fov7_180min_DEG.bed', sep='\t')
df_12h = pd.read_csv('F:/VD_FOV_3Dgenome/RNA_Seq/DEG/glr19_mock_Fov7/glr19_mock_Fov7_12h_DEG.bed', sep='\t')

## change format
df_1min = df_1min[['GeneId', 'sig']].copy()
df_5min = df_5min[['GeneId', 'sig']].copy()
df_10min = df_10min[['GeneId', 'sig']].copy()
df_30min = df_30min[['GeneId', 'sig']].copy()
df_90min = df_90min[['GeneId', 'sig']].copy()
df_180min = df_180min[['GeneId', 'sig']].copy()
df_12h = df_12h[['GeneId', 'sig']].copy()

# %%
df_1min.columns = ['GeneId', 'min1']
df_5min.columns = ['GeneId', 'min5']
df_10min.columns = ['GeneId', 'min10']
df_30min.columns = ['GeneId', 'min30']
df_90min.columns = ['GeneId', 'min90']
df_180min.columns = ['GeneId', 'min180']
df_12h.columns = ['GeneId', 'h12']

## merge
df_one = pd.merge(df_1min, df_5min, how='outer', on=['GeneId'])
df_two = pd.merge(df_one, df_10min, how='outer', on=['GeneId'])
df_three = pd.merge(df_two, df_30min, how='outer', on=['GeneId'])
df_four = pd.merge(df_three, df_90min, how='outer', on=['GeneId'])
df_five = pd.merge(df_four, df_180min, how='outer', on=['GeneId'])
df_five.fillna('Not', inplace=True)
df_six = pd.merge(df_five, df_12h, how='outer', on=['GeneId'])
df_six.fillna('Not', inplace=True)
#result
#df_out = df_five.groupby(by=['min1', 'min5', 'min10', 'min30', 'min90', 'min180'], as_index=False)['GeneId'].count()
#df_out.to_csv('F:/VD_FOV_3Dgenome/RNA_Seq/DEG/J668_mock_Fov7/J668_mock_Fov7_snaky_format_180.txt', sep='\t',index=False)
#print(df_out)

# %%
## 寻找稳定的差异表达基因动态变化过程
df_out = df_six.groupby(by=['min1', 'min5', 'min10', 'min30', 'min90', 'min180', 'h12'], as_index=False)['GeneId'].count()

df_out['tags']= df_out['min1'] + df_out['min5'] + df_out['min10'] +df_out['min30'] +df_out['min90'] + df_out['h12']
print(df_out.shape)
import re
patern = re.compile('Not')
df_result = pd.DataFrame(columns=['min1', 'min5', 'min10', 'min30', 'min90', 'min180', 'h12', 'number'])
i=0
for index, row in df_out.iterrows():
    t = row['tags']
    l = len(patern.findall(t))
    if l<4:
        df_result.loc[i, :] = [row['min1'], row['min5'], row['min10'], row['min30'], row['min90'], row['min180'], row['h12'], row['GeneId']]
        i+=1
print(df_result.shape)
#df_result.to_csv('F:/VD_FOV_3Dgenome/RNA_Seq/DEG/J668_mock_Fov7/J668_mock_Fov7_snaky_format_not.txt', sep='\t', index=False)
#df_result.to_csv('F:/VD_FOV_3Dgenome/RNA_Seq/DEG/J668_mock_v991/J668_mock_v991_snaky_format_not.txt', sep='\t', index=False)
df_result.to_csv('F:/VD_FOV_3Dgenome/RNA_Seq/DEG/glr19_mock_Fov7/glr19_mock_Fov7_snaky_format_not.txt', sep='\t', index=False)
# Out:
# (492, 9)
# (327, 8)

# %%
## 将差异基因ID转换为拟南芥ID
times = ['1min', '5min', '10min', '30min', '90min', '180min', '12h']
df_homo = pd.read_csv('F:/VD_FOV_3Dgenome/RNA_Seq/Gh_vs_Arabidopsis.txt', sep='\t')
for t in times:
    #Dir = 'F:/VD_FOV_3Dgenome/RNA_Seq/DEG/J668_mock_Fov7/J668_mock_Fov7'
    #Dir = 'F:/VD_FOV_3Dgenome/RNA_Seq/DEG/J668_mock_v991/J668_mock_v991'
    Dir = 'F:/VD_FOV_3Dgenome/RNA_Seq/DEG/glr19_mock_Fov7/glr19_mock_Fov7'
    input_n = "{0}_{1}_DEG.bed".format(Dir, t)
    output_n = "{0}_{1}_DEG_geneid.txt".format(Dir, t)
    df = pd.read_csv(input_n, sep='\t')
    df_out = pd.merge(df, df_homo, how='inner', on='GeneId')
    df_out.drop_duplicates(keep='first', subset=['AtId'], inplace=True)
    df_out.to_csv(output_n, sep='\t', index=False, columns=['GeneId', 'AtId'])

# %%
import pandas as pd
import numpy as np
## 将GO term 注释文件整合为一个文件
times = ['1min', '5min', '10min', '30min', '90min', '180min', '12h']
Dir = 'F:/VD_FOV_3Dgenome/RNA_Seq/DEG/J668_mock_Fov7/J668_mock_Fov7'
#Dir = 'F:/VD_FOV_3Dgenome/RNA_Seq/DEG/J668_mock_v991/J668_mock_v991'
#Dir = 'F:/VD_FOV_3Dgenome/RNA_Seq/DEG/glr19_mock_Fov7/glr19_mock_Fov7'
df_out = pd.DataFrame()
#output_n = "{0}_all_DEG_GO_top10.txt".format(Dir)
output_n = "{0}_all_DEG_GO.txt".format(Dir)
for t in times:
    Dir = 'F:/VD_FOV_3Dgenome/RNA_Seq/DEG/J668_mock_Fov7/J668_mock_Fov7'
    #Dir = 'F:/VD_FOV_3Dgenome/RNA_Seq/DEG/J668_mock_v991/J668_mock_v991'
    #Dir = 'F:/VD_FOV_3Dgenome/RNA_Seq/DEG/glr19_mock_Fov7/glr19_mock_Fov7'
    input_n = "{0}_{1}_DEG_GO.txt".format(Dir, t)
    df = pd.read_csv(input_n, sep='\t')
    name1, name2 = "Count_"+t, "qvalue_"+t
    #df_tmp = df[['ID', 'Description', 'Count', 'qvalue']].copy()
    #df_tmp.columns = ['ID', 'Description', name1, name2]
    df_tmp = df[['ID', 'Description',  'qvalue']].copy()
    df_tmp.columns = ['ID', 'Description', name2]
    ## 选择前10个term做分析
    #df_tmp = df_tmp.iloc[0:10, :].copy()
    #print(df_tmp)
    df_tmp[name2] = -np.log10(df_tmp[name2])
    if df_out.shape[0]==0:
        df_out = df_tmp.copy()
    else:
        df_out = pd.merge(df_out, df_tmp, how='outer', on=['ID', 'Description'])
df_out.fillna("s", inplace=True)
df_out.to_csv(output_n, sep='\t', index=False)

# %%
### 分析 J668 mock vs V991 和 J668 mock vs Fov7 和 glr19 mock vs Fov7 置信度前20的Go term 合集
import pandas as pd
Dirs = "G:/VD_FOV_3Dgenome/RNA_Seq/DEG/"
filename = ['J668_mock_v991', 'J668_mock_Fov7', 'glr19_mock_Fov7']
times = ['1min', '5min', '10min', '30min', '90min', '180min', '12h']

## find top20 Go ID
df_GoID = pd.DataFrame(columns = ['ID','Description'])
for f in filename:
    for t in times:
        input_f = "{0}{1}/all_go_term/{1}_{2}_DEG_GO.txt".format(Dirs, f, t)
        df_input = pd.read_csv(input_f, sep='\t')
        df_input.sort_values(by=['p.adjust'], inplace=True)
        df_input.reset_index(drop=True, inplace=True)
        ## Top 20
        #df_input_top20 = df_input.iloc[0:20, :][['ID', 'Description']]
        #df_GoID = df_GoID.append(df_input_top20, ignore_index=True)
        ## all 
        df_input_all = df_input[['ID', 'Description']]
        df_GoID = df_GoID.append(df_input_all, ignore_index=True)
        df_GoID.drop_duplicates(keep='first', inplace=True)
print(df_GoID.shape[0])

## find top 20 Go term
df_result = pd.DataFrame() 
for f in filename:
    df_tmp1 = pd.DataFrame()
    for t in times:
        input_f = "{0}{1}/all_go_term/{1}_{2}_DEG_GO.txt".format(Dirs, f, t)
        df_input = pd.read_csv(input_f, sep='\t')
        df_input = df_input[['ID', 'GeneRatio', 'p.adjust', 'Description']].copy()
        df_input[['GeneNumber', 'GeneAllNumber']] = df_input['GeneRatio'].str.split('/', expand=True)
        df_input = df_input[['ID', 'GeneNumber', 'p.adjust', 'Description']].copy()
        #df_input['times'] = [t]*df_input.shape[0]
        df_Goterm = pd.merge(df_GoID, df_input, how='left', on=['ID'])
        df_Goterm['times'] = [t]*df_Goterm.shape[0]
        #print(df_Goterm.shape[0])
        df_tmp1 = df_tmp1.append(df_Goterm, ignore_index=True)
        #print(df_tmp1.shape[0])
    df_tmp1['tags'] = [f]*df_tmp1.shape[0]
    df_result = df_result.append(df_tmp1, ignore_index=True)
## top 20 
#df_result.to_csv("G:/VD_FOV_3Dgenome/RNA_Seq/DEG/Go_terms/top20/J668_mock_fov7_v991_glr19.txt", sep='\t', index=False)
## top all
df_result.to_csv("G:/VD_FOV_3Dgenome/RNA_Seq/DEG/Go_terms/all/J668_mock_fov7_v991_glr19.txt", sep='\t', index=False)
# Out:
# 792

# %%
### 选择与ca 相关的差异表达基因
import pandas as pd
#! 整合基因
def concat_f(dir_path, names):
    df_return = pd.DataFrame()
    for i in ['1min', '5min', '10min', '30min', '90min', '180min', '12h']:
        file_name = "{0}/{1}_{2}_DEG_GO.txt".format(dir_path, names, i) 
        #print(file_name)       
        df = pd.read_csv(file_name, sep='\t')
        df['days'] = [i]*df.shape[0]
        if df_return.shape[0] == 0:
            df_return = df.copy()
        else:
            df_return = df_return.append(df, ignore_index=True)
    return df_return
#! 得到与某一信号通路相关的基因id
def target_genes(key_word, dir_path, names):
    df = concat_f(dir_path, names)
    df_need = df.query("Description.str.contains(@key_word)", engine="python")
    print(df_need[['days', 'Description']])
    need_gid = list(set("/".join(df_need["geneID"].tolist()).split('/')))
    df_return = pd.DataFrame({'gid':need_gid})
    out_file = "{0}/{1}_{2}_DEGid.txt".format(dir_path, names, key_word)
   # df_return.to_csv(out_file, sep='\t', index=False, header=False)
#! 分时期写出与Ca term 所包含的基因数目,以及基因的表达量
def time_target_genes(key_word, dir_path, names):
    df = concat_f(dir_path, names)
    df_tmp = df.query("Description.str.contains(@key_word)", engine="python")[['days', 'ONTOLOGY', 'ID', 'Description', 'geneID']]
    #print(df_need)
    df_tmp1 = df_tmp[['days', 'ONTOLOGY', 'ID', "Description"]]
    df_tmp2 = df_tmp['geneID'].str.split("/", expand=True)
    df_need = pd.concat([df_tmp1, df_tmp2], axis=1)
    df_out = df_need.melt(id_vars = ['days', 'ONTOLOGY', 'ID', "Description"])[['days', 'ONTOLOGY', 'ID', "Description", 'value']]
    df_out2 = df_out.drop_duplicates(keep='first')
    df_result1 = df_out2.query("(value != 'NA')").copy()
    df_result = df_result1.query("(value != 'None')").copy()
    df_result.dropna(inplace=True)
    out_file = "{0}/time_target_gene/{1}_{2}_Attags.txt".format(dir_path, names, key_word)
    df_result.to_csv(out_file, sep='\t', index=False)
#* calcium
#target_genes('calcium', 'G:/VD_FOV_3Dgenome/RNA_Seq/DEG/J668_mock_Fov7/all_go_term', 'J668_mock_Fov7')
#target_genes('calcium', 'G:/VD_FOV_3Dgenome/RNA_Seq/DEG/J668_mock_v991/all_go_term', 'J668_mock_v991')
#target_genes('calcium', 'G:/VD_FOV_3Dgenome/RNA_Seq/DEG/glr19_mock_Fov7/all_go_term', 'glr19_mock_Fov7')
#* reactive oxygen
#target_genes('reactive oxygen', 'G:/VD_FOV_3Dgenome/RNA_Seq/DEG/J668_mock_Fov7/all_go_term', 'J668_mock_Fov7')
#target_genes('reactive oxygen', 'G:/VD_FOV_3Dgenome/RNA_Seq/DEG/J668_mock_v991/all_go_term', 'J668_mock_v991')
#target_genes('reactive oxygen', 'G:/VD_FOV_3Dgenome/RNA_Seq/DEG/glr19_mock_Fov7/all_go_term', 'glr19_mock_Fov7')

#* calcium
time_target_genes('calcium', 'G:/VD_FOV_3Dgenome/RNA_Seq/DEG/J668_mock_Fov7/all_go_term', 'J668_mock_Fov7')
time_target_genes('calcium', 'G:/VD_FOV_3Dgenome/RNA_Seq/DEG/J668_mock_v991/all_go_term', 'J668_mock_v991')
time_target_genes('calcium', 'G:/VD_FOV_3Dgenome/RNA_Seq/DEG/glr19_mock_Fov7/all_go_term', 'glr19_mock_Fov7')

# %%
### 分析莫一特定Go term 相关的基因 其动态变化过程
import pandas as pd
#! 根据拟南芥id 找到棉花所对应的基因id
def id_pairs(Go_id_file):
    df = pd.read_csv(Go_id_file, sep='\t')
    df_pairs = pd.read_csv('F:/VD_FOV_3Dgenome/RNA_Seq/Gh_vs_Arabidopsis.txt', sep='\t', names = ['GeneId', 'TAIR'])
    df_return = pd.merge(df_pairs, df, how='inner', on='TAIR')
    #print(df_return)
    df_return = pd.DataFrame(df_return['GeneId'])
    #print(df_return.shape[0])
    return df_return

#! 将所有差异基因整合为一个文件
def concat_f(dir_path, names):
    df_return = pd.DataFrame()
    for i in ['1min', '5min', '10min', '30min', '90min', '180min', '12h']:
        file_name = "{0}/{1}_{2}_DEG.bed".format(dir_path, names, i) 
        #print(file_name)       
        df = pd.read_csv(file_name, sep='\t')
        df['days'] = [i]*df.shape[0]
        if df_return.shape[0] == 0:
            df_return = df.copy()
        else:
            df_return = df_return.append(df, ignore_index=True)
    return df_return

#! 整合文件成为桑基图格式
def snaky_format(df):
    df_1min, df_5min, df_10min, df_30min, df_90min, df_180min, df_12h = df.query("days=='1min'")[['GeneId', 'sig']], df.query("days=='5min'")[['GeneId', 'sig']], df.query("days=='10min'")[['GeneId', 'sig']], df.query("days=='30min'")[['GeneId', 'sig']], df.query("days=='90min'")[['GeneId', 'sig']], df.query("days=='180min'")[['GeneId', 'sig']], df.query("days=='12h'")[['GeneId', 'sig']]
    df_1min.columns =['GeneId', 'min1']
    df_5min.columns =['GeneId', 'min5']
    df_10min.columns =['GeneId', 'min10']
    df_30min.columns =['GeneId', 'min30']
    df_90min.columns =['GeneId', 'min90']
    df_180min.columns =['GeneId', 'min180']
    #df_12h.columns =['GeneId', 'h12']
    df_tmp = df_1min.copy()
    for df_tz in [ df_5min, df_10min, df_30min, df_90min, df_180min]:
        df_tmp = df_tmp.merge(df_tz, how='outer', on='GeneId')
    # df_tmp.fillna("stable", inplace=True)
    # df_return = df_tmp.groupby(by=['1min', '5min', '10min', '30min', '90min', '180min', '12h'], as_index=False)['GeneId'].count()
    # df_return.rename(columns={'GeneId':'number'}, inplace=True)
    ## 去掉12h 这个异常的时间节点
    #df_no_12h = df_tmp[['GeneId', 'min1', 'min5', 'min10', 'min30', 'min90', 'min180']].copy()
    df_tmp.dropna(how='all', inplace=True)
    df_tmp.fillna('stable', inplace=True)  
    df_return = df_tmp.groupby(by=['min1', 'min5', 'min10', 'min30', 'min90', 'min180'], as_index=False)['GeneId'].count()
    df_return.rename(columns={'GeneId':'number'}, inplace=True)
    df_return2 = pd.DataFrame(df_tmp['GeneId'])
    #print(df_return)
    return df_return, df_return2

# #!  分析每个基因的差异倍数
# def TPM_format(df):
#     for i in 

#! 分析go term 所包含的基因，对应的差异表达情况
def Go_gene_DEG(dir_path, names, GO_id_file, outfile1, outfile2):
    df_go_id = id_pairs(GO_id_file)
    df_DEG_gene = concat_f(dir_path, names)
    df_tmp = pd.merge(df_DEG_gene, df_go_id, how='inner', on='GeneId')
    df_tmp = df_tmp[['GeneId', 'sig', 'days']]
    df_return, df_return2 = snaky_format(df_tmp)
    df_return.to_csv(outfile1, sep='\t', index=False)
    df_return2.to_csv(outfile2, sep='\t', index=False)

#* calcium
# #! glr19_mock_Fov7
# Dir_path = 'F:/VD_FOV_3Dgenome/RNA_Seq/DEG/glr19_mock_Fov7'
# Names = "glr19_mock_Fov7"
# GO_id_file = "F:/VD_FOV_3Dgenome/RNA_Seq/DEG/glr19_mock_Fov7/all_go_term/glr19_mock_Fov7_DEGid_pairs.txt"
# outfile1 = "F:/VD_FOV_3Dgenome/RNA_Seq/DEG/glr19_mock_Fov7/all_go_term/glr19_mock_Fov7_DEGid_snaky.txt"
# outfile2 = "F:/VD_FOV_3Dgenome/RNA_Seq/DEG/glr19_mock_Fov7/all_go_term/glr19_mock_Fov7_DEGid_cotton.txt"

# #! J668_mock_Fov7
# Dir_path = 'F:/VD_FOV_3Dgenome/RNA_Seq/DEG/J668_mock_Fov7'
# Names = "J668_mock_Fov7"
# GO_id_file = "F:/VD_FOV_3Dgenome/RNA_Seq/DEG/J668_mock_Fov7/all_go_term/J668_mock_Fov7_DEGid_pairs.txt"
# outfile1 = "F:/VD_FOV_3Dgenome/RNA_Seq/DEG/J668_mock_Fov7/all_go_term/J668_mock_Fov7_DEGid_snaky.txt"
# outfile2 = "F:/VD_FOV_3Dgenome/RNA_Seq/DEG/J668_mock_Fov7/all_go_term/J668_mock_Fov7_DEGid_cotton.txt"

# #! J668_mock_V991
# Dir_path = 'F:/VD_FOV_3Dgenome/RNA_Seq/DEG/J668_mock_v991'
# Names = "J668_mock_v991"
# GO_id_file = "F:/VD_FOV_3Dgenome/RNA_Seq/DEG/J668_mock_v991/all_go_term/J668_mock_v991_DEGid_pairs.txt"
# outfile1 = "F:/VD_FOV_3Dgenome/RNA_Seq/DEG/J668_mock_v991/all_go_term/J668_mock_v991_DEGid_snaky.txt"
# outfile2 = "F:/VD_FOV_3Dgenome/RNA_Seq/DEG/J668_mock_v991/all_go_term/J668_mock_v991_DEGid_cotton.txt"

#* reactive oxygen
# # #! glr19_mock_Fov7
# Dir_path = 'F:/VD_FOV_3Dgenome/RNA_Seq/DEG/glr19_mock_Fov7'
# Names = "glr19_mock_Fov7"
# GO_id_file = "F:/VD_FOV_3Dgenome/RNA_Seq/DEG/glr19_mock_Fov7/all_go_term/glr19_mock_Fov7_reactive oxygen_DEGid_pairs.txt"
# outfile1 = "F:/VD_FOV_3Dgenome/RNA_Seq/DEG/glr19_mock_Fov7/all_go_term/glr19_mock_Fov7_reactive oxygen_DEGid_snaky.txt"
# outfile2 = "F:/VD_FOV_3Dgenome/RNA_Seq/DEG/glr19_mock_Fov7/all_go_term/glr19_mock_Fov7_reactive oxygen_DEGid_cotton.txt"

# #! J668_mock_Fov7
# Dir_path = 'F:/VD_FOV_3Dgenome/RNA_Seq/DEG/J668_mock_Fov7'
# Names = "J668_mock_Fov7"
# GO_id_file = "F:/VD_FOV_3Dgenome/RNA_Seq/DEG/J668_mock_Fov7/all_go_term/J668_mock_Fov7_reactive oxygen_DEGid_pairs.txt"
# outfile1 = "F:/VD_FOV_3Dgenome/RNA_Seq/DEG/J668_mock_Fov7/all_go_term/J668_mock_Fov7_reactive oxygen_DEGid_snaky.txt"
# outfile2 = "F:/VD_FOV_3Dgenome/RNA_Seq/DEG/J668_mock_Fov7/all_go_term/J668_mock_Fov7_reactive oxygen_DEGid_cotton.txt"

#! J668_mock_V991
Dir_path = 'F:/VD_FOV_3Dgenome/RNA_Seq/DEG/J668_mock_v991'
Names = "J668_mock_v991"
GO_id_file = "F:/VD_FOV_3Dgenome/RNA_Seq/DEG/J668_mock_v991/all_go_term/J668_mock_v991_reactive oxygen_DEGid_pairs.txt"
outfile1 = "F:/VD_FOV_3Dgenome/RNA_Seq/DEG/J668_mock_v991/all_go_term/J668_mock_v991_reactive oxygen_DEGid_snaky.txt"
outfile2 = "F:/VD_FOV_3Dgenome/RNA_Seq/DEG/J668_mock_v991/all_go_term/J668_mock_v991_reactive oxygen_DEGid_cotton.txt"

Go_gene_DEG(Dir_path, Names, GO_id_file, outfile1, outfile2)

# %%
## 分析与Ca 相关的差异基因其表达水平的差异
import pandas as pd
def diffgene_expression(Attag, AtGhId, AllAtGhId, expression, outfile, time, tags):
    df_At = pd.read_csv(Attag, sep='\t')
    df_AtGh = pd.read_csv(AtGhId, sep='\t')
    df_AtGh.drop_duplicates(keep='first', inplace=True)
    df_AllAtGh = pd.read_csv(AllAtGhId, sep='\t')
    df_Gh = pd.read_csv(expression, sep='\t')
    df_Atid = pd.merge(df_At, df_AtGh, how='inner', on=['SYMBOL'])
    df_Ghid = pd.merge(df_Atid, df_AllAtGh, how='inner', on=['TAIR'])
    #print(df_Ghid)
    df_Gh_exp = pd.merge(df_Ghid, df_Gh, how='inner', on=['GeneId'])
    #print(df_Gh_exp.shape[0])
    df_result = df_Gh_exp.query("days==@time")
    out_col = ['GeneId', 'ONTOLOGY', 'ID', 'Description', 'SYMBOL', 'TAIR', "days", 'mock_'+time, tags+"_"+time]
    df_result.to_csv(outfile, sep='\t', index=False, columns=out_col)
## glr19_fov7
#! 5min
df_glr19_fov7= diffgene_expression("G:/VD_FOV_3Dgenome/RNA_Seq/DEG/glr19_mock_Fov7/all_go_term/time_target_gene/glr19_mock_Fov7_calcium_Attags.txt", 
"G:/VD_FOV_3Dgenome/RNA_Seq/DEG/glr19_mock_Fov7/all_go_term/time_target_gene/glr19_mock_Fov7_calcium_AtID.txt", 
'G:/VD_FOV_3Dgenome/RNA_Seq/DEG/glr19_mock_Fov7/glr19_mock_Fov7_5min_DEG_geneid.txt', 
"G:/VD_FOV_3Dgenome/RNA_Seq/Rep/glr19_VD_FOV_average_TPM.txt",
"G:/VD_FOV_3Dgenome/RNA_Seq/DEG/glr19_mock_Fov7/all_go_term/time_target_gene/glr_fov7_Ca_diffgene_expression_5min.txt", '5min', 'Fov7')
#! 10min
df_glr19_fov7= diffgene_expression("G:/VD_FOV_3Dgenome/RNA_Seq/DEG/glr19_mock_Fov7/all_go_term/time_target_gene/glr19_mock_Fov7_calcium_Attags.txt", 
"G:/VD_FOV_3Dgenome/RNA_Seq/DEG/glr19_mock_Fov7/all_go_term/time_target_gene/glr19_mock_Fov7_calcium_AtID.txt", 
'G:/VD_FOV_3Dgenome/RNA_Seq/DEG/glr19_mock_Fov7/glr19_mock_Fov7_10min_DEG_geneid.txt', 
"G:/VD_FOV_3Dgenome/RNA_Seq/Rep/glr19_VD_FOV_average_TPM.txt",
"G:/VD_FOV_3Dgenome/RNA_Seq/DEG/glr19_mock_Fov7/all_go_term/time_target_gene/glr_fov7_Ca_diffgene_expression_10min.txt", '10min', 'Fov7')
#! 12h
df_glr19_fov7= diffgene_expression("G:/VD_FOV_3Dgenome/RNA_Seq/DEG/glr19_mock_Fov7/all_go_term/time_target_gene/glr19_mock_Fov7_calcium_Attags.txt", 
"G:/VD_FOV_3Dgenome/RNA_Seq/DEG/glr19_mock_Fov7/all_go_term/time_target_gene/glr19_mock_Fov7_calcium_AtID.txt", 
'G:/VD_FOV_3Dgenome/RNA_Seq/DEG/glr19_mock_Fov7/glr19_mock_Fov7_12h_DEG_geneid.txt', 
"G:/VD_FOV_3Dgenome/RNA_Seq/Rep/glr19_VD_FOV_average_TPM.txt",
"G:/VD_FOV_3Dgenome/RNA_Seq/DEG/glr19_mock_Fov7/all_go_term/time_target_gene/glr_fov7_Ca_diffgene_expression_12h.txt", '12h', 'Fov7')

## J668_fov7
#! 1min
df_J668_fov7= diffgene_expression("G:/VD_FOV_3Dgenome/RNA_Seq/DEG/J668_mock_Fov7/all_go_term/time_target_gene/J668_mock_Fov7_calcium_Attags.txt", 
"G:/VD_FOV_3Dgenome/RNA_Seq/DEG/J668_mock_Fov7/all_go_term/time_target_gene/J668_mock_Fov7_calcium_AtID.txt", 
'G:/VD_FOV_3Dgenome/RNA_Seq/DEG/J668_mock_Fov7/J668_mock_Fov7_1min_DEG_geneid.txt', 
"G:/VD_FOV_3Dgenome/RNA_Seq/Rep/J668_VD_FOV_average_TPM.txt",
"G:/VD_FOV_3Dgenome/RNA_Seq/DEG/J668_mock_Fov7/all_go_term/time_target_gene/J668_fov7_Ca_diffgene_expression_1min.txt", '1min', 'Fov7')
#! 5min
df_J668_fov7= diffgene_expression("G:/VD_FOV_3Dgenome/RNA_Seq/DEG/J668_mock_Fov7/all_go_term/time_target_gene/J668_mock_Fov7_calcium_Attags.txt", 
"G:/VD_FOV_3Dgenome/RNA_Seq/DEG/J668_mock_Fov7/all_go_term/time_target_gene/J668_mock_Fov7_calcium_AtID.txt", 
'G:/VD_FOV_3Dgenome/RNA_Seq/DEG/J668_mock_Fov7/J668_mock_Fov7_5min_DEG_geneid.txt', 
"G:/VD_FOV_3Dgenome/RNA_Seq/Rep/J668_VD_FOV_average_TPM.txt",
"G:/VD_FOV_3Dgenome/RNA_Seq/DEG/J668_mock_Fov7/all_go_term/time_target_gene/J668_fov7_Ca_diffgene_expression_5min.txt", '5min', 'Fov7')
#! 12h
df_J668_fov7= diffgene_expression("G:/VD_FOV_3Dgenome/RNA_Seq/DEG/J668_mock_Fov7/all_go_term/time_target_gene/J668_mock_Fov7_calcium_Attags.txt", 
"G:/VD_FOV_3Dgenome/RNA_Seq/DEG/J668_mock_Fov7/all_go_term/time_target_gene/J668_mock_Fov7_calcium_AtID.txt", 
'G:/VD_FOV_3Dgenome/RNA_Seq/DEG/J668_mock_Fov7/J668_mock_Fov7_12h_DEG_geneid.txt', 
"G:/VD_FOV_3Dgenome/RNA_Seq/Rep/J668_VD_FOV_average_TPM.txt",
"G:/VD_FOV_3Dgenome/RNA_Seq/DEG/J668_mock_Fov7/all_go_term/time_target_gene/J668_fov7_Ca_diffgene_expression_12h.txt", '12h', 'Fov7')

## J668_v991
#! 5min
df_J668_v991= diffgene_expression("G:/VD_FOV_3Dgenome/RNA_Seq/DEG/J668_mock_v991/all_go_term/time_target_gene/J668_mock_v991_calcium_Attags.txt", 
"G:/VD_FOV_3Dgenome/RNA_Seq/DEG/J668_mock_v991/all_go_term/time_target_gene/J668_mock_v991_calcium_AtID.txt", 
'G:/VD_FOV_3Dgenome/RNA_Seq/DEG/J668_mock_v991/J668_mock_v991_5min_DEG_geneid.txt', 
"G:/VD_FOV_3Dgenome/RNA_Seq/Rep/J668_VD_FOV_average_TPM.txt",
"G:/VD_FOV_3Dgenome/RNA_Seq/DEG/J668_mock_v991/all_go_term/time_target_gene/J668_v991_Ca_diffgene_expression_5min.txt", '5min', 'v991')
#! 12h
df_J668_v991= diffgene_expression("G:/VD_FOV_3Dgenome/RNA_Seq/DEG/J668_mock_v991/all_go_term/time_target_gene/J668_mock_v991_calcium_Attags.txt", 
"G:/VD_FOV_3Dgenome/RNA_Seq/DEG/J668_mock_v991/all_go_term/time_target_gene/J668_mock_v991_calcium_AtID.txt", 
'G:/VD_FOV_3Dgenome/RNA_Seq/DEG/J668_mock_v991/J668_mock_v991_12h_DEG_geneid.txt', 
"G:/VD_FOV_3Dgenome/RNA_Seq/Rep/J668_VD_FOV_average_TPM.txt",
"G:/VD_FOV_3Dgenome/RNA_Seq/DEG/J668_mock_v991/all_go_term/time_target_gene/J668_v991_Ca_diffgene_expression_12h.txt", '12h', 'v991')

# %%
## 分析 钙相关基因 在六个时期，j668 基因缺失与否条件下的变化情况
df_g668_mock_fov7_v991 = pd.read_csv("F:/VD_FOV_3Dgenome/RNA_Seq/Rep/J668_VD_FOV_TPM.txt", sep='\t')
df_g668_fov7 = pd.read_csv("F:/VD_FOV_3Dgenome/RNA_Seq/DEG/J668_mock_Fov7/all_go_term/J668_mock_Fov7_DEGid_cotton.txt", sep='\t')
df_g668_v991 = pd.read_csv("F:/VD_FOV_3Dgenome/RNA_Seq/DEG/J668_mock_v991/all_go_term/J668_mock_v991_DEGid_cotton.txt", sep='\t')
df_g668_v991_fov7 = df_g668_v991.append(df_g668_fov7, ignore_index=True).drop_duplicates(keep='first')
df_out = pd.merge(df_g668_mock_fov7_v991, df_g668_v991_fov7, how='inner', on=['GeneId'])
df_out.to_csv('F:/VD_FOV_3Dgenome/RNA_Seq/DEG/heat_map/J668_fov7_v991/calcium_j668_fov7_v991_tpm.txt', sep='\t', index=False)

# %%
## 分析 氧相关基因 在六个时期，j668 基因缺失与否条件下的变化情况
df_g668_mock_fov7_v991 = pd.read_csv("F:/VD_FOV_3Dgenome/RNA_Seq/Rep/J668_VD_FOV_TPM.txt", sep='\t')
df_g668_fov7 = pd.read_csv("F:/VD_FOV_3Dgenome/RNA_Seq/DEG/J668_mock_Fov7/all_go_term/J668_mock_Fov7_reactive oxygen_DEGid_cotton.txt", sep='\t')
df_g668_v991 = pd.read_csv("F:/VD_FOV_3Dgenome/RNA_Seq/DEG/J668_mock_v991/all_go_term/J668_mock_v991_reactive oxygen_DEGid_cotton.txt", sep='\t')
df_g668_v991_fov7 = df_g668_v991.append(df_g668_fov7, ignore_index=True).drop_duplicates(keep='first')
df_out = pd.merge(df_g668_mock_fov7_v991, df_g668_v991_fov7, how='inner', on=['GeneId'])
df_out.to_csv('F:/VD_FOV_3Dgenome/RNA_Seq/DEG/heat_map/J668_fov7_v991/calcium_j668_fov7_v991_tpm_oxygen.txt', sep='\t', index=False)

# %%
##分析Top34的Go term 聚类后，第一类Term 所能够包含的拟南芥基因ID
import pandas as pd
df_glr_fov7_1min = pd.read_csv('G:/VD_FOV_3Dgenome/RNA_Seq/DEG/glr19_mock_Fov7/all_go_term/glr19_mock_Fov7_1min_DEG_GO.txt', sep='\t')
df_glr_fov7_5min = pd.read_csv('G:/VD_FOV_3Dgenome/RNA_Seq/DEG/glr19_mock_Fov7/all_go_term/glr19_mock_Fov7_5min_DEG_GO.txt', sep='\t')
df_glr_fov7_10min = pd.read_csv('G:/VD_FOV_3Dgenome/RNA_Seq/DEG/glr19_mock_Fov7/all_go_term/glr19_mock_Fov7_10min_DEG_GO.txt', sep='\t')
df_glr_fov7_30min = pd.read_csv('G:/VD_FOV_3Dgenome/RNA_Seq/DEG/glr19_mock_Fov7/all_go_term/glr19_mock_Fov7_30min_DEG_GO.txt', sep='\t')
df_glr_fov7_90min = pd.read_csv('G:/VD_FOV_3Dgenome/RNA_Seq/DEG/glr19_mock_Fov7/all_go_term/glr19_mock_Fov7_90min_DEG_GO.txt', sep='\t')
df_glr_fov7_180min = pd.read_csv('G:/VD_FOV_3Dgenome/RNA_Seq/DEG/glr19_mock_Fov7/all_go_term/glr19_mock_Fov7_180min_DEG_GO.txt', sep='\t')
df_glr_fov7_12h = pd.read_csv('G:/VD_FOV_3Dgenome/RNA_Seq/DEG/glr19_mock_Fov7/all_go_term/glr19_mock_Fov7_12h_DEG_GO.txt', sep='\t')
#! j668_fov7
df_j668_fov7_1min = pd.read_csv('G:/VD_FOV_3Dgenome/RNA_Seq/DEG/J668_mock_Fov7/all_go_term/J668_mock_Fov7_1min_DEG_GO.txt', sep='\t')
df_j668_fov7_5min = pd.read_csv('G:/VD_FOV_3Dgenome/RNA_Seq/DEG/J668_mock_Fov7/all_go_term/J668_mock_Fov7_5min_DEG_GO.txt', sep='\t')
df_j668_fov7_10min = pd.read_csv('G:/VD_FOV_3Dgenome/RNA_Seq/DEG/J668_mock_Fov7/all_go_term/J668_mock_Fov7_10min_DEG_GO.txt', sep='\t')
df_j668_fov7_30min = pd.read_csv('G:/VD_FOV_3Dgenome/RNA_Seq/DEG/J668_mock_Fov7/all_go_term/J668_mock_Fov7_30min_DEG_GO.txt', sep='\t')
df_j668_fov7_90min = pd.read_csv('G:/VD_FOV_3Dgenome/RNA_Seq/DEG/J668_mock_Fov7/all_go_term/J668_mock_Fov7_90min_DEG_GO.txt', sep='\t')
df_j668_fov7_180min = pd.read_csv('G:/VD_FOV_3Dgenome/RNA_Seq/DEG/J668_mock_Fov7/all_go_term/J668_mock_Fov7_180min_DEG_GO.txt', sep='\t')
df_j668_fov7_12h = pd.read_csv('G:/VD_FOV_3Dgenome/RNA_Seq/DEG/J668_mock_Fov7/all_go_term/J668_mock_Fov7_12h_DEG_GO.txt', sep='\t')
#! j668_v991
df_j668_v991_1min = pd.read_csv('G:/VD_FOV_3Dgenome/RNA_Seq/DEG/J668_mock_v991/all_go_term/J668_mock_v991_1min_DEG_GO.txt', sep='\t')
df_j668_v991_5min = pd.read_csv('G:/VD_FOV_3Dgenome/RNA_Seq/DEG/J668_mock_v991/all_go_term/J668_mock_v991_5min_DEG_GO.txt', sep='\t')
df_j668_v991_10min = pd.read_csv('G:/VD_FOV_3Dgenome/RNA_Seq/DEG/J668_mock_v991/all_go_term/J668_mock_v991_10min_DEG_GO.txt', sep='\t')
df_j668_v991_30min = pd.read_csv('G:/VD_FOV_3Dgenome/RNA_Seq/DEG/J668_mock_v991/all_go_term/J668_mock_v991_30min_DEG_GO.txt', sep='\t')
df_j668_v991_90min = pd.read_csv('G:/VD_FOV_3Dgenome/RNA_Seq/DEG/J668_mock_v991/all_go_term/J668_mock_v991_90min_DEG_GO.txt', sep='\t')
df_j668_v991_180min = pd.read_csv('G:/VD_FOV_3Dgenome/RNA_Seq/DEG/J668_mock_v991/all_go_term/J668_mock_v991_180min_DEG_GO.txt', sep='\t')
df_j668_v991_12h = pd.read_csv('G:/VD_FOV_3Dgenome/RNA_Seq/DEG/J668_mock_v991/all_go_term/J668_mock_v991_12h_DEG_GO.txt', sep='\t')

# %%
df_glr_fov7_1min['tags'] = ['glr_fov7_1min']*df_glr_fov7_1min.shape[0]
df_glr_fov7_5min['tags'] = ['glr_fov7_5min']*df_glr_fov7_5min.shape[0]
df_glr_fov7_10min['tags'] = ['glr_fov7_10min']*df_glr_fov7_10min.shape[0]
df_glr_fov7_30min['tags'] = ['glr_fov7_30min']*df_glr_fov7_30min.shape[0]
df_glr_fov7_90min['tags'] = ['glr_fov7_90min']*df_glr_fov7_90min.shape[0]
df_glr_fov7_180min['tags'] = ['glr_fov7_180min']*df_glr_fov7_180min.shape[0]
df_glr_fov7_12h['tags'] = ['glr_fov7_12h']*df_glr_fov7_12h.shape[0]

df_j668_fov7_1min['tags'] = ['j668_fov7_1min']*df_j668_fov7_1min.shape[0]
df_j668_fov7_5min['tags'] = ['j668_fov7_5min']*df_j668_fov7_5min.shape[0]
df_j668_fov7_10min['tags'] = ['j668_fov7_10min']*df_j668_fov7_10min.shape[0]
df_j668_fov7_30min['tags'] = ['j668_fov7_30min']*df_j668_fov7_30min.shape[0]
df_j668_fov7_90min['tags'] = ['j668_fov7_90min']*df_j668_fov7_90min.shape[0]
df_j668_fov7_180min['tags'] = ['j668_fov7_180min']*df_j668_fov7_180min.shape[0]
df_j668_fov7_12h['tags'] = ['j668_fov7_12h']*df_j668_fov7_12h.shape[0]

df_j668_v991_1min['tags'] = ['j668_v991_1min']*df_j668_v991_1min.shape[0]
df_j668_v991_5min['tags'] = ['j668_v991_5min']*df_j668_v991_5min.shape[0]
df_j668_v991_10min['tags'] = ['j668_v991_10min']*df_j668_v991_10min.shape[0]
df_j668_v991_30min['tags'] = ['j668_v991_30min']*df_j668_v991_30min.shape[0]
df_j668_v991_90min['tags'] = ['j668_v991_90min']*df_j668_v991_90min.shape[0]
df_j668_v991_180min['tags'] = ['j668_v991_180min']*df_j668_v991_180min.shape[0]
df_j668_v991_12h['tags'] = ['j668_v991_12h']*df_j668_v991_12h.shape[0]

df_all = df_glr_fov7_1min.append([df_glr_fov7_5min, df_glr_fov7_10min, df_glr_fov7_30min, df_glr_fov7_90min, df_glr_fov7_180min, df_glr_fov7_12h, df_j668_fov7_1min, df_j668_fov7_5min, df_j668_fov7_10min, df_j668_fov7_30min, df_j668_fov7_90min, df_j668_fov7_180min, df_j668_fov7_12h, df_j668_v991_1min, df_j668_v991_5min, df_j668_v991_10min, df_j668_v991_30min, df_j668_v991_90min, df_j668_v991_180min, df_j668_v991_12h])
#print(df_all)
df_GoID_cliques_one = pd.read_csv("G:/VD_FOV_3Dgenome/RNA_Seq/DEG/Go_terms/top34/one_clues_Go_term.txt", names = ['ID'])
df_GoTerm_cliques_one = pd.merge(df_all, df_GoID_cliques_one, how='inner', on=['ID'])
#print(df_GoTerm_cliques_one)

# %%
## 提取所能够对应的三个比较
df_glr_fov7 = df_GoTerm_cliques_one.query("tags.str.contains('glr_fov7')", engine='python')[['geneID']]
df_j668_fov7 = df_GoTerm_cliques_one.query("tags.str.contains('j668_fov7')", engine='python')[['geneID']]
df_j668_v991 = df_GoTerm_cliques_one.query("tags.str.contains('j668_v991')", engine='python')[['geneID']]
#! glr_fov7
df_glr_fov7_geneid = df_glr_fov7['geneID'].str.split('/', expand=True)
df_glr_fov7_geneid_tmp = df_glr_fov7_geneid.to_numpy()
df_glr_fov7_geneid_tmp = df_glr_fov7_geneid_tmp.reshape(-1,1)
df_glr_fov7_geneid = pd.DataFrame(df_glr_fov7_geneid_tmp, columns=['geneid'])
df_glr_fov7_geneid.drop_duplicates(keep='first', inplace=True)
df_glr_fov7_geneid.dropna(inplace=True)
#print(df_glr_fov7_geneid)
#! j668_fov7
df_j668_fov7_geneid = df_j668_fov7['geneID'].str.split('/', expand=True)
df_j668_fov7_geneid_tmp = df_j668_fov7_geneid.to_numpy()
df_j668_fov7_geneid_tmp = df_j668_fov7_geneid_tmp.reshape(-1,1)
df_j668_fov7_geneid = pd.DataFrame(df_j668_fov7_geneid_tmp, columns=['geneid'])
df_j668_fov7_geneid.drop_duplicates(keep='first', inplace=True)
df_j668_fov7_geneid.dropna(inplace=True)
#! j668_v991
df_j668_v991_geneid = df_j668_v991['geneID'].str.split('/', expand=True)
df_j668_v991_geneid_tmp = df_j668_v991_geneid.to_numpy()
df_j668_v991_geneid_tmp = df_j668_v991_geneid_tmp.reshape(-1,1)
df_j668_v991_geneid = pd.DataFrame(df_j668_v991_geneid_tmp, columns=['geneid'])
df_j668_v991_geneid.drop_duplicates(keep='first', inplace=True)
df_j668_v991_geneid.dropna(inplace=True)

# %%
## 写出三个文件所包含的基因ID
df_glr_fov7_geneid.to_csv("G:/VD_FOV_3Dgenome/RNA_Seq/DEG/Go_terms/top34/glr_fov7_cliques_one_geneid.txt", sep="\t", index=False, header=False)
df_j668_fov7_geneid.to_csv("G:/VD_FOV_3Dgenome/RNA_Seq/DEG/Go_terms/top34/j668_fov7_cliques_one_geneid.txt", sep="\t", index=False, header=False)
df_j668_v991_geneid.to_csv("G:/VD_FOV_3Dgenome/RNA_Seq/DEG/Go_terms/top34/j668_v991_cliques_one_geneid.txt", sep="\t", index=False, header=False)

# %%
## 整理所有时期能够发生差异表达的基因id
#! glr19_mock_Fov7
# df = pd.DataFrame()
# for i in ['1min', '5min', '10min', '30min', '90min', '180min', '12h']:
#     files = "G:/VD_FOV_3Dgenome/RNA_Seq/DEG/glr19_mock_Fov7/glr19_mock_Fov7_{0}_DEG_geneid.txt".format(i)
#     df_geneid = pd.read_csv(files, sep='\t')
#     df = df.append(df_geneid, ignore_index=True)
# df.drop_duplicates(keep='first', inplace=True)
# df.to_csv('G:/VD_FOV_3Dgenome/RNA_Seq/DEG/glr19_mock_Fov7/glr19_mock_Fov7_all_DEG_geneid.txt', sep='\t', index=False)
#! J668_mock_Fov7
# df = pd.DataFrame()
# for i in ['1min', '5min', '10min', '30min', '90min', '180min', '12h']:
#     files = "G:/VD_FOV_3Dgenome/RNA_Seq/DEG/J668_mock_Fov7/J668_mock_Fov7_{0}_DEG_geneid.txt".format(i)
#     df_geneid = pd.read_csv(files, sep='\t')
#     df = df.append(df_geneid, ignore_index=True)
# df.drop_duplicates(keep='first', inplace=True)
# df.to_csv('G:/VD_FOV_3Dgenome/RNA_Seq/DEG/J668_mock_Fov7/J668_mock_Fov7_all_DEG_geneid.txt', sep='\t', index=False)
#! J668_mock_v991
df = pd.DataFrame()
for i in ['1min', '5min', '10min', '30min', '90min', '180min', '12h']:
    files = "G:/VD_FOV_3Dgenome/RNA_Seq/DEG/J668_mock_v991/J668_mock_v991_{0}_DEG_geneid.txt".format(i)
    df_geneid = pd.read_csv(files, sep='\t')
    df = df.append(df_geneid, ignore_index=True)
df.drop_duplicates(keep='first', inplace=True)
df.to_csv('G:/VD_FOV_3Dgenome/RNA_Seq/DEG/J668_mock_v991/J668_mock_v991_all_DEG_geneid.txt', sep='\t', index=False)

# %%
## 给文件添加表头
headers = ['GeneId', 'g0min1', 'g0min2']
for s in ['mock', 'Fov7']:
    for i in ['1min', '5min', '10min', '30min', '90min', '180min', '12h']:
        names1 = "{0}_{1}1".format(s, i)
        names2 = "{0}_{1}2".format(s, i)
        headers.append(names1)
        headers.append(names2)
df = pd.read_csv('G:/VD_FOV_3Dgenome/RNA_Seq/Rep/glr19_VD_FOV_TPM.txt', sep="\t", header=None, names=headers)
df.to_csv('G:/VD_FOV_3Dgenome/RNA_Seq/Rep/glr19_VD_FOV_TPM.txt', sep='\t', index=False)

# %%
##计算基因表达量平均值
df = pd.read_csv("G:/VD_FOV_3Dgenome/RNA_Seq/Rep/glr19_VD_FOV_TPM.txt", sep='\t')
for s in ['mock', 'Fov7']:
    for i in ['1min', '5min', '10min', '30min', '90min', '180min', '12h']:
        names = "{0}_{1}".format(s, i)
        names1 = "{0}_{1}1".format(s, i)
        names2 = "{0}_{1}2".format(s, i)
        df[names] = (df[names1] + df[names2])/2
df['g0min'] = (df['g0min1'] + df['g0min2'])/2
all_names = ['GeneId', 'g0min', 'mock_1min', 'mock_5min', 'mock_10min', 'mock_30min', 'mock_90min', 'mock_180min', 'mock_12h', 'Fov7_1min', 'Fov7_5min', 'Fov7_10min', 'Fov7_30min', 'Fov7_90min', 'Fov7_180min', 'Fov7_12h']
df.to_csv("G:/VD_FOV_3Dgenome/RNA_Seq/Rep/glr19_VD_FOV_average_TPM.txt", sep="\t", columns=all_names, index=False)

# %%
##计算基因表达量平均值
df = pd.read_csv("G:/VD_FOV_3Dgenome/RNA_Seq/Rep/J668_VD_FOV_TPM.txt", sep='\t')
for s in ['mock', 'Fov7', 'v991']:
    for i in ['1min', '5min', '10min', '30min', '90min', '180min', '12h']:
        names = "{0}_{1}".format(s, i)
        names1 = "{0}_{1}1".format(s, i)
        names2 = "{0}_{1}2".format(s, i)
        df[names] = (df[names1] + df[names2])/2
df['g0min'] = (df['J668_0min1'] + df['J668_0min2'])/2
all_names = ['GeneId', 'g0min', 'mock_1min', 'mock_5min', 'mock_10min', 'mock_30min', 'mock_90min', 'mock_180min', 'mock_12h', 'Fov7_1min', 'Fov7_5min', 'Fov7_10min', 'Fov7_30min', 'Fov7_90min', 'Fov7_180min', 'Fov7_12h', 'v991_1min', 'v991_5min', 'v991_10min', 'v991_30min', 'v991_90min', 'v991_180min', 'v991_12h']
df.to_csv("G:/VD_FOV_3Dgenome/RNA_Seq/Rep/J668_VD_FOV_average_TPM.txt", sep="\t", columns=all_names, index=False)

# %%
## 找出拟南芥对应基因的棉花基因并且分析出其表达量
import pandas as pd
df_glr19 = pd.read_csv("G:/VD_FOV_3Dgenome/RNA_Seq/DEG/glr19_mock_Fov7/glr19_mock_Fov7_all_DEG_geneid.txt", sep='\t')
df_glr_fov7_geneid = pd.read_csv("G:/VD_FOV_3Dgenome/RNA_Seq/DEG/Go_terms/top34/glr19_fov7_symbol_geneid.txt", sep='\t')
df_glr19_expression = pd.read_csv("G:/VD_FOV_3Dgenome/RNA_Seq/Rep/glr19_VD_FOV_average_TPM.txt", sep='\t')
df_glr19_gene = pd.merge(df_glr19, df_glr_fov7_geneid, how='inner', on=['TAIR'])[['GeneId']]
df_glr19_gene_exp = pd.merge(df_glr19_gene, df_glr19_expression, how='inner', on=['GeneId'])
mock_gene_names = ['GeneId', 'g0min', 'mock_1min', 'mock_5min', 'mock_10min', 'mock_30min', 'mock_90min', 'mock_180min', 'mock_12h']
glr19_gene_names = ['GeneId', 'g0min', 'Fov7_1min', 'Fov7_5min', 'Fov7_10min', 'Fov7_30min', 'Fov7_90min', 'Fov7_180min', 'Fov7_12h']
df_glr19_gene_exp.drop_duplicates(keep='first', inplace=True)
df_glr19_gene_exp.to_csv("G:/VD_FOV_3Dgenome/RNA_Seq/DEG/Go_terms/top34/dynamic_diff_mock_gene.txt", sep='\t', index=False, columns = mock_gene_names)
df_glr19_gene_exp.to_csv("G:/VD_FOV_3Dgenome/RNA_Seq/DEG/Go_terms/top34/dynamic_diff_glr19_gene.txt", sep='\t', index=False, columns = glr19_gene_names)

# %%
## 找出各个时期能和ca 相关的基因
#! glr19 fov7
# import pandas as pd
# df_all = pd.read_csv("G:/VD_FOV_3Dgenome/RNA_Seq/Rep/glr19_VD_FOV_average_TPM.txt", sep='\t')
# df_glr = pd.read_csv("G:/VD_FOV_3Dgenome/RNA_Seq/DEG/Ca gene/glr19_fov7.txt", sep='\t'
# df_glr.drop_duplicates(keep='first', inplace=True) 
# #print(df_glr.shape[0])
# df_glrs = pd.merge(df_glr, df_all,how='inner',on=['GeneId'])
# df_glrs.to_csv("G:/VD_FOV_3Dgenome/RNA_Seq/DEG/Ca gene/glr19_fov7_gene.txt", sep='\t', index=False)

# #! j668 Fov7
# import pandas as pd
# df_all = pd.read_csv("G:/VD_FOV_3Dgenome/RNA_Seq/Rep/J668_VD_FOV_average_TPM.txt", sep='\t')
# df_j668 = pd.read_csv("G:/VD_FOV_3Dgenome/RNA_Seq/DEG/Ca gene/j668_fov7.txt", sep='\t')
# df_j668.drop_duplicates(keep='first', inplace=True) 
# df_j6682 = pd.merge(df_j668, df_all,how='inner',on=['GeneId'])
# df_j6682.to_csv("G:/VD_FOV_3Dgenome/RNA_Seq/DEG/Ca gene/j668_fov7_gene.txt", sep='\t', index=False)

#! j668 v991
import pandas as pd
df_all = pd.read_csv("G:/VD_FOV_3Dgenome/RNA_Seq/Rep/J668_VD_FOV_average_TPM.txt", sep='\t')
df_j668 = pd.read_csv("G:/VD_FOV_3Dgenome/RNA_Seq/DEG/Ca gene/j668_v991.txt", sep='\t')
df_j668.drop_duplicates(keep='first', inplace=True) 
df_j6682 = pd.merge(df_j668, df_all,how='inner',on=['GeneId'])
df_j6682.to_csv("G:/VD_FOV_3Dgenome/RNA_Seq/DEG/Ca gene/j668_v991_gene.txt", sep='\t', index=False)

# %%
# 将各个时期的Ca 相关基因汇总到一个表中
df_ghid = pd.read_csv("G:/VD_FOV_3Dgenome/RNA_Seq/DEG/Ca gene/glr19_fov7_v991_all_time_id.txt", sep='\t')
df_ghid.drop_duplicates(keep='first', inplace=True)
print(df_ghid.shape[0])
df_atid = pd.read_csv("G:/VD_FOV_3Dgenome/RNA_Seq/Gh_vs_Arabidopsis.txt", sep='\t', names=['GeneId', 'AtId'])
df_glr19 = pd.read_csv("G:/VD_FOV_3Dgenome/RNA_Seq/Rep/glr19_VD_FOV_average_TPM.txt", sep='\t')
df_j668 = pd.read_csv("G:/VD_FOV_3Dgenome/RNA_Seq/Rep/J668_VD_FOV_average_TPM.txt", sep='\t')
df_glr19.columns = ['GeneId', 'glr19_g0mim', "glr19_mock_1min", "glr19_mock_5min", 'glr19_mock_10min', 'glr19_mock_30min', 'glr19_mock_90min', 'glr19_mock_180min', 'glr19_mock_12h', 'glr19_fov7_1min',  "glr19_fov7_5min", 'glr19_fov7_10min', 'glr19_fov7_30min', 'glr19_fov7_90min', 'glr19_fov7_180min', 'glr19_fov7_12h']
df_j668.columns = ['GeneId', 'j668_g0min', "j668_mock_1min", "j668_mock_5min", 'j668_mock_10min', 'j668_mock_30min', 'j668_mock_90min', 'j668_mock_180min', 'j668_mock_12h', 'j668_fov7_1min',  "j668_fov7_5min", 'j668_fov7_10min', 'j668_fov7_30min', 'j668_fov7_90min', 'j668_fov7_180min', 'j668_fov7_12h',  'j668_v991_1min',  "j668_v991_5min", 'j668_v991_10min', 'j668_v991_30min', 'j668_v991_90min', 'j668_v991_180min', 'j668_v991_12h']
df_a = pd.merge(df_ghid, df_atid, how='inner', on=['GeneId'])
df_b = pd.merge(df_a, df_glr19, how='inner', on=['GeneId'])
df_c = pd.merge(df_b, df_j668, how='inner', on=['GeneId'])
#df_c.to_csv("G:/VD_FOV_3Dgenome/RNA_Seq/DEG/Ca gene/Ca_GoTerm_gene_all_time.txt", sep='\t', index=False)
# Out:
# 194

# %%
## 将所有的表达变化汇总到一个图中
df_glr19_j668 = pd.merge(df_glr19, df_j668, how="inner", on=['GeneId'])
df_glr19_j668.to_csv("G:/VD_FOV_3Dgenome/RNA_Seq/Rep/glr19_j668_VD_Fov7_averge_TPM.txt", sep="\t", index=False)

# %%
# 分析Ca 相关的基因
import pandas as pd
# #! glr19
# names = ['GeneId','g0min', 'Fov7_1min', 'Fov7_5min', 'Fov7_10min', 'Fov7_30min', 'Fov7_90min', 'Fov7_180min', 'Fov7_12h']
# df = pd.read_csv("G:/VD_FOV_3Dgenome/RNA_Seq/DEG/Ca gene/glr19_fov7_gene.txt", sep="\t")
# df.to_csv("G:/VD_FOV_3Dgenome/RNA_Seq/DEG/Ca gene/mfuzz/glr19/glr19_fov7_dynamic.txt", sep="\t", columns = names, index=False)

#j668_fov7
# names = ['GeneId','g0min', 'Fov7_1min', 'Fov7_5min', 'Fov7_10min', 'Fov7_30min', 'Fov7_90min', 'Fov7_180min', 'Fov7_12h']
# df = pd.read_csv("G:/VD_FOV_3Dgenome/RNA_Seq/DEG/Ca gene/j668_fov7_gene.txt", sep="\t")
# df.to_csv("G:/VD_FOV_3Dgenome/RNA_Seq/DEG/Ca gene/mfuzz/j668_fov7/j668_fov7_dynamic.txt", sep="\t", columns = names, index=False)

#j668_v991
names = ['GeneId','g0min', 'v991_1min', 'v991_5min', 'v991_10min', 'v991_30min', 'v991_90min', 'v991_180min', 'v991_12h']
df = pd.read_csv("G:/VD_FOV_3Dgenome/RNA_Seq/DEG/Ca gene/j668_v991_gene.txt", sep="\t")
df.to_csv("G:/VD_FOV_3Dgenome/RNA_Seq/DEG/Ca gene/mfuzz/j668_v991/j668_v991_dynamic.txt", sep="\t", columns = names, index=False)

# %%
## 分析mfuzz所有聚类基因在所有时期的表达变化
# # glr19
# import re
# import pandas as pd
# df_cluster_geneid = pd.read_csv('G:/VD_FOV_3Dgenome/RNA_Seq/DEG/Ca gene/mfuzz/glr19/glr_fov7_cluster_geneid.txt', sep='\t', names=['GeneId', 'clusterId'])
# #print(df_cluster_geneid.shape[0])
# df_all_tpm = pd.read_csv("G:/VD_FOV_3Dgenome/RNA_Seq/Rep/glr19_j668_VD_Fov7_averge_TPM.txt", sep="\t")
# df_cluter_all_tpm = pd.merge(df_cluster_geneid, df_all_tpm, how='inner', on=['GeneId'])
# #print(df_cluter_all_tpm.shape[0])
# ## 写到文件中
# df_cluter_all_tpm.to_csv("G:/VD_FOV_3Dgenome/RNA_Seq/DEG/Ca gene/mfuzz/glr19/all_gene_dynamic_width.txt", sep='\t', index=False)

# #j668 fov7
# import re
# import pandas as pd
# df_cluster_geneid = pd.read_csv('G:/VD_FOV_3Dgenome/RNA_Seq/DEG/Ca gene/mfuzz/j668_fov7/j668_fov7_cluster_geneid.txt', sep='\t', names=['GeneId', 'clusterId'])
# #print(df_cluster_geneid.shape[0])
# df_all_tpm = pd.read_csv("G:/VD_FOV_3Dgenome/RNA_Seq/Rep/glr19_j668_VD_Fov7_averge_TPM.txt", sep="\t")
# df_cluter_all_tpm = pd.merge(df_cluster_geneid, df_all_tpm, how='inner', on=['GeneId'])
# #print(df_cluter_all_tpm.shape[0])
# ## 写到文件中
# df_cluter_all_tpm.to_csv("G:/VD_FOV_3Dgenome/RNA_Seq/DEG/Ca gene/mfuzz/j668_fov7/all_gene_dynamic_width.txt", sep='\t', index=False)

#j668 v991
import re
import pandas as pd
df_cluster_geneid = pd.read_csv('G:/VD_FOV_3Dgenome/RNA_Seq/DEG/Ca gene/mfuzz/j668_v991/j668_v991_cluster_geneid.txt', sep='\t', names=['GeneId', 'clusterId'])
#print(df_cluster_geneid.shape[0])
df_all_tpm = pd.read_csv("G:/VD_FOV_3Dgenome/RNA_Seq/Rep/glr19_j668_VD_Fov7_averge_TPM.txt", sep="\t")
df_cluter_all_tpm = pd.merge(df_cluster_geneid, df_all_tpm, how='inner', on=['GeneId'])
#print(df_cluter_all_tpm.shape[0])
## 写到文件中
df_cluter_all_tpm.to_csv("G:/VD_FOV_3Dgenome/RNA_Seq/DEG/Ca gene/mfuzz/j668_v991/all_gene_dyna mic_width.txt", sep='\t', index=False)

# # 长宽数据转换
# df_cluster_all_tpm_long = pd.melt(df_cluter_all_tpm, id_vars=['GeneId', 'clusterId'])
# #print(df_cluster_all_tpm_long)
# # 给不同类型基因打上标签
# pattern = re.compile(r"j668_\w{4}|glr19_\w{4}")
# pattern2 = re.compile(r"0min|1min|5min|10min|30min|90min|180min|12h")
# for index, row in df_cluster_all_tpm_long.iterrows():
#     #print(row)
#     variables = row['variable']
#     tags = pattern.findall(variables)[0]
#     times = pattern2.findall(variables)[0]
#     df_cluster_all_tpm_long.loc[index, 'tags'] = tags
#     df_cluster_all_tpm_long.loc[index, 'times'] = times
# df_glr19_0min = df_cluster_all_tpm_long.query("tags == 'glr19_0min'")
# df_j668_0min = df_cluster_all_tpm_long.query("tags == 'j668_0min'")

# #! glr19 0min
# df_glr19_0min['tags'] = ['glr19_mock']*df_glr19_0min.shape[0]
# df_cluster_all_tpm_long = df_cluster_all_tpm_long.append(df_glr19_0min, ignore_index=True)
# df_glr19_0min['tags'] = ['glr19_fov7']*df_glr19_0min.shape[0]
# df_cluster_all_tpm_long = df_cluster_all_tpm_long.append(df_glr19_0min, ignore_index=True)

# #! j668 0min
# df_j668_0min['tags'] = ['j668_mock']*df_j668_0min.shape[0]
# df_cluster_all_tpm_long = df_cluster_all_tpm_long.append(df_j668_0min, ignore_index=True)
# df_j668_0min['tags'] = ['j668_fov7']*df_j668_0min.shape[0]
# df_cluster_all_tpm_long = df_cluster_all_tpm_long.append(df_j668_0min, ignore_index=True)
# df_j668_0min['tags'] = ['j668_v991']*df_j668_0min.shape[0]
# df_cluster_all_tpm_long = df_cluster_all_tpm_long.append(df_j668_0min, ignore_index=True)

# df_result1 = df_cluster_all_tpm_long.query("~(tags=='glr19_0min')").copy()
# df_result = df_result1.query("~(tags=='j668_0min')")
# df_result.to_csv('G:/VD_FOV_3Dgenome/RNA_Seq/DEG/Ca gene/mfuzz/glr19/all_gene_dynamic.txt', sep='\t', index=False)
# Out:
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
